# %% [markdown]
# # Hello, [Pandas](https://pandas.pydata.org/docs/reference/index.html)!

# %% [markdown]
# ## What is pandas?

# %% [markdown]
# - (in short) data analysis library
# - (according to the official website) "an open source, BSD-licensed library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language."

# %% [markdown]
# ## Download data
#
# We will be using the [Stack Overflow Annual Developer Survey](https://insights.stackoverflow.com/survey) results from last year.

# %%
# !wget https://info.stackoverflowsolutions.com/rs/719-EMH-566/images/stack-overflow-developer-survey-2021.zip -O tmp.zip
# !unzip tmp.zip -d ./data
# !rm tmp.zip
# Out:
# --2022-03-10 13:21:02--  https://info.stackoverflowsolutions.com/rs/719-EMH-566/images/stack-overflow-developer-survey-2021.zip
# Resolving info.stackoverflowsolutions.com (info.stackoverflowsolutions.com)... 104.17.72.206, 104.17.70.206, 104.17.73.206, ...
# Connecting to info.stackoverflowsolutions.com (info.stackoverflowsolutions.com)|104.17.72.206|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8825103 (8.4M) [application/zip]
# Saving to: ‘tmp.zip’
#
# tmp.zip             100%[===================>]   8.42M  28.9MB/s    in 0.3s
#
# 2022-03-10 13:21:03 (28.9 MB/s) - ‘tmp.zip’ saved [8825103/8825103]
#
# Archive:  tmp.zip
#   inflating: ./data/README_2021.txt
#   inflating: ./data/so_survey_2021.pdf
#   inflating: ./data/survey_results_public.csv
#   inflating: ./data/survey_results_schema.csv

# %% [markdown]
# ## Imports and Constants

# %%
import pandas as pd
import numpy as np

# %%
DATA_PATH = '/content/data/survey_results_public.csv'
SCHEMA_PATH = '/content/data/survey_results_schema.csv'

# %% [markdown]
# ## Load the data into a DataFrame

# %% [markdown]
# A **dataframe** is a tablular representation of data, i.e. rows and columns of data.

# %%
df = pd.read_csv(DATA_PATH)
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# 2                                     Student, full-time
# 3                                     Employed full-time
# 4      Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                                                  Country    US_State  \
# 0                                               Slovakia         NaN
# 1                                            Netherlands         NaN
# 2                                     Russian Federation         NaN
# 3                                                Austria         NaN
# 4      United Kingdom of Great Britain and Northern I...         NaN
# ...                                                  ...         ...
# 83434                           United States of America       Texas
# 83435                                              Benin         NaN
# 83436                           United States of America  New Jersey
# 83437                                             Canada         NaN
# 83438                                             Brazil         NaN
#
#       UK_Country                                            EdLevel  \
# 0            NaN  Secondary school (e.g. American high school, G...
# 1            NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2            NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3            NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4        England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...          ...                                                ...
# 83434        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83435        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436        NaN  Secondary school (e.g. American high school, G...
# 83437        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83438        NaN                 Professional degree (JD, MD, etc.)
#
#           Age1stCode                                          LearnCode  \
# 0      18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 1      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 2      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3      11 - 17 years                                                NaN
# 4       5 - 10 years                            Friend or family member
# ...              ...                                                ...
# 83434  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83435  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436  11 - 17 years                                             School
# 83437  11 - 17 years  Online Courses or Certification;Books / Physic...
# 83438  11 - 17 years                                             School
#
#       YearsCode  ...              Age Gender Trans                Sexuality  \
# 0           NaN  ...  25-34 years old    Man    No  Straight / Heterosexual
# 1             7  ...  18-24 years old    Man    No  Straight / Heterosexual
# 2           NaN  ...  18-24 years old    Man    No        Prefer not to say
# 3           NaN  ...  35-44 years old    Man    No  Straight / Heterosexual
# 4            17  ...  25-34 years old    Man    No                      NaN
# ...         ...  ...              ...    ...   ...                      ...
# 83434         6  ...  25-34 years old    Man    No  Straight / Heterosexual
# 83435         4  ...  18-24 years old    Man    No  Straight / Heterosexual
# 83436        10  ...  25-34 years old    Man    No                      NaN
# 83437         5  ...  25-34 years old    Man    No  Straight / Heterosexual
# 83438        14  ...  18-24 years old    Man    No  Straight / Heterosexual
#
#                           Ethnicity                Accessibility  \
# 0      White or of European descent            None of the above
# 1      White or of European descent            None of the above
# 2                 Prefer not to say            None of the above
# 3      White or of European descent  I am deaf / hard of hearing
# 4      White or of European descent            None of the above
# ...                             ...                          ...
# 83434  White or of European descent            None of the above
# 83435   Black or of African descent            None of the above
# 83436  White or of European descent            None of the above
# 83437  White or of European descent            None of the above
# 83438        Hispanic or Latino/a/x            None of the above
#
#                                             MentalHealth  \
# 0                                      None of the above
# 1                                      None of the above
# 2                                      None of the above
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
#
#                 SurveyLength                  SurveyEase ConvertedCompYearly
# 0      Appropriate in length                        Easy             62268.0
# 1      Appropriate in length                        Easy                 NaN
# 2      Appropriate in length                        Easy                 NaN
# 3      Appropriate in length  Neither easy nor difficult                 NaN
# 4      Appropriate in length                        Easy                 NaN
# ...                      ...                         ...                 ...
# 83434  Appropriate in length                        Easy            160500.0
# 83435  Appropriate in length                        Easy              3960.0
# 83436  Appropriate in length  Neither easy nor difficult             90000.0
# 83437  Appropriate in length  Neither easy nor difficult            816816.0
# 83438  Appropriate in length                        Easy             21168.0
#
# [83439 rows x 48 columns]

# %%
# (num_rows, num_cols)
df.shape
# Out:
# (83439, 48)

# %%
# With `.info()` you see the column names as well as their type and whether they have any missing entries.
# The type `object` usually refers to string.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
#  12  OrgSize                       60726 non-null  object
#  13  Currency                      61080 non-null  object
#  14  CompTotal                     47183 non-null  float64
#  15  CompFreq                      52150 non-null  object
#  16  LanguageHaveWorkedWith        82357 non-null  object
#  17  LanguageWantToWorkWith        76821 non-null  object
#  18  DatabaseHaveWorkedWith        69546 non-null  object
#  19  DatabaseWantToWorkWith        58299 non-null  object
#  20  PlatformHaveWorkedWith        52135 non-null  object
#  21  PlatformWantToWorkWith        41619 non-null  object
#  22  WebframeHaveWorkedWith        61707 non-null  object
#  23  WebframeWantToWorkWith        52095 non-null  object
#  24  MiscTechHaveWorkedWith        47055 non-null  object
#  25  MiscTechWantToWorkWith        38021 non-null  object
#  26  ToolsTechHaveWorkedWith       72537 non-null  object
#  27  ToolsTechWantToWorkWith       65480 non-null  object
#  28  NEWCollabToolsHaveWorkedWith  81234 non-null  object
#  29  NEWCollabToolsWantToWorkWith  73022 non-null  object
#  30  OpSys                         83294 non-null  object
#  31  NEWStuck                      83052 non-null  object
#  32  NEWSOSites                    83171 non-null  object
#  33  SOVisitFreq                   82413 non-null  object
#  34  SOAccount                     82525 non-null  object
#  35  SOPartFreq                    67553 non-null  object
#  36  SOComm                        82319 non-null  object
#  37  NEWOtherComms                 82828 non-null  object
#  38  Age                           82407 non-null  object
#  39  Gender                        82286 non-null  object
#  40  Trans                         80678 non-null  object
#  41  Sexuality                     73366 non-null  object
#  42  Ethnicity                     79464 non-null  object
#  43  Accessibility                 77603 non-null  object
#  44  MentalHealth                  76920 non-null  object
#  45  SurveyLength                  81711 non-null  object
#  46  SurveyEase                    81948 non-null  object
#  47  ConvertedCompYearly           46844 non-null  float64
# dtypes: float64(2), int64(1), object(45)
# memory usage: 30.6+ MB

# %%
pd.set_option('display.max_columns', df.shape[1])
# pd.set_option('display.max_rows', df.shape[0]) # In case you want to see all rows
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# 2                                     Student, full-time
# 3                                     Employed full-time
# 4      Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                                                  Country    US_State  \
# 0                                               Slovakia         NaN
# 1                                            Netherlands         NaN
# 2                                     Russian Federation         NaN
# 3                                                Austria         NaN
# 4      United Kingdom of Great Britain and Northern I...         NaN
# ...                                                  ...         ...
# 83434                           United States of America       Texas
# 83435                                              Benin         NaN
# 83436                           United States of America  New Jersey
# 83437                                             Canada         NaN
# 83438                                             Brazil         NaN
#
#       UK_Country                                            EdLevel  \
# 0            NaN  Secondary school (e.g. American high school, G...
# 1            NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2            NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3            NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4        England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...          ...                                                ...
# 83434        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83435        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436        NaN  Secondary school (e.g. American high school, G...
# 83437        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83438        NaN                 Professional degree (JD, MD, etc.)
#
#           Age1stCode                                          LearnCode  \
# 0      18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 1      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 2      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3      11 - 17 years                                                NaN
# 4       5 - 10 years                            Friend or family member
# ...              ...                                                ...
# 83434  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83435  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436  11 - 17 years                                             School
# 83437  11 - 17 years  Online Courses or Certification;Books / Physic...
# 83438  11 - 17 years                                             School
#
#       YearsCode YearsCodePro  \
# 0           NaN          NaN
# 1             7          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4            17           10
# ...         ...          ...
# 83434         6            5
# 83435         4            2
# 83436        10            4
# 83437         5            3
# 83438        14            4
#
#                                                  DevType  \
# 0                                      Developer, mobile
# 1                                                    NaN
# 2                                                    NaN
# 3                                   Developer, front-end
# 4      Developer, desktop or enterprise applications;...
# ...                                                  ...
# 83434                                Developer, back-end
# 83435                              Developer, full-stack
# 83436  Data scientist or machine learning specialist;...
# 83437                                Developer, back-end
# 83438  Developer, front-end;Developer, full-stack;Dev...
#
#                                                  OrgSize  \
# 0                                     20 to 99 employees
# 1                                                    NaN
# 2                                                    NaN
# 3                                   100 to 499 employees
# 4      Just me - I am a freelancer, sole proprietor, ...
# ...                                                  ...
# 83434                                 20 to 99 employees
# 83435  Just me - I am a freelancer, sole proprietor, ...
# 83436                           10,000 or more employees
# 83437                                 20 to 99 employees
# 83438                                       I don’t know
#
#                           Currency  CompTotal CompFreq  \
# 0                EUR European Euro     4800.0  Monthly
# 1                              NaN        NaN      NaN
# 2                              NaN        NaN      NaN
# 3                EUR European Euro        NaN  Monthly
# 4              GBP\tPound sterling        NaN      NaN
# ...                            ...        ...      ...
# 83434    USD\tUnited States dollar   160500.0   Yearly
# 83435  XOF\tWest African CFA franc   200000.0  Monthly
# 83436    USD\tUnited States dollar     1800.0   Weekly
# 83437         CAD\tCanadian dollar    90000.0  Monthly
# 83438          BRL\tBrazilian real     7700.0  Monthly
#
#                               LanguageHaveWorkedWith  \
# 0      C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1                                  JavaScript;Python
# 2                           Assembly;C;Python;R;Rust
# 3                              JavaScript;TypeScript
# 4                     Bash/Shell;HTML/CSS;Python;SQL
# ...                                              ...
# 83434                             Clojure;Kotlin;SQL
# 83435                                            NaN
# 83436                             Groovy;Java;Python
# 83437           Bash/Shell;JavaScript;Node.js;Python
# 83438         Delphi;Elixir;HTML/CSS;Java;JavaScript
#
#                                   LanguageWantToWorkWith  \
# 0                                                  Swift
# 1                                                    NaN
# 2                                      Julia;Python;Rust
# 3                                  JavaScript;TypeScript
# 4                         Bash/Shell;HTML/CSS;Python;SQL
# ...                                                  ...
# 83434                                            Clojure
# 83435                                                NaN
# 83436                                        Java;Python
# 83437                                            Go;Rust
# 83438  Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
#
#                                  DatabaseHaveWorkedWith  \
# 0                                     PostgreSQL;SQLite
# 1                                            PostgreSQL
# 2                                                SQLite
# 3                                                   NaN
# 4                        Elasticsearch;PostgreSQL;Redis
# ...                                                 ...
# 83434                                     Oracle;SQLite
# 83435    Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83436   DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83437  Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438                                 Oracle;PostgreSQL
#
#                                   DatabaseWantToWorkWith  \
# 0                                                 SQLite
# 1                                                    NaN
# 2                                                 SQLite
# 3                                                    NaN
# 4               Cassandra;Elasticsearch;PostgreSQL;Redis
# ...                                                  ...
# 83434                                             SQLite
# 83435  Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83436                                     DynamoDB;Redis
# 83437                                                NaN
# 83438  Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
#
#           PlatformHaveWorkedWith PlatformWantToWorkWith  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                         Heroku                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
# ...                          ...                    ...
# 83434                        AWS                    AWS
# 83435                        NaN                    NaN
# 83436  AWS;Google Cloud Platform                    AWS
# 83437                     Heroku       AWS;DigitalOcean
# 83438            Microsoft Azure                    AWS
#
#                              WebframeHaveWorkedWith  \
# 0                                   Laravel;Symfony
# 1                              Angular;Flask;Vue.js
# 2                                             Flask
# 3                                    Angular;jQuery
# 4                                             Flask
# ...                                             ...
# 83434                                           NaN
# 83435  Django;jQuery;Laravel;React.js;Ruby on Rails
# 83436                                 FastAPI;Flask
# 83437                 Django;Express;Flask;React.js
# 83438                                Angular;Spring
#
#                                   WebframeWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                  Flask
# 3                                         Angular;jQuery
# 4                                                  Flask
# ...                                                  ...
# 83434                                                NaN
# 83435  Django;Express;jQuery;Laravel;React.js;Ruby on...
# 83436                                      FastAPI;Flask
# 83437                                                NaN
# 83438                     Express;Laravel;Spring;Symfony
#
#                       MiscTechHaveWorkedWith  \
# 0                                        NaN
# 1                                    Cordova
# 2      NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                        NaN
# 4           Apache Spark;Hadoop;NumPy;Pandas
# ...                                      ...
# 83434                                    NaN
# 83435                             Flutter;Qt
# 83436              Hadoop;Keras;NumPy;Pandas
# 83437  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                    NaN
#
#                                   MiscTechWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2            Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                                    NaN
# 4                                    Hadoop;NumPy;Pandas
# ...                                                  ...
# 83434                                                NaN
# 83435                                                NaN
# 83436  Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83437              NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                                NaN
#
#             ToolsTechHaveWorkedWith          ToolsTechWantToWorkWith  \
# 0                               NaN                              NaN
# 1                   Docker;Git;Yarn                              Git
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4        Docker;Git;Kubernetes;Yarn       Docker;Git;Kubernetes;Yarn
# ...                             ...                              ...
# 83434                    Docker;Git                   Git;Kubernetes
# 83435    Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83436  Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83437  Ansible;Docker;Git;Terraform             Kubernetes;Terraform
# 83438                    Docker;Git            Docker;Git;Kubernetes
#
#                             NEWCollabToolsHaveWorkedWith  \
# 0                                         PHPStorm;Xcode
# 1              Android Studio;IntelliJ;Notepad++;PyCharm
# 2      IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                    NaN
# 4             Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# ...                                                  ...
# 83434       IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83435  Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83436  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83437                               PyCharm;Sublime Text
# 83438                        IntelliJ;Visual Studio Code
#
#                             NEWCollabToolsWantToWorkWith        OpSys  \
# 0                                             Atom;Xcode        MacOS
# 1                                                    NaN      Windows
# 2      IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                    NaN      Windows
# 4      Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# ...                                                  ...          ...
# 83434                                   Sublime Text;Vim        MacOS
# 83435  Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83436             IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83437                                                NaN        MacOS
# 83438               IntelliJ;PHPStorm;Visual Studio Code  Linux-based
#
#                                                 NEWStuck  \
# 0      Call a coworker or friend;Visit Stack Overflow...
# 1                         Visit Stack Overflow;Google it
# 2      Visit Stack Overflow;Google it;Watch help / tu...
# 3      Call a coworker or friend;Visit Stack Overflow...
# 4      Visit Stack Overflow;Go for a walk or other ph...
# ...                                                  ...
# 83434                Call a coworker or friend;Google it
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
# 83438  Call a coworker or friend;Visit Stack Overflow...
#
#                                               NEWSOSites  \
# 0                                         Stack Overflow
# 1                                         Stack Overflow
# 2                          Stack Overflow;Stack Exchange
# 3                                         Stack Overflow
# 4                          Stack Overflow;Stack Exchange
# ...                                                  ...
# 83434                      Stack Overflow;Stack Exchange
# 83435                      Stack Overflow;Stack Exchange
# 83436                      Stack Overflow;Stack Exchange
# 83437                                     Stack Overflow
# 83438  Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                            SOVisitFreq SOAccount  \
# 0               Multiple times per day       Yes
# 1                Daily or almost daily       Yes
# 2               Multiple times per day       Yes
# 3                Daily or almost daily       Yes
# 4                Daily or almost daily       Yes
# ...                                ...       ...
# 83434             A few times per week        No
# 83435           Multiple times per day       Yes
# 83436             A few times per week       Yes
# 83437  A few times per month or weekly       Yes
# 83438             A few times per week       Yes
#
#                                               SOPartFreq           SOComm  \
# 0                        A few times per month or weekly  Yes, definitely
# 1                                  Daily or almost daily  Yes, definitely
# 2                                 Multiple times per day  Yes, definitely
# 3                                  Daily or almost daily          Neutral
# 4                                   A few times per week    Yes, somewhat
# ...                                                  ...              ...
# 83434                                                NaN   No, not at all
# 83435  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 83436  I have never participated in Q&A on Stack Over...   No, not really
# 83437                Less than once per month or monthly   No, not really
# 83438                               A few times per week    Yes, somewhat
#
#       NEWOtherComms              Age Gender Trans                Sexuality  \
# 0                No  25-34 years old    Man    No  Straight / Heterosexual
# 1                No  18-24 years old    Man    No  Straight / Heterosexual
# 2               Yes  18-24 years old    Man    No        Prefer not to say
# 3                No  35-44 years old    Man    No  Straight / Heterosexual
# 4                No  25-34 years old    Man    No                      NaN
# ...             ...              ...    ...   ...                      ...
# 83434            No  25-34 years old    Man    No  Straight / Heterosexual
# 83435            No  18-24 years old    Man    No  Straight / Heterosexual
# 83436            No  25-34 years old    Man    No                      NaN
# 83437            No  25-34 years old    Man    No  Straight / Heterosexual
# 83438            No  18-24 years old    Man    No  Straight / Heterosexual
#
#                           Ethnicity                Accessibility  \
# 0      White or of European descent            None of the above
# 1      White or of European descent            None of the above
# 2                 Prefer not to say            None of the above
# 3      White or of European descent  I am deaf / hard of hearing
# 4      White or of European descent            None of the above
# ...                             ...                          ...
# 83434  White or of European descent            None of the above
# 83435   Black or of African descent            None of the above
# 83436  White or of European descent            None of the above
# 83437  White or of European descent            None of the above
# 83438        Hispanic or Latino/a/x            None of the above
#
#                                             MentalHealth  \
# 0                                      None of the above
# 1                                      None of the above
# 2                                      None of the above
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
#
#                 SurveyLength                  SurveyEase  ConvertedCompYearly
# 0      Appropriate in length                        Easy              62268.0
# 1      Appropriate in length                        Easy                  NaN
# 2      Appropriate in length                        Easy                  NaN
# 3      Appropriate in length  Neither easy nor difficult                  NaN
# 4      Appropriate in length                        Easy                  NaN
# ...                      ...                         ...                  ...
# 83434  Appropriate in length                        Easy             160500.0
# 83435  Appropriate in length                        Easy               3960.0
# 83436  Appropriate in length  Neither easy nor difficult              90000.0
# 83437  Appropriate in length  Neither easy nor difficult             816816.0
# 83438  Appropriate in length                        Easy              21168.0
#
# [83439 rows x 48 columns]

# %%
# In order to see what question each of these columns refer to, we need to load the schema.
schema_df = pd.read_csv(SCHEMA_PATH)
schema_df
# Out:
#        qid               qname  \
# 0    QID16                  S0
# 1    QID12            MetaInfo
# 2     QID1                  S1
# 3     QID2          MainBranch
# 4    QID24          Employment
# 5     QID6             Country
# 6     QID7            US_State
# 7     QID9          UK_Country
# 8   QID190                  S2
# 9    QID25             EdLevel
# 10  QID149          Age1stCode
# 11  QID276           LearnCode
# 12   QID32           YearsCode
# 13   QID34        YearsCodePro
# 14   QID31             DevType
# 15   QID29             OrgSize
# 16   QID50            Currency
# 17   QID51           CompTotal
# 18   QID52            CompFreq
# 19   QID61                  S3
# 20  QID233            Language
# 21  QID262            Database
# 22  QID263            Platform
# 23  QID264            Webframe
# 24  QID265            MiscTech
# 25  QID275           ToolsTech
# 26  QID274      NEWCollabTools
# 27   QID71               OpSys
# 28  QID243            NEWStuck
# 29   QID91                  S4
# 30  QID266          NEWSOSites
# 31  QID100         SOVisitFreq
# 32  QID101           SOAccount
# 33  QID102          SOPartFreq
# 34  QID106              SOComm
# 35  QID267       NEWOtherComms
# 36  QID268  NEWOtherCommsNames
# 37  QID121                  S5
# 38  QID127                 Age
# 39  QID122              Gender
# 40  QID153               Trans
# 41  QID136           Sexuality
# 42  QID126           Ethnicity
# 43  QID124       Accessibility
# 44  QID125        MentalHealth
# 45  QID131                  S6
# 46  QID132        SurveyLength
# 47  QID133          SurveyEase
#
#                                              question  force_resp    type  \
# 0   <div><span style="font-size:19px;"><strong>Hel...       False      DB
# 1                                   Browser Meta Info       False    Meta
# 2   <span style="font-size:22px; font-family: aria...       False      DB
# 3   Which of the following options best describes ...        True      MC
# 4   Which of the following best describes your cur...       False      MC
# 5   Where do you live? <span style="font-weight: b...        True      MC
# 6   <p>In which state or territory of the USA do y...       False      MC
# 7   In which part of the United Kingdom do you liv...       False      MC
# 8   <span style="font-size:22px; font-family: aria...       False      DB
# 9   Which of the following best describes the high...       False      MC
# 10  At what age did you write your first line of c...       False      MC
# 11  How did you learn to code? Select all that apply.       False      MC
# 12  Including any education, how many years have y...       False      MC
# 13  NOT including education, how many years have y...       False      MC
# 14  Which of the following describes your current ...       False      MC
# 15  Approximately how many people are employed by ...       False      MC
# 16  Which currency do you use day-to-day? If your ...        True      MC
# 17  What is your current total compensation (salar...       False      TE
# 18   Is that compensation weekly, monthly, or yearly?       False      MC
# 19  <span style="font-size:22px; font-family: aria...       False      DB
# 20  Which <b>programming, scripting, and markup la...       False  Matrix
# 21  Which <b>database environments </b>have you do...       False  Matrix
# 22  Which <b>cloud platforms</b> have you done ext...       False  Matrix
# 23  Which <strong>web frameworks </strong><span st...       False  Matrix
# 24  Which <b>other frameworks and libraries</b> ha...       False  Matrix
# 25  Which <strong>tools</strong> have you done ext...       False  Matrix
# 26  Which <strong>development environments</strong...       False  Matrix
# 27  What is the primary operating system in which ...       False      MC
# 28  What do you do when you get stuck on a problem...       False      MC
# 29  <span style="font-size:22px; font-family: aria...       False      DB
# 30  Which of the following Stack Overflow sites ha...       False      MC
# 31  How frequently would you say you visit Stack O...       False      MC
# 32              Do you have a Stack Overflow account?       False      MC
# 33  How frequently would you say you participate i...       False      MC
# 34  Do you consider yourself a member of the Stack...       False      MC
# 35  Are you a member of any other online developer...       False      MC
# 36  Please name up to 5 other online developer com...       False  Matrix
# 37  <span style="font-size:22px; font-family: aria...       False      DB
# 38                                  What is your age?       False      MC
# 39  Which of the following describe you, if any? P...       False      MC
# 40                    Do you identify as transgender?       False      MC
# 41  Which of the following describe you, if any? P...       False      MC
# 42  Which of the following describe you, if any? P...       False      MC
# 43  Which of the following describe you, if any? P...       False      MC
# 44  Which of the following describe you, if any? P...       False      MC
# 45  <span style="font-size:22px;"><strong>Final Qu...       False      DB
# 46  How do you feel about the length of the survey...       False      MC
# 47  How easy or difficult was this survey to compl...       False      MC
#
#    selector
# 0        TB
# 1   Browser
# 2        TB
# 3      SAVR
# 4      MAVR
# 5        DL
# 6        DL
# 7        DL
# 8        TB
# 9      SAVR
# 10     MAVR
# 11     MAVR
# 12       DL
# 13       DL
# 14     MAVR
# 15     MAVR
# 16       SB
# 17       SL
# 18     MAVR
# 19       TB
# 20   Likert
# 21   Likert
# 22   Likert
# 23   Likert
# 24   Likert
# 25   Likert
# 26   Likert
# 27     SAVR
# 28     MAVR
# 29       TB
# 30     MAVR
# 31     MAVR
# 32     MAVR
# 33     MAVR
# 34     MAVR
# 35     MAVR
# 36   Likert
# 37       TB
# 38     MAVR
# 39     MAVR
# 40     MAVR
# 41     MAVR
# 42     MAVR
# 43     MAVR
# 44     MAVR
# 45       TB
# 46     MAVR
# 47     MAVR

# %%
# See the first 5 rows
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# 2                                 Russian Federation      NaN        NaN
# 3                                            Austria      NaN        NaN
# 4  United Kingdom of Great Britain and Northern I...      NaN    England
#
#                                              EdLevel     Age1stCode  \
# 0  Secondary school (e.g. American high school, G...  18 - 24 years
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 2       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 3    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
# 4    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   5 - 10 years
#
#                                            LearnCode YearsCode YearsCodePro  \
# 0  Coding Bootcamp;Other online resources (ex: vi...       NaN          NaN
# 1  Other online resources (ex: videos, blogs, etc...         7          NaN
# 2  Other online resources (ex: videos, blogs, etc...       NaN          NaN
# 3                                                NaN       NaN          NaN
# 4                            Friend or family member        17           10
#
#                                              DevType  \
# 0                                  Developer, mobile
# 1                                                NaN
# 2                                                NaN
# 3                               Developer, front-end
# 4  Developer, desktop or enterprise applications;...
#
#                                              OrgSize             Currency  \
# 0                                 20 to 99 employees    EUR European Euro
# 1                                                NaN                  NaN
# 2                                                NaN                  NaN
# 3                               100 to 499 employees    EUR European Euro
# 4  Just me - I am a freelancer, sole proprietor, ...  GBP\tPound sterling
#
#    CompTotal CompFreq                         LanguageHaveWorkedWith  \
# 0     4800.0  Monthly  C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1        NaN      NaN                              JavaScript;Python
# 2        NaN      NaN                       Assembly;C;Python;R;Rust
# 3        NaN  Monthly                          JavaScript;TypeScript
# 4        NaN      NaN                 Bash/Shell;HTML/CSS;Python;SQL
#
#            LanguageWantToWorkWith          DatabaseHaveWorkedWith  \
# 0                           Swift               PostgreSQL;SQLite
# 1                             NaN                      PostgreSQL
# 2               Julia;Python;Rust                          SQLite
# 3           JavaScript;TypeScript                             NaN
# 4  Bash/Shell;HTML/CSS;Python;SQL  Elasticsearch;PostgreSQL;Redis
#
#                      DatabaseWantToWorkWith PlatformHaveWorkedWith  \
# 0                                    SQLite                    NaN
# 1                                       NaN                    NaN
# 2                                    SQLite                 Heroku
# 3                                       NaN                    NaN
# 4  Cassandra;Elasticsearch;PostgreSQL;Redis                    NaN
#
#   PlatformWantToWorkWith WebframeHaveWorkedWith WebframeWantToWorkWith  \
# 0                    NaN        Laravel;Symfony                    NaN
# 1                    NaN   Angular;Flask;Vue.js                    NaN
# 2                    NaN                  Flask                  Flask
# 3                    NaN         Angular;jQuery         Angular;jQuery
# 4                    NaN                  Flask                  Flask
#
#                   MiscTechHaveWorkedWith  \
# 0                                    NaN
# 1                                Cordova
# 2  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                    NaN
# 4       Apache Spark;Hadoop;NumPy;Pandas
#
#                         MiscTechWantToWorkWith     ToolsTechHaveWorkedWith  \
# 0                                          NaN                         NaN
# 1                                          NaN             Docker;Git;Yarn
# 2  Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch                         NaN
# 3                                          NaN                         NaN
# 4                          Hadoop;NumPy;Pandas  Docker;Git;Kubernetes;Yarn
#
#       ToolsTechWantToWorkWith  \
# 0                         NaN
# 1                         Git
# 2                         NaN
# 3                         NaN
# 4  Docker;Git;Kubernetes;Yarn
#
#                         NEWCollabToolsHaveWorkedWith  \
# 0                                     PHPStorm;Xcode
# 1          Android Studio;IntelliJ;Notepad++;PyCharm
# 2  IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                NaN
# 4         Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
#
#                         NEWCollabToolsWantToWorkWith        OpSys  \
# 0                                         Atom;Xcode        MacOS
# 1                                                NaN      Windows
# 2  IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                NaN      Windows
# 4  Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
#
#                                             NEWStuck  \
# 0  Call a coworker or friend;Visit Stack Overflow...
# 1                     Visit Stack Overflow;Google it
# 2  Visit Stack Overflow;Google it;Watch help / tu...
# 3  Call a coworker or friend;Visit Stack Overflow...
# 4  Visit Stack Overflow;Go for a walk or other ph...
#
#                       NEWSOSites             SOVisitFreq SOAccount  \
# 0                 Stack Overflow  Multiple times per day       Yes
# 1                 Stack Overflow   Daily or almost daily       Yes
# 2  Stack Overflow;Stack Exchange  Multiple times per day       Yes
# 3                 Stack Overflow   Daily or almost daily       Yes
# 4  Stack Overflow;Stack Exchange   Daily or almost daily       Yes
#
#                         SOPartFreq           SOComm NEWOtherComms  \
# 0  A few times per month or weekly  Yes, definitely            No
# 1            Daily or almost daily  Yes, definitely            No
# 2           Multiple times per day  Yes, definitely           Yes
# 3            Daily or almost daily          Neutral            No
# 4             A few times per week    Yes, somewhat            No
#
#                Age Gender Trans                Sexuality  \
# 0  25-34 years old    Man    No  Straight / Heterosexual
# 1  18-24 years old    Man    No  Straight / Heterosexual
# 2  18-24 years old    Man    No        Prefer not to say
# 3  35-44 years old    Man    No  Straight / Heterosexual
# 4  25-34 years old    Man    No                      NaN
#
#                       Ethnicity                Accessibility  \
# 0  White or of European descent            None of the above
# 1  White or of European descent            None of the above
# 2             Prefer not to say            None of the above
# 3  White or of European descent  I am deaf / hard of hearing
# 4  White or of European descent            None of the above
#
#         MentalHealth           SurveyLength                  SurveyEase  \
# 0  None of the above  Appropriate in length                        Easy
# 1  None of the above  Appropriate in length                        Easy
# 2  None of the above  Appropriate in length                        Easy
# 3                NaN  Appropriate in length  Neither easy nor difficult
# 4                NaN  Appropriate in length                        Easy
#
#    ConvertedCompYearly
# 0              62268.0
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
# See the first n rows
df.head(10)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
# 5           6             I am a student who is learning to code
# 6           7                        I code primarily as a hobby
# 7           8             I am a student who is learning to code
# 8           9                     I am a developer by profession
# 9          10                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
# 5                                 Student, part-time
# 6                                I prefer not to say
# 7                                 Student, full-time
# 8                                 Employed part-time
# 9                                 Employed full-time
#
#                                              Country       US_State  \
# 0                                           Slovakia            NaN
# 1                                        Netherlands            NaN
# 2                                 Russian Federation            NaN
# 3                                            Austria            NaN
# 4  United Kingdom of Great Britain and Northern I...            NaN
# 5                           United States of America        Georgia
# 6                           United States of America  New Hampshire
# 7                                           Malaysia            NaN
# 8                                              India            NaN
# 9                                             Sweden            NaN
#
#   UK_Country                                            EdLevel  \
# 0        NaN  Secondary school (e.g. American high school, G...
# 1        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4    England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 6        NaN  Secondary school (e.g. American high school, G...
# 7        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 8        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 9        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#       Age1stCode                                          LearnCode YearsCode  \
# 0  18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...       NaN
# 1  11 - 17 years  Other online resources (ex: videos, blogs, etc...         7
# 2  11 - 17 years  Other online resources (ex: videos, blogs, etc...       NaN
# 3  11 - 17 years                                                NaN       NaN
# 4   5 - 10 years                            Friend or family member        17
# 5  11 - 17 years  Other online resources (ex: videos, blogs, etc...       NaN
# 6  11 - 17 years  Other online resources (ex: videos, blogs, etc...         3
# 7  11 - 17 years             School;Online Courses or Certification         4
# 8  18 - 24 years                                    Coding Bootcamp         6
# 9  11 - 17 years                                             School         7
#
#   YearsCodePro                                            DevType  \
# 0          NaN                                  Developer, mobile
# 1          NaN                                                NaN
# 2          NaN                                                NaN
# 3          NaN                               Developer, front-end
# 4           10  Developer, desktop or enterprise applications;...
# 5          NaN                                                NaN
# 6          NaN                                                NaN
# 7          NaN                                                NaN
# 8            4                               Developer, front-end
# 9            4      Data scientist or machine learning specialist
#
#                                              OrgSize             Currency  \
# 0                                 20 to 99 employees    EUR European Euro
# 1                                                NaN                  NaN
# 2                                                NaN                  NaN
# 3                               100 to 499 employees    EUR European Euro
# 4  Just me - I am a freelancer, sole proprietor, ...  GBP\tPound sterling
# 5                                                NaN                  NaN
# 6                                                NaN                  NaN
# 7                                                NaN                  NaN
# 8                           10,000 or more employees    INR\tIndian rupee
# 9                                 10 to 19 employees   SEK\tSwedish krona
#
#    CompTotal CompFreq                             LanguageHaveWorkedWith  \
# 0     4800.0  Monthly      C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1        NaN      NaN                                  JavaScript;Python
# 2        NaN      NaN                           Assembly;C;Python;R;Rust
# 3        NaN  Monthly                              JavaScript;TypeScript
# 4        NaN      NaN                     Bash/Shell;HTML/CSS;Python;SQL
# 5        NaN      NaN  C;C#;C++;HTML/CSS;Java;JavaScript;Node.js;Powe...
# 6        NaN      NaN                                HTML/CSS;JavaScript
# 7        NaN      NaN        HTML/CSS;JavaScript;PHP;Ruby;SQL;TypeScript
# 8        NaN  Monthly                                HTML/CSS;JavaScript
# 9    42000.0  Monthly                                         C++;Python
#
#                               LanguageWantToWorkWith  \
# 0                                              Swift
# 1                                                NaN
# 2                                  Julia;Python;Rust
# 3                              JavaScript;TypeScript
# 4                     Bash/Shell;HTML/CSS;Python;SQL
# 5  C#;C++;Go;HTML/CSS;Java;JavaScript;Node.js;Obj...
# 6                            HTML/CSS;JavaScript;PHP
# 7                                               Ruby
# 8                                HTML/CSS;JavaScript
# 9                                     Haskell;Python
#
#            DatabaseHaveWorkedWith  \
# 0               PostgreSQL;SQLite
# 1                      PostgreSQL
# 2                          SQLite
# 3                             NaN
# 4  Elasticsearch;PostgreSQL;Redis
# 5         MySQL;PostgreSQL;SQLite
# 6                             NaN
# 7         MySQL;PostgreSQL;SQLite
# 8                      PostgreSQL
# 9                      PostgreSQL
#
#                               DatabaseWantToWorkWith  PlatformHaveWorkedWith  \
# 0                                             SQLite                     NaN
# 1                                                NaN                     NaN
# 2                                             SQLite                  Heroku
# 3                                                NaN                     NaN
# 4           Cassandra;Elasticsearch;PostgreSQL;Redis                     NaN
# 5  Elasticsearch;Firebase;IBM DB2;MariaDB;Microso...                     NaN
# 6                                                NaN                     NaN
# 7                                         PostgreSQL  Heroku;Microsoft Azure
# 8                                         PostgreSQL                     AWS
# 9                                                NaN                     NaN
#
#   PlatformWantToWorkWith           WebframeHaveWorkedWith  \
# 0                    NaN                  Laravel;Symfony
# 1                    NaN             Angular;Flask;Vue.js
# 2                    NaN                            Flask
# 3                    NaN                   Angular;jQuery
# 4                    NaN                            Flask
# 5                    NaN    Express;Flask;jQuery;React.js
# 6                    NaN                           jQuery
# 7                 Heroku  Angular.js;jQuery;Ruby on Rails
# 8                    NaN                   Django;FastAPI
# 9                    NaN                              NaN
#
#           WebframeWantToWorkWith                       MiscTechHaveWorkedWith  \
# 0                            NaN                                          NaN
# 1                            NaN                                      Cordova
# 2                          Flask        NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                 Angular;jQuery                                          NaN
# 4                          Flask             Apache Spark;Hadoop;NumPy;Pandas
# 5  Express;Flask;jQuery;React.js  Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 6                         jQuery                                          NaN
# 7                  Ruby on Rails                                          NaN
# 8                 Django;FastAPI                                          NaN
# 9                            NaN  Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
#
#                               MiscTechWantToWorkWith  \
# 0                                                NaN
# 1                                                NaN
# 2        Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                                NaN
# 4                                Hadoop;NumPy;Pandas
# 5  Keras;NumPy;Pandas;Qt;React Native;TensorFlow;...
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9               Keras;NumPy;TensorFlow;Torch/PyTorch
#
#       ToolsTechHaveWorkedWith            ToolsTechWantToWorkWith  \
# 0                         NaN                                NaN
# 1             Docker;Git;Yarn                                Git
# 2                         NaN                                NaN
# 3                         NaN                                NaN
# 4  Docker;Git;Kubernetes;Yarn         Docker;Git;Kubernetes;Yarn
# 5                         Git  Docker;Git;Unity 3D;Unreal Engine
# 6                         NaN                                NaN
# 7                         NaN                                NaN
# 8                  Docker;Git              Docker;Git;Kubernetes
# 9                         Git                                Git
#
#                         NEWCollabToolsHaveWorkedWith  \
# 0                                     PHPStorm;Xcode
# 1          Android Studio;IntelliJ;Notepad++;PyCharm
# 2  IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                NaN
# 4         Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# 5  IPython/Jupyter;Notepad++;PyCharm;Sublime Text...
# 6                                                NaN
# 7                    Sublime Text;Visual Studio Code
# 8                               PyCharm;Sublime Text
# 9             IPython/Jupyter;Vim;Visual Studio Code
#
#                         NEWCollabToolsWantToWorkWith        OpSys  \
# 0                                         Atom;Xcode        MacOS
# 1                                                NaN      Windows
# 2  IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                NaN      Windows
# 4  Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# 5  Android Studio;IPython/Jupyter;Vim;Visual Stud...      Windows
# 6                                                NaN      Windows
# 7                    Sublime Text;Visual Studio Code  Linux-based
# 8                               PyCharm;Sublime Text      Windows
# 9       Emacs;IPython/Jupyter;Vim;Visual Studio Code  Linux-based
#
#                                             NEWStuck  \
# 0  Call a coworker or friend;Visit Stack Overflow...
# 1                     Visit Stack Overflow;Google it
# 2  Visit Stack Overflow;Google it;Watch help / tu...
# 3  Call a coworker or friend;Visit Stack Overflow...
# 4  Visit Stack Overflow;Go for a walk or other ph...
# 5  Visit Stack Overflow;Go for a walk or other ph...
# 6  Call a coworker or friend;Visit Stack Overflow...
# 7  Visit Stack Overflow;Go for a walk or other ph...
# 8               Visit Stack Overflow;Google it;Panic
# 9  Call a coworker or friend;Visit Stack Overflow...
#
#                       NEWSOSites             SOVisitFreq SOAccount  \
# 0                 Stack Overflow  Multiple times per day       Yes
# 1                 Stack Overflow   Daily or almost daily       Yes
# 2  Stack Overflow;Stack Exchange  Multiple times per day       Yes
# 3                 Stack Overflow   Daily or almost daily       Yes
# 4  Stack Overflow;Stack Exchange   Daily or almost daily       Yes
# 5  Stack Overflow;Stack Exchange  Multiple times per day       Yes
# 6                 Stack Overflow   Daily or almost daily       Yes
# 7  Stack Overflow;Stack Exchange  Multiple times per day       Yes
# 8  Stack Overflow;Stack Exchange    A few times per week       Yes
# 9  Stack Overflow;Stack Exchange  Multiple times per day       Yes
#
#                                           SOPartFreq           SOComm  \
# 0                    A few times per month or weekly  Yes, definitely
# 1                              Daily or almost daily  Yes, definitely
# 2                             Multiple times per day  Yes, definitely
# 3                              Daily or almost daily          Neutral
# 4                               A few times per week    Yes, somewhat
# 5  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 6                               A few times per week    Yes, somewhat
# 7  I have never participated in Q&A on Stack Over...   No, not at all
# 8                Less than once per month or monthly  Yes, definitely
# 9                              Daily or almost daily    Yes, somewhat
#
#   NEWOtherComms                Age             Gender Trans  \
# 0            No    25-34 years old                Man    No
# 1            No    18-24 years old                Man    No
# 2           Yes    18-24 years old                Man    No
# 3            No    35-44 years old                Man    No
# 4            No    25-34 years old                Man    No
# 5            No    18-24 years old  Prefer not to say    No
# 6            No  Prefer not to say  Prefer not to say    No
# 7           Yes    18-24 years old              Woman    No
# 8            No    25-34 years old                Man    No
# 9            No    25-34 years old                Man    No
#
#                  Sexuality                                          Ethnicity  \
# 0  Straight / Heterosexual                       White or of European descent
# 1  Straight / Heterosexual                       White or of European descent
# 2        Prefer not to say                                  Prefer not to say
# 3  Straight / Heterosexual                       White or of European descent
# 4                      NaN                       White or of European descent
# 5  Straight / Heterosexual                                  Prefer not to say
# 6                      NaN                                       I don't know
# 7  Straight / Heterosexual  White or of European descent;Multiracial;South...
# 8                      NaN                                        South Asian
# 9  Straight / Heterosexual                       White or of European descent
#
#                  Accessibility  \
# 0            None of the above
# 1            None of the above
# 2            None of the above
# 3  I am deaf / hard of hearing
# 4            None of the above
# 5            None of the above
# 6            None of the above
# 7            None of the above
# 8                          NaN
# 9            None of the above
#
#                                         MentalHealth           SurveyLength  \
# 0                                  None of the above  Appropriate in length
# 1                                  None of the above  Appropriate in length
# 2                                  None of the above  Appropriate in length
# 3                                                NaN  Appropriate in length
# 4                                                NaN  Appropriate in length
# 5  I have a concentration and/or memory disorder ...               Too long
# 6                                  None of the above  Appropriate in length
# 7                                  None of the above  Appropriate in length
# 8  I have a concentration and/or memory disorder ...  Appropriate in length
# 9                                  None of the above  Appropriate in length
#
#                    SurveyEase  ConvertedCompYearly
# 0                        Easy              62268.0
# 1                        Easy                  NaN
# 2                        Easy                  NaN
# 3  Neither easy nor difficult                  NaN
# 4                        Easy                  NaN
# 5  Neither easy nor difficult                  NaN
# 6  Neither easy nor difficult                  NaN
# 7                        Easy                  NaN
# 8                        Easy                  NaN
# 9  Neither easy nor difficult              51552.0

# %%
# See the last 5 rows
df.tail()
# Out:
#        ResponseId                      MainBranch  \
# 83434       83435  I am a developer by profession
# 83435       83436  I am a developer by profession
# 83436       83437  I am a developer by profession
# 83437       83438  I am a developer by profession
# 83438       83439  I am a developer by profession
#
#                                               Employment  \
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                         Country    US_State UK_Country  \
# 83434  United States of America       Texas        NaN
# 83435                     Benin         NaN        NaN
# 83436  United States of America  New Jersey        NaN
# 83437                    Canada         NaN        NaN
# 83438                    Brazil         NaN        NaN
#
#                                                  EdLevel     Age1stCode  \
# 83434       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83435       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83436  Secondary school (e.g. American high school, G...  11 - 17 years
# 83437       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83438                 Professional degree (JD, MD, etc.)  11 - 17 years
#
#                                                LearnCode YearsCode  \
# 83434  Other online resources (ex: videos, blogs, etc...         6
# 83435  Other online resources (ex: videos, blogs, etc...         4
# 83436                                             School        10
# 83437  Online Courses or Certification;Books / Physic...         5
# 83438                                             School        14
#
#       YearsCodePro                                            DevType  \
# 83434            5                                Developer, back-end
# 83435            2                              Developer, full-stack
# 83436            4  Data scientist or machine learning specialist;...
# 83437            3                                Developer, back-end
# 83438            4  Developer, front-end;Developer, full-stack;Dev...
#
#                                                  OrgSize  \
# 83434                                 20 to 99 employees
# 83435  Just me - I am a freelancer, sole proprietor, ...
# 83436                           10,000 or more employees
# 83437                                 20 to 99 employees
# 83438                                       I don’t know
#
#                           Currency  CompTotal CompFreq  \
# 83434    USD\tUnited States dollar   160500.0   Yearly
# 83435  XOF\tWest African CFA franc   200000.0  Monthly
# 83436    USD\tUnited States dollar     1800.0   Weekly
# 83437         CAD\tCanadian dollar    90000.0  Monthly
# 83438          BRL\tBrazilian real     7700.0  Monthly
#
#                        LanguageHaveWorkedWith  \
# 83434                      Clojure;Kotlin;SQL
# 83435                                     NaN
# 83436                      Groovy;Java;Python
# 83437    Bash/Shell;JavaScript;Node.js;Python
# 83438  Delphi;Elixir;HTML/CSS;Java;JavaScript
#
#                                   LanguageWantToWorkWith  \
# 83434                                            Clojure
# 83435                                                NaN
# 83436                                        Java;Python
# 83437                                            Go;Rust
# 83438  Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
#
#                                  DatabaseHaveWorkedWith  \
# 83434                                     Oracle;SQLite
# 83435    Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83436   DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83437  Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438                                 Oracle;PostgreSQL
#
#                                   DatabaseWantToWorkWith  \
# 83434                                             SQLite
# 83435  Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83436                                     DynamoDB;Redis
# 83437                                                NaN
# 83438  Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
#
#           PlatformHaveWorkedWith PlatformWantToWorkWith  \
# 83434                        AWS                    AWS
# 83435                        NaN                    NaN
# 83436  AWS;Google Cloud Platform                    AWS
# 83437                     Heroku       AWS;DigitalOcean
# 83438            Microsoft Azure                    AWS
#
#                              WebframeHaveWorkedWith  \
# 83434                                           NaN
# 83435  Django;jQuery;Laravel;React.js;Ruby on Rails
# 83436                                 FastAPI;Flask
# 83437                 Django;Express;Flask;React.js
# 83438                                Angular;Spring
#
#                                   WebframeWantToWorkWith  \
# 83434                                                NaN
# 83435  Django;Express;jQuery;Laravel;React.js;Ruby on...
# 83436                                      FastAPI;Flask
# 83437                                                NaN
# 83438                     Express;Laravel;Spring;Symfony
#
#                       MiscTechHaveWorkedWith  \
# 83434                                    NaN
# 83435                             Flutter;Qt
# 83436              Hadoop;Keras;NumPy;Pandas
# 83437  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                    NaN
#
#                                   MiscTechWantToWorkWith  \
# 83434                                                NaN
# 83435                                                NaN
# 83436  Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83437              NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                                NaN
#
#             ToolsTechHaveWorkedWith          ToolsTechWantToWorkWith  \
# 83434                    Docker;Git                   Git;Kubernetes
# 83435    Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83436  Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83437  Ansible;Docker;Git;Terraform             Kubernetes;Terraform
# 83438                    Docker;Git            Docker;Git;Kubernetes
#
#                             NEWCollabToolsHaveWorkedWith  \
# 83434       IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83435  Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83436  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83437                               PyCharm;Sublime Text
# 83438                        IntelliJ;Visual Studio Code
#
#                             NEWCollabToolsWantToWorkWith        OpSys  \
# 83434                                   Sublime Text;Vim        MacOS
# 83435  Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83436             IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83437                                                NaN        MacOS
# 83438               IntelliJ;PHPStorm;Visual Studio Code  Linux-based
#
#                                                 NEWStuck  \
# 83434                Call a coworker or friend;Google it
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
# 83438  Call a coworker or friend;Visit Stack Overflow...
#
#                                               NEWSOSites  \
# 83434                      Stack Overflow;Stack Exchange
# 83435                      Stack Overflow;Stack Exchange
# 83436                      Stack Overflow;Stack Exchange
# 83437                                     Stack Overflow
# 83438  Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                            SOVisitFreq SOAccount  \
# 83434             A few times per week        No
# 83435           Multiple times per day       Yes
# 83436             A few times per week       Yes
# 83437  A few times per month or weekly       Yes
# 83438             A few times per week       Yes
#
#                                               SOPartFreq          SOComm  \
# 83434                                                NaN  No, not at all
# 83435  I have never participated in Q&A on Stack Over...   Yes, somewhat
# 83436  I have never participated in Q&A on Stack Over...  No, not really
# 83437                Less than once per month or monthly  No, not really
# 83438                               A few times per week   Yes, somewhat
#
#       NEWOtherComms              Age Gender Trans                Sexuality  \
# 83434            No  25-34 years old    Man    No  Straight / Heterosexual
# 83435            No  18-24 years old    Man    No  Straight / Heterosexual
# 83436            No  25-34 years old    Man    No                      NaN
# 83437            No  25-34 years old    Man    No  Straight / Heterosexual
# 83438            No  18-24 years old    Man    No  Straight / Heterosexual
#
#                           Ethnicity      Accessibility  \
# 83434  White or of European descent  None of the above
# 83435   Black or of African descent  None of the above
# 83436  White or of European descent  None of the above
# 83437  White or of European descent  None of the above
# 83438        Hispanic or Latino/a/x  None of the above
#
#                                             MentalHealth  \
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
#
#                 SurveyLength                  SurveyEase  ConvertedCompYearly
# 83434  Appropriate in length                        Easy             160500.0
# 83435  Appropriate in length                        Easy               3960.0
# 83436  Appropriate in length  Neither easy nor difficult              90000.0
# 83437  Appropriate in length  Neither easy nor difficult             816816.0
# 83438  Appropriate in length                        Easy              21168.0

# %%
# See the last 10 rows
df.tail(10)
# Out:
#        ResponseId                      MainBranch  \
# 83429       83430     I code primarily as a hobby
# 83430       83431  I am a developer by profession
# 83431       83432  I am a developer by profession
# 83432       83433  I am a developer by profession
# 83433       83434  I am a developer by profession
# 83434       83435  I am a developer by profession
# 83435       83436  I am a developer by profession
# 83436       83437  I am a developer by profession
# 83437       83438  I am a developer by profession
# 83438       83439  I am a developer by profession
#
#                                               Employment  \
# 83429                 Not employed, but looking for work
# 83430                                 Employed full-time
# 83431  Independent contractor, freelancer, or self-em...
# 83432                                 Employed full-time
# 83433  Independent contractor, freelancer, or self-em...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                         Country    US_State UK_Country  \
# 83429  United States of America  Washington        NaN
# 83430  United States of America    Illinois        NaN
# 83431                  Pakistan         NaN        NaN
# 83432                    Canada         NaN        NaN
# 83433                    Brazil         NaN        NaN
# 83434  United States of America       Texas        NaN
# 83435                     Benin         NaN        NaN
# 83436  United States of America  New Jersey        NaN
# 83437                    Canada         NaN        NaN
# 83438                    Brazil         NaN        NaN
#
#                                                  EdLevel     Age1stCode  \
# 83429       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# 83430    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
# 83431       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83432       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# 83433       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# 83434       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83435       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83436  Secondary school (e.g. American high school, G...  11 - 17 years
# 83437       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83438                 Professional degree (JD, MD, etc.)  11 - 17 years
#
#                                                LearnCode YearsCode  \
# 83429    Other online resources (ex: videos, blogs, etc)         6
# 83430  Other online resources (ex: videos, blogs, etc...        23
# 83431  Other online resources (ex: videos, blogs, etc...         9
# 83432                                             School         5
# 83433  Online Forum;Online Courses or Certification;O...        15
# 83434  Other online resources (ex: videos, blogs, etc...         6
# 83435  Other online resources (ex: videos, blogs, etc...         4
# 83436                                             School        10
# 83437  Online Courses or Certification;Books / Physic...         5
# 83438                                             School        14
#
#            YearsCodePro                                            DevType  \
# 83429               NaN                    Other (please specify):;Student
# 83430                21  Developer, front-end;Developer, full-stack;Dev...
# 83431                 4  Developer, mobile;Developer, desktop or enterp...
# 83432  Less than 1 year                                Developer, back-end
# 83433                11  Developer, mobile;Developer, front-end;Develop...
# 83434                 5                                Developer, back-end
# 83435                 2                              Developer, full-stack
# 83436                 4  Data scientist or machine learning specialist;...
# 83437                 3                                Developer, back-end
# 83438                 4  Developer, front-end;Developer, full-stack;Dev...
#
#                                                  OrgSize  \
# 83429                                                NaN
# 83430                                 10 to 19 employees
# 83431                                   2 to 9 employees
# 83432                           10,000 or more employees
# 83433                           1,000 to 4,999 employees
# 83434                                 20 to 99 employees
# 83435  Just me - I am a freelancer, sole proprietor, ...
# 83436                           10,000 or more employees
# 83437                                 20 to 99 employees
# 83438                                       I don’t know
#
#                           Currency  CompTotal CompFreq  \
# 83429                          NaN        NaN      NaN
# 83430    USD\tUnited States dollar   125000.0   Yearly
# 83431         PKR\tPakistani rupee   150000.0  Monthly
# 83432         CAD\tCanadian dollar   106000.0   Yearly
# 83433          BRL\tBrazilian real    80000.0   Yearly
# 83434    USD\tUnited States dollar   160500.0   Yearly
# 83435  XOF\tWest African CFA franc   200000.0  Monthly
# 83436    USD\tUnited States dollar     1800.0   Weekly
# 83437         CAD\tCanadian dollar    90000.0  Monthly
# 83438          BRL\tBrazilian real     7700.0  Monthly
#
#                                   LanguageHaveWorkedWith  \
# 83429             HTML/CSS;PHP;PowerShell;Python;SQL;VBA
# 83430        APL;Clojure;LISP;Python;Ruby;SQL;TypeScript
# 83431  C#;Dart;HTML/CSS;Java;JavaScript;Kotlin;Node.j...
# 83432                                               Ruby
# 83433      Java;JavaScript;Kotlin;Objective-C;TypeScript
# 83434                                 Clojure;Kotlin;SQL
# 83435                                                NaN
# 83436                                 Groovy;Java;Python
# 83437               Bash/Shell;JavaScript;Node.js;Python
# 83438             Delphi;Elixir;HTML/CSS;Java;JavaScript
#
#                                   LanguageWantToWorkWith  \
# 83429  C#;Go;HTML/CSS;Java;JavaScript;PHP;Python;SQL;VBA
# 83430                         APL;Clojure;Haskell;LISP;R
# 83431  C#;Dart;HTML/CSS;JavaScript;Kotlin;Node.js;Pyt...
# 83432                               Java;Ruby;TypeScript
# 83433                                             Kotlin
# 83434                                            Clojure
# 83435                                                NaN
# 83436                                        Java;Python
# 83437                                            Go;Rust
# 83438  Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
#
#                                  DatabaseHaveWorkedWith  \
# 83429                          MongoDB;MySQL;PostgreSQL
# 83430                    MongoDB;MySQL;PostgreSQL;Redis
# 83431                             Firebase;MySQL;SQLite
# 83432                                  MySQL;PostgreSQL
# 83433                     Firebase;MongoDB;MySQL;SQLite
# 83434                                     Oracle;SQLite
# 83435    Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83436   DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83437  Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438                                 Oracle;PostgreSQL
#
#                                   DatabaseWantToWorkWith  \
# 83429  MariaDB;Microsoft SQL Server;MongoDB;MySQL;Pos...
# 83430                                         PostgreSQL
# 83431             DynamoDB;Firebase;MongoDB;MySQL;SQLite
# 83432                                                NaN
# 83433                                                NaN
# 83434                                             SQLite
# 83435  Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83436                                     DynamoDB;Redis
# 83437                                                NaN
# 83438  Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
#
#                               PlatformHaveWorkedWith  \
# 83429                                         Heroku
# 83430  AWS;DigitalOcean;Google Cloud Platform;Heroku
# 83431                          Google Cloud Platform
# 83432                   Google Cloud Platform;Heroku
# 83433                                            NaN
# 83434                                            AWS
# 83435                                            NaN
# 83436                      AWS;Google Cloud Platform
# 83437                                         Heroku
# 83438                                Microsoft Azure
#
#                                   PlatformWantToWorkWith  \
# 83429  AWS;Heroku;IBM Cloud or Watson;Microsoft Azure...
# 83430             AWS;DigitalOcean;Google Cloud Platform
# 83431                          AWS;Google Cloud Platform
# 83432                                                NaN
# 83433                                                NaN
# 83434                                                AWS
# 83435                                                NaN
# 83436                                                AWS
# 83437                                   AWS;DigitalOcean
# 83438                                                AWS
#
#                              WebframeHaveWorkedWith  \
# 83429                           Django;Flask;jQuery
# 83430                 Django;React.js;Ruby on Rails
# 83431                                  Flask;jQuery
# 83432           Flask;React.js;Ruby on Rails;Vue.js
# 83433                                      React.js
# 83434                                           NaN
# 83435  Django;jQuery;Laravel;React.js;Ruby on Rails
# 83436                                 FastAPI;Flask
# 83437                 Django;Express;Flask;React.js
# 83438                                Angular;Spring
#
#                                   WebframeWantToWorkWith  \
# 83429  Angular.js;ASP.NET;ASP.NET Core ;Django;FastAP...
# 83430                                                NaN
# 83431                Angular;Django;Flask;jQuery;Laravel
# 83432                                                NaN
# 83433                                                NaN
# 83434                                                NaN
# 83435  Django;Express;jQuery;Laravel;React.js;Ruby on...
# 83436                                      FastAPI;Flask
# 83437                                                NaN
# 83438                     Express;Laravel;Spring;Symfony
#
#                       MiscTechHaveWorkedWith  \
# 83429                           NumPy;Pandas
# 83430                                    NaN
# 83431                                Flutter
# 83432  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83433                           React Native
# 83434                                    NaN
# 83435                             Flutter;Qt
# 83436              Hadoop;Keras;NumPy;Pandas
# 83437  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                    NaN
#
#                                   MiscTechWantToWorkWith  \
# 83429     .NET Framework;.NET Core / .NET 5;NumPy;Pandas
# 83430                                                NaN
# 83431      Flutter;Hadoop;NumPy;TensorFlow;Torch/PyTorch
# 83432                                                NaN
# 83433                                            Flutter
# 83434                                                NaN
# 83435                                                NaN
# 83436  Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83437              NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                                NaN
#
#             ToolsTechHaveWorkedWith          ToolsTechWantToWorkWith  \
# 83429                           Git               Docker;Git;Xamarin
# 83430                    Docker;Git   Docker;Git;Kubernetes;Unity 3D
# 83431                           Git                       Docker;Git
# 83432    Docker;Git;Kubernetes;Yarn                              NaN
# 83433               Docker;Git;Yarn                       Docker;Git
# 83434                    Docker;Git                   Git;Kubernetes
# 83435    Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83436  Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83437  Ansible;Docker;Git;Terraform             Kubernetes;Terraform
# 83438                    Docker;Git            Docker;Git;Kubernetes
#
#                             NEWCollabToolsHaveWorkedWith  \
# 83429     Atom;Notepad++;Sublime Text;Visual Studio Code
# 83430                                          Emacs;Vim
# 83431  Android Studio;IntelliJ;IPython/Jupyter;Notepa...
# 83432        Atom;IPython/Jupyter;Vim;Visual Studio Code
# 83433            Android Studio;Visual Studio Code;Xcode
# 83434       IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83435  Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83436  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83437                               PyCharm;Sublime Text
# 83438                        IntelliJ;Visual Studio Code
#
#                             NEWCollabToolsWantToWorkWith        OpSys  \
# 83429     Atom;Notepad++;Sublime Text;Visual Studio Code      Windows
# 83430                                              Emacs  Linux-based
# 83431  Android Studio;IntelliJ;IPython/Jupyter;PyChar...      Windows
# 83432                                                NaN        MacOS
# 83433                               Android Studio;Xcode        MacOS
# 83434                                   Sublime Text;Vim        MacOS
# 83435  Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83436             IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83437                                                NaN        MacOS
# 83438               IntelliJ;PHPStorm;Visual Studio Code  Linux-based
#
#                                                 NEWStuck  \
# 83429  Visit Stack Overflow;Google it;Watch help / tu...
# 83430  Call a coworker or friend;Visit Stack Overflow...
# 83431  Visit Stack Overflow;Go for a walk or other ph...
# 83432  Visit Stack Overflow;Go for a walk or other ph...
# 83433  Call a coworker or friend;Visit Stack Overflow...
# 83434                Call a coworker or friend;Google it
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
# 83438  Call a coworker or friend;Visit Stack Overflow...
#
#                                               NEWSOSites  \
# 83429                      Stack Overflow;Stack Exchange
# 83430                      Stack Overflow;Stack Exchange
# 83431                      Stack Overflow;Stack Exchange
# 83432                      Stack Overflow;Stack Exchange
# 83433                                     Stack Overflow
# 83434                      Stack Overflow;Stack Exchange
# 83435                      Stack Overflow;Stack Exchange
# 83436                      Stack Overflow;Stack Exchange
# 83437                                     Stack Overflow
# 83438  Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                            SOVisitFreq                SOAccount  \
# 83429  A few times per month or weekly  Not sure/can't remember
# 83430             A few times per week                       No
# 83431           Multiple times per day                      Yes
# 83432            Daily or almost daily                       No
# 83433            Daily or almost daily                      Yes
# 83434             A few times per week                       No
# 83435           Multiple times per day                      Yes
# 83436             A few times per week                      Yes
# 83437  A few times per month or weekly                      Yes
# 83438             A few times per week                      Yes
#
#                                               SOPartFreq           SOComm  \
# 83429                                                NaN    Yes, somewhat
# 83430                                                NaN   No, not really
# 83431                    A few times per month or weekly  Yes, definitely
# 83432                                                NaN   No, not really
# 83433                    A few times per month or weekly    Yes, somewhat
# 83434                                                NaN   No, not at all
# 83435  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 83436  I have never participated in Q&A on Stack Over...   No, not really
# 83437                Less than once per month or monthly   No, not really
# 83438                               A few times per week    Yes, somewhat
#
#       NEWOtherComms              Age                      Gender Trans  \
# 83429            No  25-34 years old  Man;Or, in your own words:   Yes
# 83430            No  45-54 years old                         Man    No
# 83431            No  18-24 years old                         Man    No
# 83432            No  18-24 years old                       Woman    No
# 83433            No  25-34 years old                         Man    No
# 83434            No  25-34 years old                         Man    No
# 83435            No  18-24 years old                         Man    No
# 83436            No  25-34 years old                         Man    No
# 83437            No  25-34 years old                         Man    No
# 83438            No  18-24 years old                         Man    No
#
#                      Sexuality                     Ethnicity  \
# 83429                    Queer  White or of European descent
# 83430  Straight / Heterosexual  White or of European descent
# 83431  Straight / Heterosexual               Southeast Asian
# 83432  Straight / Heterosexual                    East Asian
# 83433  Straight / Heterosexual        Hispanic or Latino/a/x
# 83434  Straight / Heterosexual  White or of European descent
# 83435  Straight / Heterosexual   Black or of African descent
# 83436                      NaN  White or of European descent
# 83437  Straight / Heterosexual  White or of European descent
# 83438  Straight / Heterosexual        Hispanic or Latino/a/x
#
#                                            Accessibility  \
# 83429  I am unable to / find it difficult to walk or ...
# 83430                                  None of the above
# 83431                                  None of the above
# 83432                                  None of the above
# 83433                                  None of the above
# 83434                                  None of the above
# 83435                                  None of the above
# 83436                                  None of the above
# 83437                                  None of the above
# 83438                                  None of the above
#
#                                             MentalHealth  \
# 83429                         I have an anxiety disorder
# 83430                                  None of the above
# 83431                                  None of the above
# 83432                                  None of the above
# 83433                         I have an anxiety disorder
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
#
#                 SurveyLength                  SurveyEase  ConvertedCompYearly
# 83429  Appropriate in length  Neither easy nor difficult                  NaN
# 83430  Appropriate in length                        Easy             125000.0
# 83431  Appropriate in length                        Easy              11676.0
# 83432  Appropriate in length                        Easy              80169.0
# 83433  Appropriate in length                        Easy              18326.0
# 83434  Appropriate in length                        Easy             160500.0
# 83435  Appropriate in length                        Easy               3960.0
# 83436  Appropriate in length  Neither easy nor difficult              90000.0
# 83437  Appropriate in length  Neither easy nor difficult             816816.0
# 83438  Appropriate in length                        Easy              21168.0

# %% [markdown]
# ## Selecting Rows and Columns

# %% [markdown]
# If we wanted to store information about a person, we could use the following format.

# %%
person = {
    'first': 'SimoFirst',
    'last': 'SimoLast',
    'email': 's.e.hristov99@gmail.com'
}

# %% [markdown]
# However, we can't store information about multiple people. For that, we would need this approach.

# %%
people = {
    'first': ['SimoFirst', 'Jane', 'John'],
    'last': ['SimoLast', 'Doe', 'Doe'],
    'email': ['s.e.hristov99@gmail.com', 'JaneDoe@gmail.com', 'JohnDoe@gmail.com']
}

# %% [markdown]
# We can think of these as rows and columns. They keys are the columns and the values are the rows. Usually, the definition for a dataframe object in pandas is `two-dimensional data structure`. If that sounds confusing, think of it as multiple rows and columns.

# %%
# If we wanted to see the `email` column, we would access the `email` key in the `people` dictionary.
people['email']

# %%
# Let's create a dataframe from the `people` dictionary!
# Note: The left-most column is called an idex. Think of it as the primary key for a database table. More on that later.
ppl_df = pd.DataFrame(people)
ppl_df
# Out:
#        first      last                    email
# 0  SimoFirst  SimoLast  s.e.hristov99@gmail.com
# 1       Jane       Doe        JaneDoe@gmail.com
# 2       John       Doe        JohnDoe@gmail.com

# %%
# Get all the values in a column.
ppl_df['email'] # Same as ppl_df.email
# Out:
# 0    s.e.hristov99@gmail.com
# 1          JaneDoe@gmail.com
# 2          JohnDoe@gmail.com
# Name: email, dtype: object

# %%
# Note: The return type is actually a pandas.Series object. A Series is a list of data with more information and functionality. You can think of it as the values of a single column.
type(ppl_df['email'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# > **Conclusion**: We can then say that a DataFrame is a container for Series objects.

# %%
# Get the rows of multiple columns
ppl_df[['last', 'email']]
# Out:
#        last                    email
# 0  SimoLast  s.e.hristov99@gmail.com
# 1       Doe        JaneDoe@gmail.com
# 2       Doe        JohnDoe@gmail.com

# %%
# Note: The return type is not a Series. It's a new DataFrame.
type(ppl_df[['last', 'email']])
# Out:
# pandas.core.frame.DataFrame

# %%
# Get the names of all columns.
ppl_df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %% [markdown]
# In order to get specific rows, we use the:
# - **iloc** method: access rows by integer location, i.e. like indexing an array in C++.
# - **loc** method: access by the dataframe index index.

# %% [markdown]
# ### iloc

# %%
# It returns a Series with all the values for the 0th row.
ppl_df.iloc[0]
# Out:
# first                  SimoFirst
# last                    SimoLast
# email    s.e.hristov99@gmail.com
# Name: 0, dtype: object

# %%
# Get the values of n rows.
ppl_df.iloc[[0, -1]]
# Out:
#        first      last                    email
# 0  SimoFirst  SimoLast  s.e.hristov99@gmail.com
# 2       John       Doe        JohnDoe@gmail.com

# %%
# We can also get the values of a certain column.
ppl_df.iloc[[0, -1], -1]
# Out:
# 0    s.e.hristov99@gmail.com
# 2          JohnDoe@gmail.com
# Name: email, dtype: object

# %% [markdown]
# ### loc

# %%
# While the `iloc` method indexes the rows as intergers from 0 .. len - 1
# loc indexes the rows by the left-most column.
# Notice how there's no name above it.
ppl_df
# Out:
#        first      last                    email
# 0  SimoFirst  SimoLast  s.e.hristov99@gmail.com
# 1       Jane       Doe        JaneDoe@gmail.com
# 2       John       Doe        JohnDoe@gmail.com

# %%
ppl_df.loc[0]

# %%
ppl_df.loc[[0, 2]]
# Out:
#        first      last                    email
# 0  SimoFirst  SimoLast  s.e.hristov99@gmail.com
# 2       John       Doe        JohnDoe@gmail.com

# %%
ppl_df.loc[[0, 2], 'email']
# Out:
# 0    s.e.hristov99@gmail.com
# 2          JohnDoe@gmail.com
# Name: email, dtype: object

# %%
ppl_df.loc[[0, 2], ['email', 'first']]
# Out:
#                      email      first
# 0  s.e.hristov99@gmail.com  SimoFirst
# 2        JohnDoe@gmail.com       John

# %% [markdown]
# ### **Question**: How many people are there in each employment type?

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df['Employment']
# Out:
# 0        Independent contractor, freelancer, or self-em...
# 1                                       Student, full-time
# 2                                       Student, full-time
# 3                                       Employed full-time
# 4        Independent contractor, freelancer, or self-em...
#                                ...
# 83434                                   Employed full-time
# 83435    Independent contractor, freelancer, or self-em...
# 83436                                   Employed full-time
# 83437                                   Employed full-time
# 83438                                   Employed full-time
# Name: Employment, Length: 83439, dtype: object

# %%
df['Employment'].value_counts()
# Out:
# Employed full-time                                      53584
# Student, full-time                                      11781
# Independent contractor, freelancer, or self-employed     8041
# Not employed, but looking for work                       2961
# Employed part-time                                       2461
# Student, part-time                                       2051
# Not employed, and not looking for work                   1228
# I prefer not to say                                       890
# Retired                                                   326
# Name: Employment, dtype: int64

# %%
# Get the responce of the first person for the `employment` question.
df.loc[0, 'Employment']
# Out:
# 'Independent contractor, freelancer, or self-employed'

# %%
# Get the responce of the first three people for the `employment` question.
# via a list
df.loc[[0, 1, 2], 'Employment']
# Out:
# 0    Independent contractor, freelancer, or self-em...
# 1                                   Student, full-time
# 2                                   Student, full-time
# Name: Employment, dtype: object

# %%
# via slicing
# Note: The last element when using `loc` is inclusive.
df.loc[0:2, 'Employment']
# Out:
# 0    Independent contractor, freelancer, or self-em...
# 1                                   Student, full-time
# 2                                   Student, full-time
# Name: Employment, dtype: object

# %%
# Get the values of the first three respondents for the columns from `employment` to `edlevel`
df.loc[0:2, 'Employment':'EdLevel']
# Out:
#                                           Employment             Country  \
# 0  Independent contractor, freelancer, or self-em...            Slovakia
# 1                                 Student, full-time         Netherlands
# 2                                 Student, full-time  Russian Federation
#
#   US_State UK_Country                                            EdLevel
# 0      NaN        NaN  Secondary school (e.g. American high school, G...
# 1      NaN        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2      NaN        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)

# %% [markdown]
# ## Indexes - Set, Reset, and Use

# %%
ppl_df
# Out:
#        first      last                    email
# 0  SimoFirst  SimoLast  s.e.hristov99@gmail.com
# 1       Jane       Doe        JaneDoe@gmail.com
# 2       John       Doe        JohnDoe@gmail.com

# %%
ppl_df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
# Set the email addresses as an index.
ppl_df.set_index('email')
# Out:
#                              first      last
# email
# s.e.hristov99@gmail.com  SimoFirst  SimoLast
# JaneDoe@gmail.com             Jane       Doe
# JohnDoe@gmail.com             John       Doe

# %%
# Note: Our dataframe didn't actually change because `set_index` returns a new dataframe.
ppl_df
# Out:
#        first      last                    email
# 0  SimoFirst  SimoLast  s.e.hristov99@gmail.com
# 1       Jane       Doe        JaneDoe@gmail.com
# 2       John       Doe        JohnDoe@gmail.com

# %%
ppl_df = ppl_df.set_index('email') # Same as ppl_df.set_index('email', inplace=True)
ppl_df
# Out:
#                              first      last
# email
# s.e.hristov99@gmail.com  SimoFirst  SimoLast
# JaneDoe@gmail.com             Jane       Doe
# JohnDoe@gmail.com             John       Doe

# %%
ppl_df.index
# Out:
# Index(['s.e.hristov99@gmail.com', 'JaneDoe@gmail.com', 'JohnDoe@gmail.com'], dtype='object', name='email')

# %%
# Get the last name of Jane using `loc`
ppl_df.loc['JaneDoe@gmail.com', 'last']
# Out:
# 'Doe'

# %%
# Get the last name of Jane using `iloc`
ppl_df.iloc[1, 1]
# or: ppl_df.iloc[1, -1]
# Out:
# 'Doe'

# %%
# ppl_df.loc[0] # This will no longer work, since the index is now a string.
ppl_df.iloc[0]
# Out:
# first    SimoFirst
# last      SimoLast
# Name: s.e.hristov99@gmail.com, dtype: object

# %%
# Reset the idex.
ppl_df = ppl_df.reset_index()
ppl_df
# Out:
#                      email      first      last
# 0  s.e.hristov99@gmail.com  SimoFirst  SimoLast
# 1        JaneDoe@gmail.com       Jane       Doe
# 2        JohnDoe@gmail.com       John       Doe

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# 2                                     Student, full-time
# 3                                     Employed full-time
# 4      Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                                                  Country    US_State  \
# 0                                               Slovakia         NaN
# 1                                            Netherlands         NaN
# 2                                     Russian Federation         NaN
# 3                                                Austria         NaN
# 4      United Kingdom of Great Britain and Northern I...         NaN
# ...                                                  ...         ...
# 83434                           United States of America       Texas
# 83435                                              Benin         NaN
# 83436                           United States of America  New Jersey
# 83437                                             Canada         NaN
# 83438                                             Brazil         NaN
#
#       UK_Country                                            EdLevel  \
# 0            NaN  Secondary school (e.g. American high school, G...
# 1            NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2            NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3            NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4        England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...          ...                                                ...
# 83434        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83435        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436        NaN  Secondary school (e.g. American high school, G...
# 83437        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83438        NaN                 Professional degree (JD, MD, etc.)
#
#           Age1stCode                                          LearnCode  \
# 0      18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 1      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 2      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3      11 - 17 years                                                NaN
# 4       5 - 10 years                            Friend or family member
# ...              ...                                                ...
# 83434  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83435  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436  11 - 17 years                                             School
# 83437  11 - 17 years  Online Courses or Certification;Books / Physic...
# 83438  11 - 17 years                                             School
#
#       YearsCode YearsCodePro  \
# 0           NaN          NaN
# 1             7          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4            17           10
# ...         ...          ...
# 83434         6            5
# 83435         4            2
# 83436        10            4
# 83437         5            3
# 83438        14            4
#
#                                                  DevType  \
# 0                                      Developer, mobile
# 1                                                    NaN
# 2                                                    NaN
# 3                                   Developer, front-end
# 4      Developer, desktop or enterprise applications;...
# ...                                                  ...
# 83434                                Developer, back-end
# 83435                              Developer, full-stack
# 83436  Data scientist or machine learning specialist;...
# 83437                                Developer, back-end
# 83438  Developer, front-end;Developer, full-stack;Dev...
#
#                                                  OrgSize  \
# 0                                     20 to 99 employees
# 1                                                    NaN
# 2                                                    NaN
# 3                                   100 to 499 employees
# 4      Just me - I am a freelancer, sole proprietor, ...
# ...                                                  ...
# 83434                                 20 to 99 employees
# 83435  Just me - I am a freelancer, sole proprietor, ...
# 83436                           10,000 or more employees
# 83437                                 20 to 99 employees
# 83438                                       I don’t know
#
#                           Currency  CompTotal CompFreq  \
# 0                EUR European Euro     4800.0  Monthly
# 1                              NaN        NaN      NaN
# 2                              NaN        NaN      NaN
# 3                EUR European Euro        NaN  Monthly
# 4              GBP\tPound sterling        NaN      NaN
# ...                            ...        ...      ...
# 83434    USD\tUnited States dollar   160500.0   Yearly
# 83435  XOF\tWest African CFA franc   200000.0  Monthly
# 83436    USD\tUnited States dollar     1800.0   Weekly
# 83437         CAD\tCanadian dollar    90000.0  Monthly
# 83438          BRL\tBrazilian real     7700.0  Monthly
#
#                               LanguageHaveWorkedWith  \
# 0      C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1                                  JavaScript;Python
# 2                           Assembly;C;Python;R;Rust
# 3                              JavaScript;TypeScript
# 4                     Bash/Shell;HTML/CSS;Python;SQL
# ...                                              ...
# 83434                             Clojure;Kotlin;SQL
# 83435                                            NaN
# 83436                             Groovy;Java;Python
# 83437           Bash/Shell;JavaScript;Node.js;Python
# 83438         Delphi;Elixir;HTML/CSS;Java;JavaScript
#
#                                   LanguageWantToWorkWith  \
# 0                                                  Swift
# 1                                                    NaN
# 2                                      Julia;Python;Rust
# 3                                  JavaScript;TypeScript
# 4                         Bash/Shell;HTML/CSS;Python;SQL
# ...                                                  ...
# 83434                                            Clojure
# 83435                                                NaN
# 83436                                        Java;Python
# 83437                                            Go;Rust
# 83438  Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
#
#                                  DatabaseHaveWorkedWith  \
# 0                                     PostgreSQL;SQLite
# 1                                            PostgreSQL
# 2                                                SQLite
# 3                                                   NaN
# 4                        Elasticsearch;PostgreSQL;Redis
# ...                                                 ...
# 83434                                     Oracle;SQLite
# 83435    Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83436   DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83437  Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438                                 Oracle;PostgreSQL
#
#                                   DatabaseWantToWorkWith  \
# 0                                                 SQLite
# 1                                                    NaN
# 2                                                 SQLite
# 3                                                    NaN
# 4               Cassandra;Elasticsearch;PostgreSQL;Redis
# ...                                                  ...
# 83434                                             SQLite
# 83435  Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83436                                     DynamoDB;Redis
# 83437                                                NaN
# 83438  Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
#
#           PlatformHaveWorkedWith PlatformWantToWorkWith  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                         Heroku                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
# ...                          ...                    ...
# 83434                        AWS                    AWS
# 83435                        NaN                    NaN
# 83436  AWS;Google Cloud Platform                    AWS
# 83437                     Heroku       AWS;DigitalOcean
# 83438            Microsoft Azure                    AWS
#
#                              WebframeHaveWorkedWith  \
# 0                                   Laravel;Symfony
# 1                              Angular;Flask;Vue.js
# 2                                             Flask
# 3                                    Angular;jQuery
# 4                                             Flask
# ...                                             ...
# 83434                                           NaN
# 83435  Django;jQuery;Laravel;React.js;Ruby on Rails
# 83436                                 FastAPI;Flask
# 83437                 Django;Express;Flask;React.js
# 83438                                Angular;Spring
#
#                                   WebframeWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                  Flask
# 3                                         Angular;jQuery
# 4                                                  Flask
# ...                                                  ...
# 83434                                                NaN
# 83435  Django;Express;jQuery;Laravel;React.js;Ruby on...
# 83436                                      FastAPI;Flask
# 83437                                                NaN
# 83438                     Express;Laravel;Spring;Symfony
#
#                       MiscTechHaveWorkedWith  \
# 0                                        NaN
# 1                                    Cordova
# 2      NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                        NaN
# 4           Apache Spark;Hadoop;NumPy;Pandas
# ...                                      ...
# 83434                                    NaN
# 83435                             Flutter;Qt
# 83436              Hadoop;Keras;NumPy;Pandas
# 83437  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                    NaN
#
#                                   MiscTechWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2            Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                                    NaN
# 4                                    Hadoop;NumPy;Pandas
# ...                                                  ...
# 83434                                                NaN
# 83435                                                NaN
# 83436  Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83437              NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                                NaN
#
#             ToolsTechHaveWorkedWith          ToolsTechWantToWorkWith  \
# 0                               NaN                              NaN
# 1                   Docker;Git;Yarn                              Git
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4        Docker;Git;Kubernetes;Yarn       Docker;Git;Kubernetes;Yarn
# ...                             ...                              ...
# 83434                    Docker;Git                   Git;Kubernetes
# 83435    Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83436  Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83437  Ansible;Docker;Git;Terraform             Kubernetes;Terraform
# 83438                    Docker;Git            Docker;Git;Kubernetes
#
#                             NEWCollabToolsHaveWorkedWith  \
# 0                                         PHPStorm;Xcode
# 1              Android Studio;IntelliJ;Notepad++;PyCharm
# 2      IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                    NaN
# 4             Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# ...                                                  ...
# 83434       IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83435  Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83436  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83437                               PyCharm;Sublime Text
# 83438                        IntelliJ;Visual Studio Code
#
#                             NEWCollabToolsWantToWorkWith        OpSys  \
# 0                                             Atom;Xcode        MacOS
# 1                                                    NaN      Windows
# 2      IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                    NaN      Windows
# 4      Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# ...                                                  ...          ...
# 83434                                   Sublime Text;Vim        MacOS
# 83435  Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83436             IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83437                                                NaN        MacOS
# 83438               IntelliJ;PHPStorm;Visual Studio Code  Linux-based
#
#                                                 NEWStuck  \
# 0      Call a coworker or friend;Visit Stack Overflow...
# 1                         Visit Stack Overflow;Google it
# 2      Visit Stack Overflow;Google it;Watch help / tu...
# 3      Call a coworker or friend;Visit Stack Overflow...
# 4      Visit Stack Overflow;Go for a walk or other ph...
# ...                                                  ...
# 83434                Call a coworker or friend;Google it
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
# 83438  Call a coworker or friend;Visit Stack Overflow...
#
#                                               NEWSOSites  \
# 0                                         Stack Overflow
# 1                                         Stack Overflow
# 2                          Stack Overflow;Stack Exchange
# 3                                         Stack Overflow
# 4                          Stack Overflow;Stack Exchange
# ...                                                  ...
# 83434                      Stack Overflow;Stack Exchange
# 83435                      Stack Overflow;Stack Exchange
# 83436                      Stack Overflow;Stack Exchange
# 83437                                     Stack Overflow
# 83438  Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                            SOVisitFreq SOAccount  \
# 0               Multiple times per day       Yes
# 1                Daily or almost daily       Yes
# 2               Multiple times per day       Yes
# 3                Daily or almost daily       Yes
# 4                Daily or almost daily       Yes
# ...                                ...       ...
# 83434             A few times per week        No
# 83435           Multiple times per day       Yes
# 83436             A few times per week       Yes
# 83437  A few times per month or weekly       Yes
# 83438             A few times per week       Yes
#
#                                               SOPartFreq           SOComm  \
# 0                        A few times per month or weekly  Yes, definitely
# 1                                  Daily or almost daily  Yes, definitely
# 2                                 Multiple times per day  Yes, definitely
# 3                                  Daily or almost daily          Neutral
# 4                                   A few times per week    Yes, somewhat
# ...                                                  ...              ...
# 83434                                                NaN   No, not at all
# 83435  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 83436  I have never participated in Q&A on Stack Over...   No, not really
# 83437                Less than once per month or monthly   No, not really
# 83438                               A few times per week    Yes, somewhat
#
#       NEWOtherComms              Age Gender Trans                Sexuality  \
# 0                No  25-34 years old    Man    No  Straight / Heterosexual
# 1                No  18-24 years old    Man    No  Straight / Heterosexual
# 2               Yes  18-24 years old    Man    No        Prefer not to say
# 3                No  35-44 years old    Man    No  Straight / Heterosexual
# 4                No  25-34 years old    Man    No                      NaN
# ...             ...              ...    ...   ...                      ...
# 83434            No  25-34 years old    Man    No  Straight / Heterosexual
# 83435            No  18-24 years old    Man    No  Straight / Heterosexual
# 83436            No  25-34 years old    Man    No                      NaN
# 83437            No  25-34 years old    Man    No  Straight / Heterosexual
# 83438            No  18-24 years old    Man    No  Straight / Heterosexual
#
#                           Ethnicity                Accessibility  \
# 0      White or of European descent            None of the above
# 1      White or of European descent            None of the above
# 2                 Prefer not to say            None of the above
# 3      White or of European descent  I am deaf / hard of hearing
# 4      White or of European descent            None of the above
# ...                             ...                          ...
# 83434  White or of European descent            None of the above
# 83435   Black or of African descent            None of the above
# 83436  White or of European descent            None of the above
# 83437  White or of European descent            None of the above
# 83438        Hispanic or Latino/a/x            None of the above
#
#                                             MentalHealth  \
# 0                                      None of the above
# 1                                      None of the above
# 2                                      None of the above
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
#
#                 SurveyLength                  SurveyEase  ConvertedCompYearly
# 0      Appropriate in length                        Easy              62268.0
# 1      Appropriate in length                        Easy                  NaN
# 2      Appropriate in length                        Easy                  NaN
# 3      Appropriate in length  Neither easy nor difficult                  NaN
# 4      Appropriate in length                        Easy                  NaN
# ...                      ...                         ...                  ...
# 83434  Appropriate in length                        Easy             160500.0
# 83435  Appropriate in length                        Easy               3960.0
# 83436  Appropriate in length  Neither easy nor difficult              90000.0
# 83437  Appropriate in length  Neither easy nor difficult             816816.0
# 83438  Appropriate in length                        Easy              21168.0
#
# [83439 rows x 48 columns]

# %%
# Notice how the `ResponseId` column is a unique identifier.
# Set it as an index
df.set_index('ResponseId')
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
# 4                                          Employed full-time
# 5           Independent contractor, freelancer, or self-em...
# ...                                                       ...
# 83435                                      Employed full-time
# 83436       Independent contractor, freelancer, or self-em...
# 83437                                      Employed full-time
# 83438                                      Employed full-time
# 83439                                      Employed full-time
#
#                                                       Country    US_State  \
# ResponseId
# 1                                                    Slovakia         NaN
# 2                                                 Netherlands         NaN
# 3                                          Russian Federation         NaN
# 4                                                     Austria         NaN
# 5           United Kingdom of Great Britain and Northern I...         NaN
# ...                                                       ...         ...
# 83435                                United States of America       Texas
# 83436                                                   Benin         NaN
# 83437                                United States of America  New Jersey
# 83438                                                  Canada         NaN
# 83439                                                  Brazil         NaN
#
#            UK_Country                                            EdLevel  \
# ResponseId
# 1                 NaN  Secondary school (e.g. American high school, G...
# 2                 NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                 NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4                 NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5             England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...               ...                                                ...
# 83435             NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436             NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83437             NaN  Secondary school (e.g. American high school, G...
# 83438             NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83439             NaN                 Professional degree (JD, MD, etc.)
#
#                Age1stCode                                          LearnCode  \
# ResponseId
# 1           18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 2           11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3           11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 4           11 - 17 years                                                NaN
# 5            5 - 10 years                            Friend or family member
# ...                   ...                                                ...
# 83435       11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436       11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83437       11 - 17 years                                             School
# 83438       11 - 17 years  Online Courses or Certification;Books / Physic...
# 83439       11 - 17 years                                             School
#
#            YearsCode YearsCodePro  \
# ResponseId
# 1                NaN          NaN
# 2                  7          NaN
# 3                NaN          NaN
# 4                NaN          NaN
# 5                 17           10
# ...              ...          ...
# 83435              6            5
# 83436              4            2
# 83437             10            4
# 83438              5            3
# 83439             14            4
#
#                                                       DevType  \
# ResponseId
# 1                                           Developer, mobile
# 2                                                         NaN
# 3                                                         NaN
# 4                                        Developer, front-end
# 5           Developer, desktop or enterprise applications;...
# ...                                                       ...
# 83435                                     Developer, back-end
# 83436                                   Developer, full-stack
# 83437       Data scientist or machine learning specialist;...
# 83438                                     Developer, back-end
# 83439       Developer, front-end;Developer, full-stack;Dev...
#
#                                                       OrgSize  \
# ResponseId
# 1                                          20 to 99 employees
# 2                                                         NaN
# 3                                                         NaN
# 4                                        100 to 499 employees
# 5           Just me - I am a freelancer, sole proprietor, ...
# ...                                                       ...
# 83435                                      20 to 99 employees
# 83436       Just me - I am a freelancer, sole proprietor, ...
# 83437                                10,000 or more employees
# 83438                                      20 to 99 employees
# 83439                                            I don’t know
#
#                                Currency  CompTotal CompFreq  \
# ResponseId
# 1                     EUR European Euro     4800.0  Monthly
# 2                                   NaN        NaN      NaN
# 3                                   NaN        NaN      NaN
# 4                     EUR European Euro        NaN  Monthly
# 5                   GBP\tPound sterling        NaN      NaN
# ...                                 ...        ...      ...
# 83435         USD\tUnited States dollar   160500.0   Yearly
# 83436       XOF\tWest African CFA franc   200000.0  Monthly
# 83437         USD\tUnited States dollar     1800.0   Weekly
# 83438              CAD\tCanadian dollar    90000.0  Monthly
# 83439               BRL\tBrazilian real     7700.0  Monthly
#
#                                    LanguageHaveWorkedWith  \
# ResponseId
# 1           C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 2                                       JavaScript;Python
# 3                                Assembly;C;Python;R;Rust
# 4                                   JavaScript;TypeScript
# 5                          Bash/Shell;HTML/CSS;Python;SQL
# ...                                                   ...
# 83435                                  Clojure;Kotlin;SQL
# 83436                                                 NaN
# 83437                                  Groovy;Java;Python
# 83438                Bash/Shell;JavaScript;Node.js;Python
# 83439              Delphi;Elixir;HTML/CSS;Java;JavaScript
#
#                                        LanguageWantToWorkWith  \
# ResponseId
# 1                                                       Swift
# 2                                                         NaN
# 3                                           Julia;Python;Rust
# 4                                       JavaScript;TypeScript
# 5                              Bash/Shell;HTML/CSS;Python;SQL
# ...                                                       ...
# 83435                                                 Clojure
# 83436                                                     NaN
# 83437                                             Java;Python
# 83438                                                 Go;Rust
# 83439       Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
#
#                                       DatabaseHaveWorkedWith  \
# ResponseId
# 1                                          PostgreSQL;SQLite
# 2                                                 PostgreSQL
# 3                                                     SQLite
# 4                                                        NaN
# 5                             Elasticsearch;PostgreSQL;Redis
# ...                                                      ...
# 83435                                          Oracle;SQLite
# 83436         Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83437        DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438       Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83439                                      Oracle;PostgreSQL
#
#                                        DatabaseWantToWorkWith  \
# ResponseId
# 1                                                      SQLite
# 2                                                         NaN
# 3                                                      SQLite
# 4                                                         NaN
# 5                    Cassandra;Elasticsearch;PostgreSQL;Redis
# ...                                                       ...
# 83435                                                  SQLite
# 83436       Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83437                                          DynamoDB;Redis
# 83438                                                     NaN
# 83439       Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
#
#                PlatformHaveWorkedWith PlatformWantToWorkWith  \
# ResponseId
# 1                                 NaN                    NaN
# 2                                 NaN                    NaN
# 3                              Heroku                    NaN
# 4                                 NaN                    NaN
# 5                                 NaN                    NaN
# ...                               ...                    ...
# 83435                             AWS                    AWS
# 83436                             NaN                    NaN
# 83437       AWS;Google Cloud Platform                    AWS
# 83438                          Heroku       AWS;DigitalOcean
# 83439                 Microsoft Azure                    AWS
#
#                                   WebframeHaveWorkedWith  \
# ResponseId
# 1                                        Laravel;Symfony
# 2                                   Angular;Flask;Vue.js
# 3                                                  Flask
# 4                                         Angular;jQuery
# 5                                                  Flask
# ...                                                  ...
# 83435                                                NaN
# 83436       Django;jQuery;Laravel;React.js;Ruby on Rails
# 83437                                      FastAPI;Flask
# 83438                      Django;Express;Flask;React.js
# 83439                                     Angular;Spring
#
#                                        WebframeWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                                                       Flask
# 4                                              Angular;jQuery
# 5                                                       Flask
# ...                                                       ...
# 83435                                                     NaN
# 83436       Django;Express;jQuery;Laravel;React.js;Ruby on...
# 83437                                           FastAPI;Flask
# 83438                                                     NaN
# 83439                          Express;Laravel;Spring;Symfony
#
#                            MiscTechHaveWorkedWith  \
# ResponseId
# 1                                             NaN
# 2                                         Cordova
# 3           NumPy;Pandas;TensorFlow;Torch/PyTorch
# 4                                             NaN
# 5                Apache Spark;Hadoop;NumPy;Pandas
# ...                                           ...
# 83435                                         NaN
# 83436                                  Flutter;Qt
# 83437                   Hadoop;Keras;NumPy;Pandas
# 83438       NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83439                                         NaN
#
#                                        MiscTechWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                 Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 4                                                         NaN
# 5                                         Hadoop;NumPy;Pandas
# ...                                                       ...
# 83435                                                     NaN
# 83436                                                     NaN
# 83437       Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83438                   NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83439                                                     NaN
#
#                  ToolsTechHaveWorkedWith          ToolsTechWantToWorkWith  \
# ResponseId
# 1                                    NaN                              NaN
# 2                        Docker;Git;Yarn                              Git
# 3                                    NaN                              NaN
# 4                                    NaN                              NaN
# 5             Docker;Git;Kubernetes;Yarn       Docker;Git;Kubernetes;Yarn
# ...                                  ...                              ...
# 83435                         Docker;Git                   Git;Kubernetes
# 83436         Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83437       Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83438       Ansible;Docker;Git;Terraform             Kubernetes;Terraform
# 83439                         Docker;Git            Docker;Git;Kubernetes
#
#                                  NEWCollabToolsHaveWorkedWith  \
# ResponseId
# 1                                              PHPStorm;Xcode
# 2                   Android Studio;IntelliJ;Notepad++;PyCharm
# 3           IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 4                                                         NaN
# 5                  Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# ...                                                       ...
# 83435            IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83436       Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83437       Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83438                                    PyCharm;Sublime Text
# 83439                             IntelliJ;Visual Studio Code
#
#                                  NEWCollabToolsWantToWorkWith        OpSys  \
# ResponseId
# 1                                                  Atom;Xcode        MacOS
# 2                                                         NaN      Windows
# 3           IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 4                                                         NaN      Windows
# 5           Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# ...                                                       ...          ...
# 83435                                        Sublime Text;Vim        MacOS
# 83436       Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83437                  IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83438                                                     NaN        MacOS
# 83439                    IntelliJ;PHPStorm;Visual Studio Code  Linux-based
#
#                                                      NEWStuck  \
# ResponseId
# 1           Call a coworker or friend;Visit Stack Overflow...
# 2                              Visit Stack Overflow;Google it
# 3           Visit Stack Overflow;Google it;Watch help / tu...
# 4           Call a coworker or friend;Visit Stack Overflow...
# 5           Visit Stack Overflow;Go for a walk or other ph...
# ...                                                       ...
# 83435                     Call a coworker or friend;Google it
# 83436       Call a coworker or friend;Visit Stack Overflow...
# 83437       Call a coworker or friend;Visit Stack Overflow...
# 83438       Call a coworker or friend;Visit Stack Overflow...
# 83439       Call a coworker or friend;Visit Stack Overflow...
#
#                                                    NEWSOSites  \
# ResponseId
# 1                                              Stack Overflow
# 2                                              Stack Overflow
# 3                               Stack Overflow;Stack Exchange
# 4                                              Stack Overflow
# 5                               Stack Overflow;Stack Exchange
# ...                                                       ...
# 83435                           Stack Overflow;Stack Exchange
# 83436                           Stack Overflow;Stack Exchange
# 83437                           Stack Overflow;Stack Exchange
# 83438                                          Stack Overflow
# 83439       Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                                 SOVisitFreq SOAccount  \
# ResponseId
# 1                    Multiple times per day       Yes
# 2                     Daily or almost daily       Yes
# 3                    Multiple times per day       Yes
# 4                     Daily or almost daily       Yes
# 5                     Daily or almost daily       Yes
# ...                                     ...       ...
# 83435                  A few times per week        No
# 83436                Multiple times per day       Yes
# 83437                  A few times per week       Yes
# 83438       A few times per month or weekly       Yes
# 83439                  A few times per week       Yes
#
#                                                    SOPartFreq  \
# ResponseId
# 1                             A few times per month or weekly
# 2                                       Daily or almost daily
# 3                                      Multiple times per day
# 4                                       Daily or almost daily
# 5                                        A few times per week
# ...                                                       ...
# 83435                                                     NaN
# 83436       I have never participated in Q&A on Stack Over...
# 83437       I have never participated in Q&A on Stack Over...
# 83438                     Less than once per month or monthly
# 83439                                    A few times per week
#
#                      SOComm NEWOtherComms              Age Gender Trans  \
# ResponseId
# 1           Yes, definitely            No  25-34 years old    Man    No
# 2           Yes, definitely            No  18-24 years old    Man    No
# 3           Yes, definitely           Yes  18-24 years old    Man    No
# 4                   Neutral            No  35-44 years old    Man    No
# 5             Yes, somewhat            No  25-34 years old    Man    No
# ...                     ...           ...              ...    ...   ...
# 83435        No, not at all            No  25-34 years old    Man    No
# 83436         Yes, somewhat            No  18-24 years old    Man    No
# 83437        No, not really            No  25-34 years old    Man    No
# 83438        No, not really            No  25-34 years old    Man    No
# 83439         Yes, somewhat            No  18-24 years old    Man    No
#
#                           Sexuality                     Ethnicity  \
# ResponseId
# 1           Straight / Heterosexual  White or of European descent
# 2           Straight / Heterosexual  White or of European descent
# 3                 Prefer not to say             Prefer not to say
# 4           Straight / Heterosexual  White or of European descent
# 5                               NaN  White or of European descent
# ...                             ...                           ...
# 83435       Straight / Heterosexual  White or of European descent
# 83436       Straight / Heterosexual   Black or of African descent
# 83437                           NaN  White or of European descent
# 83438       Straight / Heterosexual  White or of European descent
# 83439       Straight / Heterosexual        Hispanic or Latino/a/x
#
#                           Accessibility  \
# ResponseId
# 1                     None of the above
# 2                     None of the above
# 3                     None of the above
# 4           I am deaf / hard of hearing
# 5                     None of the above
# ...                                 ...
# 83435                 None of the above
# 83436                 None of the above
# 83437                 None of the above
# 83438                 None of the above
# 83439                 None of the above
#
#                                                  MentalHealth  \
# ResponseId
# 1                                           None of the above
# 2                                           None of the above
# 3                                           None of the above
# 4                                                         NaN
# 5                                                         NaN
# ...                                                       ...
# 83435       I have a concentration and/or memory disorder ...
# 83436                                       None of the above
# 83437                                       None of the above
# 83438       I have a mood or emotional disorder (e.g. depr...
# 83439                                       None of the above
#
#                      SurveyLength                  SurveyEase  \
# ResponseId
# 1           Appropriate in length                        Easy
# 2           Appropriate in length                        Easy
# 3           Appropriate in length                        Easy
# 4           Appropriate in length  Neither easy nor difficult
# 5           Appropriate in length                        Easy
# ...                           ...                         ...
# 83435       Appropriate in length                        Easy
# 83436       Appropriate in length                        Easy
# 83437       Appropriate in length  Neither easy nor difficult
# 83438       Appropriate in length  Neither easy nor difficult
# 83439       Appropriate in length                        Easy
#
#             ConvertedCompYearly
# ResponseId
# 1                       62268.0
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# ...                         ...
# 83435                  160500.0
# 83436                    3960.0
# 83437                   90000.0
# 83438                  816816.0
# 83439                   21168.0
#
# [83439 rows x 47 columns]

# %%
# Set it as an index while loading in the data!
df = pd.read_csv(DATA_PATH, index_col='ResponseId')
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
# 4                                          Employed full-time
# 5           Independent contractor, freelancer, or self-em...
# ...                                                       ...
# 83435                                      Employed full-time
# 83436       Independent contractor, freelancer, or self-em...
# 83437                                      Employed full-time
# 83438                                      Employed full-time
# 83439                                      Employed full-time
#
#                                                       Country    US_State  \
# ResponseId
# 1                                                    Slovakia         NaN
# 2                                                 Netherlands         NaN
# 3                                          Russian Federation         NaN
# 4                                                     Austria         NaN
# 5           United Kingdom of Great Britain and Northern I...         NaN
# ...                                                       ...         ...
# 83435                                United States of America       Texas
# 83436                                                   Benin         NaN
# 83437                                United States of America  New Jersey
# 83438                                                  Canada         NaN
# 83439                                                  Brazil         NaN
#
#            UK_Country                                            EdLevel  \
# ResponseId
# 1                 NaN  Secondary school (e.g. American high school, G...
# 2                 NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                 NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4                 NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5             England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...               ...                                                ...
# 83435             NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436             NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83437             NaN  Secondary school (e.g. American high school, G...
# 83438             NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83439             NaN                 Professional degree (JD, MD, etc.)
#
#                Age1stCode                                          LearnCode  \
# ResponseId
# 1           18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 2           11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3           11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 4           11 - 17 years                                                NaN
# 5            5 - 10 years                            Friend or family member
# ...                   ...                                                ...
# 83435       11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436       11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83437       11 - 17 years                                             School
# 83438       11 - 17 years  Online Courses or Certification;Books / Physic...
# 83439       11 - 17 years                                             School
#
#            YearsCode YearsCodePro  \
# ResponseId
# 1                NaN          NaN
# 2                  7          NaN
# 3                NaN          NaN
# 4                NaN          NaN
# 5                 17           10
# ...              ...          ...
# 83435              6            5
# 83436              4            2
# 83437             10            4
# 83438              5            3
# 83439             14            4
#
#                                                       DevType  \
# ResponseId
# 1                                           Developer, mobile
# 2                                                         NaN
# 3                                                         NaN
# 4                                        Developer, front-end
# 5           Developer, desktop or enterprise applications;...
# ...                                                       ...
# 83435                                     Developer, back-end
# 83436                                   Developer, full-stack
# 83437       Data scientist or machine learning specialist;...
# 83438                                     Developer, back-end
# 83439       Developer, front-end;Developer, full-stack;Dev...
#
#                                                       OrgSize  \
# ResponseId
# 1                                          20 to 99 employees
# 2                                                         NaN
# 3                                                         NaN
# 4                                        100 to 499 employees
# 5           Just me - I am a freelancer, sole proprietor, ...
# ...                                                       ...
# 83435                                      20 to 99 employees
# 83436       Just me - I am a freelancer, sole proprietor, ...
# 83437                                10,000 or more employees
# 83438                                      20 to 99 employees
# 83439                                            I don’t know
#
#                                Currency  CompTotal CompFreq  \
# ResponseId
# 1                     EUR European Euro     4800.0  Monthly
# 2                                   NaN        NaN      NaN
# 3                                   NaN        NaN      NaN
# 4                     EUR European Euro        NaN  Monthly
# 5                   GBP\tPound sterling        NaN      NaN
# ...                                 ...        ...      ...
# 83435         USD\tUnited States dollar   160500.0   Yearly
# 83436       XOF\tWest African CFA franc   200000.0  Monthly
# 83437         USD\tUnited States dollar     1800.0   Weekly
# 83438              CAD\tCanadian dollar    90000.0  Monthly
# 83439               BRL\tBrazilian real     7700.0  Monthly
#
#                                    LanguageHaveWorkedWith  \
# ResponseId
# 1           C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 2                                       JavaScript;Python
# 3                                Assembly;C;Python;R;Rust
# 4                                   JavaScript;TypeScript
# 5                          Bash/Shell;HTML/CSS;Python;SQL
# ...                                                   ...
# 83435                                  Clojure;Kotlin;SQL
# 83436                                                 NaN
# 83437                                  Groovy;Java;Python
# 83438                Bash/Shell;JavaScript;Node.js;Python
# 83439              Delphi;Elixir;HTML/CSS;Java;JavaScript
#
#                                        LanguageWantToWorkWith  \
# ResponseId
# 1                                                       Swift
# 2                                                         NaN
# 3                                           Julia;Python;Rust
# 4                                       JavaScript;TypeScript
# 5                              Bash/Shell;HTML/CSS;Python;SQL
# ...                                                       ...
# 83435                                                 Clojure
# 83436                                                     NaN
# 83437                                             Java;Python
# 83438                                                 Go;Rust
# 83439       Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
#
#                                       DatabaseHaveWorkedWith  \
# ResponseId
# 1                                          PostgreSQL;SQLite
# 2                                                 PostgreSQL
# 3                                                     SQLite
# 4                                                        NaN
# 5                             Elasticsearch;PostgreSQL;Redis
# ...                                                      ...
# 83435                                          Oracle;SQLite
# 83436         Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83437        DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438       Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83439                                      Oracle;PostgreSQL
#
#                                        DatabaseWantToWorkWith  \
# ResponseId
# 1                                                      SQLite
# 2                                                         NaN
# 3                                                      SQLite
# 4                                                         NaN
# 5                    Cassandra;Elasticsearch;PostgreSQL;Redis
# ...                                                       ...
# 83435                                                  SQLite
# 83436       Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83437                                          DynamoDB;Redis
# 83438                                                     NaN
# 83439       Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
#
#                PlatformHaveWorkedWith PlatformWantToWorkWith  \
# ResponseId
# 1                                 NaN                    NaN
# 2                                 NaN                    NaN
# 3                              Heroku                    NaN
# 4                                 NaN                    NaN
# 5                                 NaN                    NaN
# ...                               ...                    ...
# 83435                             AWS                    AWS
# 83436                             NaN                    NaN
# 83437       AWS;Google Cloud Platform                    AWS
# 83438                          Heroku       AWS;DigitalOcean
# 83439                 Microsoft Azure                    AWS
#
#                                   WebframeHaveWorkedWith  \
# ResponseId
# 1                                        Laravel;Symfony
# 2                                   Angular;Flask;Vue.js
# 3                                                  Flask
# 4                                         Angular;jQuery
# 5                                                  Flask
# ...                                                  ...
# 83435                                                NaN
# 83436       Django;jQuery;Laravel;React.js;Ruby on Rails
# 83437                                      FastAPI;Flask
# 83438                      Django;Express;Flask;React.js
# 83439                                     Angular;Spring
#
#                                        WebframeWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                                                       Flask
# 4                                              Angular;jQuery
# 5                                                       Flask
# ...                                                       ...
# 83435                                                     NaN
# 83436       Django;Express;jQuery;Laravel;React.js;Ruby on...
# 83437                                           FastAPI;Flask
# 83438                                                     NaN
# 83439                          Express;Laravel;Spring;Symfony
#
#                            MiscTechHaveWorkedWith  \
# ResponseId
# 1                                             NaN
# 2                                         Cordova
# 3           NumPy;Pandas;TensorFlow;Torch/PyTorch
# 4                                             NaN
# 5                Apache Spark;Hadoop;NumPy;Pandas
# ...                                           ...
# 83435                                         NaN
# 83436                                  Flutter;Qt
# 83437                   Hadoop;Keras;NumPy;Pandas
# 83438       NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83439                                         NaN
#
#                                        MiscTechWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                 Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 4                                                         NaN
# 5                                         Hadoop;NumPy;Pandas
# ...                                                       ...
# 83435                                                     NaN
# 83436                                                     NaN
# 83437       Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83438                   NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83439                                                     NaN
#
#                  ToolsTechHaveWorkedWith          ToolsTechWantToWorkWith  \
# ResponseId
# 1                                    NaN                              NaN
# 2                        Docker;Git;Yarn                              Git
# 3                                    NaN                              NaN
# 4                                    NaN                              NaN
# 5             Docker;Git;Kubernetes;Yarn       Docker;Git;Kubernetes;Yarn
# ...                                  ...                              ...
# 83435                         Docker;Git                   Git;Kubernetes
# 83436         Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83437       Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83438       Ansible;Docker;Git;Terraform             Kubernetes;Terraform
# 83439                         Docker;Git            Docker;Git;Kubernetes
#
#                                  NEWCollabToolsHaveWorkedWith  \
# ResponseId
# 1                                              PHPStorm;Xcode
# 2                   Android Studio;IntelliJ;Notepad++;PyCharm
# 3           IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 4                                                         NaN
# 5                  Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# ...                                                       ...
# 83435            IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83436       Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83437       Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83438                                    PyCharm;Sublime Text
# 83439                             IntelliJ;Visual Studio Code
#
#                                  NEWCollabToolsWantToWorkWith        OpSys  \
# ResponseId
# 1                                                  Atom;Xcode        MacOS
# 2                                                         NaN      Windows
# 3           IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 4                                                         NaN      Windows
# 5           Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# ...                                                       ...          ...
# 83435                                        Sublime Text;Vim        MacOS
# 83436       Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83437                  IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83438                                                     NaN        MacOS
# 83439                    IntelliJ;PHPStorm;Visual Studio Code  Linux-based
#
#                                                      NEWStuck  \
# ResponseId
# 1           Call a coworker or friend;Visit Stack Overflow...
# 2                              Visit Stack Overflow;Google it
# 3           Visit Stack Overflow;Google it;Watch help / tu...
# 4           Call a coworker or friend;Visit Stack Overflow...
# 5           Visit Stack Overflow;Go for a walk or other ph...
# ...                                                       ...
# 83435                     Call a coworker or friend;Google it
# 83436       Call a coworker or friend;Visit Stack Overflow...
# 83437       Call a coworker or friend;Visit Stack Overflow...
# 83438       Call a coworker or friend;Visit Stack Overflow...
# 83439       Call a coworker or friend;Visit Stack Overflow...
#
#                                                    NEWSOSites  \
# ResponseId
# 1                                              Stack Overflow
# 2                                              Stack Overflow
# 3                               Stack Overflow;Stack Exchange
# 4                                              Stack Overflow
# 5                               Stack Overflow;Stack Exchange
# ...                                                       ...
# 83435                           Stack Overflow;Stack Exchange
# 83436                           Stack Overflow;Stack Exchange
# 83437                           Stack Overflow;Stack Exchange
# 83438                                          Stack Overflow
# 83439       Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                                 SOVisitFreq SOAccount  \
# ResponseId
# 1                    Multiple times per day       Yes
# 2                     Daily or almost daily       Yes
# 3                    Multiple times per day       Yes
# 4                     Daily or almost daily       Yes
# 5                     Daily or almost daily       Yes
# ...                                     ...       ...
# 83435                  A few times per week        No
# 83436                Multiple times per day       Yes
# 83437                  A few times per week       Yes
# 83438       A few times per month or weekly       Yes
# 83439                  A few times per week       Yes
#
#                                                    SOPartFreq  \
# ResponseId
# 1                             A few times per month or weekly
# 2                                       Daily or almost daily
# 3                                      Multiple times per day
# 4                                       Daily or almost daily
# 5                                        A few times per week
# ...                                                       ...
# 83435                                                     NaN
# 83436       I have never participated in Q&A on Stack Over...
# 83437       I have never participated in Q&A on Stack Over...
# 83438                     Less than once per month or monthly
# 83439                                    A few times per week
#
#                      SOComm NEWOtherComms              Age Gender Trans  \
# ResponseId
# 1           Yes, definitely            No  25-34 years old    Man    No
# 2           Yes, definitely            No  18-24 years old    Man    No
# 3           Yes, definitely           Yes  18-24 years old    Man    No
# 4                   Neutral            No  35-44 years old    Man    No
# 5             Yes, somewhat            No  25-34 years old    Man    No
# ...                     ...           ...              ...    ...   ...
# 83435        No, not at all            No  25-34 years old    Man    No
# 83436         Yes, somewhat            No  18-24 years old    Man    No
# 83437        No, not really            No  25-34 years old    Man    No
# 83438        No, not really            No  25-34 years old    Man    No
# 83439         Yes, somewhat            No  18-24 years old    Man    No
#
#                           Sexuality                     Ethnicity  \
# ResponseId
# 1           Straight / Heterosexual  White or of European descent
# 2           Straight / Heterosexual  White or of European descent
# 3                 Prefer not to say             Prefer not to say
# 4           Straight / Heterosexual  White or of European descent
# 5                               NaN  White or of European descent
# ...                             ...                           ...
# 83435       Straight / Heterosexual  White or of European descent
# 83436       Straight / Heterosexual   Black or of African descent
# 83437                           NaN  White or of European descent
# 83438       Straight / Heterosexual  White or of European descent
# 83439       Straight / Heterosexual        Hispanic or Latino/a/x
#
#                           Accessibility  \
# ResponseId
# 1                     None of the above
# 2                     None of the above
# 3                     None of the above
# 4           I am deaf / hard of hearing
# 5                     None of the above
# ...                                 ...
# 83435                 None of the above
# 83436                 None of the above
# 83437                 None of the above
# 83438                 None of the above
# 83439                 None of the above
#
#                                                  MentalHealth  \
# ResponseId
# 1                                           None of the above
# 2                                           None of the above
# 3                                           None of the above
# 4                                                         NaN
# 5                                                         NaN
# ...                                                       ...
# 83435       I have a concentration and/or memory disorder ...
# 83436                                       None of the above
# 83437                                       None of the above
# 83438       I have a mood or emotional disorder (e.g. depr...
# 83439                                       None of the above
#
#                      SurveyLength                  SurveyEase  \
# ResponseId
# 1           Appropriate in length                        Easy
# 2           Appropriate in length                        Easy
# 3           Appropriate in length                        Easy
# 4           Appropriate in length  Neither easy nor difficult
# 5           Appropriate in length                        Easy
# ...                           ...                         ...
# 83435       Appropriate in length                        Easy
# 83436       Appropriate in length                        Easy
# 83437       Appropriate in length  Neither easy nor difficult
# 83438       Appropriate in length  Neither easy nor difficult
# 83439       Appropriate in length                        Easy
#
#             ConvertedCompYearly
# ResponseId
# 1                       62268.0
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# ...                         ...
# 83435                  160500.0
# 83436                    3960.0
# 83437                   90000.0
# 83438                  816816.0
# 83439                   21168.0
#
# [83439 rows x 47 columns]

# %%
# The first responded has an index of 1 now.
df.loc[1]
# Out:
# MainBranch                                         I am a developer by profession
# Employment                      Independent contractor, freelancer, or self-em...
# Country                                                                  Slovakia
# US_State                                                                      NaN
# UK_Country                                                                    NaN
# EdLevel                         Secondary school (e.g. American high school, G...
# Age1stCode                                                          18 - 24 years
# LearnCode                       Coding Bootcamp;Other online resources (ex: vi...
# YearsCode                                                                     NaN
# YearsCodePro                                                                  NaN
# DevType                                                         Developer, mobile
# OrgSize                                                        20 to 99 employees
# Currency                                                        EUR European Euro
# CompTotal                                                                  4800.0
# CompFreq                                                                  Monthly
# LanguageHaveWorkedWith              C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# LanguageWantToWorkWith                                                      Swift
# DatabaseHaveWorkedWith                                          PostgreSQL;SQLite
# DatabaseWantToWorkWith                                                     SQLite
# PlatformHaveWorkedWith                                                        NaN
# PlatformWantToWorkWith                                                        NaN
# WebframeHaveWorkedWith                                            Laravel;Symfony
# WebframeWantToWorkWith                                                        NaN
# MiscTechHaveWorkedWith                                                        NaN
# MiscTechWantToWorkWith                                                        NaN
# ToolsTechHaveWorkedWith                                                       NaN
# ToolsTechWantToWorkWith                                                       NaN
# NEWCollabToolsHaveWorkedWith                                       PHPStorm;Xcode
# NEWCollabToolsWantToWorkWith                                           Atom;Xcode
# OpSys                                                                       MacOS
# NEWStuck                        Call a coworker or friend;Visit Stack Overflow...
# NEWSOSites                                                         Stack Overflow
# SOVisitFreq                                                Multiple times per day
# SOAccount                                                                     Yes
# SOPartFreq                                        A few times per month or weekly
# SOComm                                                            Yes, definitely
# NEWOtherComms                                                                  No
# Age                                                               25-34 years old
# Gender                                                                        Man
# Trans                                                                          No
# Sexuality                                                 Straight / Heterosexual
# Ethnicity                                            White or of European descent
# Accessibility                                                   None of the above
# MentalHealth                                                    None of the above
# SurveyLength                                                Appropriate in length
# SurveyEase                                                                   Easy
# ConvertedCompYearly                                                       62268.0
# Name: 1, dtype: object

# %% [markdown]
# ### **Task**: Get the question a column refers to.

# %%
# First, get the name of the column that will be used as an index.
schema_df
# Out:
#        qid               qname  \
# 0    QID16                  S0
# 1    QID12            MetaInfo
# 2     QID1                  S1
# 3     QID2          MainBranch
# 4    QID24          Employment
# 5     QID6             Country
# 6     QID7            US_State
# 7     QID9          UK_Country
# 8   QID190                  S2
# 9    QID25             EdLevel
# 10  QID149          Age1stCode
# 11  QID276           LearnCode
# 12   QID32           YearsCode
# 13   QID34        YearsCodePro
# 14   QID31             DevType
# 15   QID29             OrgSize
# 16   QID50            Currency
# 17   QID51           CompTotal
# 18   QID52            CompFreq
# 19   QID61                  S3
# 20  QID233            Language
# 21  QID262            Database
# 22  QID263            Platform
# 23  QID264            Webframe
# 24  QID265            MiscTech
# 25  QID275           ToolsTech
# 26  QID274      NEWCollabTools
# 27   QID71               OpSys
# 28  QID243            NEWStuck
# 29   QID91                  S4
# 30  QID266          NEWSOSites
# 31  QID100         SOVisitFreq
# 32  QID101           SOAccount
# 33  QID102          SOPartFreq
# 34  QID106              SOComm
# 35  QID267       NEWOtherComms
# 36  QID268  NEWOtherCommsNames
# 37  QID121                  S5
# 38  QID127                 Age
# 39  QID122              Gender
# 40  QID153               Trans
# 41  QID136           Sexuality
# 42  QID126           Ethnicity
# 43  QID124       Accessibility
# 44  QID125        MentalHealth
# 45  QID131                  S6
# 46  QID132        SurveyLength
# 47  QID133          SurveyEase
#
#                                              question  force_resp    type  \
# 0   <div><span style="font-size:19px;"><strong>Hel...       False      DB
# 1                                   Browser Meta Info       False    Meta
# 2   <span style="font-size:22px; font-family: aria...       False      DB
# 3   Which of the following options best describes ...        True      MC
# 4   Which of the following best describes your cur...       False      MC
# 5   Where do you live? <span style="font-weight: b...        True      MC
# 6   <p>In which state or territory of the USA do y...       False      MC
# 7   In which part of the United Kingdom do you liv...       False      MC
# 8   <span style="font-size:22px; font-family: aria...       False      DB
# 9   Which of the following best describes the high...       False      MC
# 10  At what age did you write your first line of c...       False      MC
# 11  How did you learn to code? Select all that apply.       False      MC
# 12  Including any education, how many years have y...       False      MC
# 13  NOT including education, how many years have y...       False      MC
# 14  Which of the following describes your current ...       False      MC
# 15  Approximately how many people are employed by ...       False      MC
# 16  Which currency do you use day-to-day? If your ...        True      MC
# 17  What is your current total compensation (salar...       False      TE
# 18   Is that compensation weekly, monthly, or yearly?       False      MC
# 19  <span style="font-size:22px; font-family: aria...       False      DB
# 20  Which <b>programming, scripting, and markup la...       False  Matrix
# 21  Which <b>database environments </b>have you do...       False  Matrix
# 22  Which <b>cloud platforms</b> have you done ext...       False  Matrix
# 23  Which <strong>web frameworks </strong><span st...       False  Matrix
# 24  Which <b>other frameworks and libraries</b> ha...       False  Matrix
# 25  Which <strong>tools</strong> have you done ext...       False  Matrix
# 26  Which <strong>development environments</strong...       False  Matrix
# 27  What is the primary operating system in which ...       False      MC
# 28  What do you do when you get stuck on a problem...       False      MC
# 29  <span style="font-size:22px; font-family: aria...       False      DB
# 30  Which of the following Stack Overflow sites ha...       False      MC
# 31  How frequently would you say you visit Stack O...       False      MC
# 32              Do you have a Stack Overflow account?       False      MC
# 33  How frequently would you say you participate i...       False      MC
# 34  Do you consider yourself a member of the Stack...       False      MC
# 35  Are you a member of any other online developer...       False      MC
# 36  Please name up to 5 other online developer com...       False  Matrix
# 37  <span style="font-size:22px; font-family: aria...       False      DB
# 38                                  What is your age?       False      MC
# 39  Which of the following describe you, if any? P...       False      MC
# 40                    Do you identify as transgender?       False      MC
# 41  Which of the following describe you, if any? P...       False      MC
# 42  Which of the following describe you, if any? P...       False      MC
# 43  Which of the following describe you, if any? P...       False      MC
# 44  Which of the following describe you, if any? P...       False      MC
# 45  <span style="font-size:22px;"><strong>Final Qu...       False      DB
# 46  How do you feel about the length of the survey...       False      MC
# 47  How easy or difficult was this survey to compl...       False      MC
#
#    selector
# 0        TB
# 1   Browser
# 2        TB
# 3      SAVR
# 4      MAVR
# 5        DL
# 6        DL
# 7        DL
# 8        TB
# 9      SAVR
# 10     MAVR
# 11     MAVR
# 12       DL
# 13       DL
# 14     MAVR
# 15     MAVR
# 16       SB
# 17       SL
# 18     MAVR
# 19       TB
# 20   Likert
# 21   Likert
# 22   Likert
# 23   Likert
# 24   Likert
# 25   Likert
# 26   Likert
# 27     SAVR
# 28     MAVR
# 29       TB
# 30     MAVR
# 31     MAVR
# 32     MAVR
# 33     MAVR
# 34     MAVR
# 35     MAVR
# 36   Likert
# 37       TB
# 38     MAVR
# 39     MAVR
# 40     MAVR
# 41     MAVR
# 42     MAVR
# 43     MAVR
# 44     MAVR
# 45       TB
# 46     MAVR
# 47     MAVR

# %%
# In this case it's `qname`
schema_df = pd.read_csv(SCHEMA_PATH, index_col='qname')
schema_df
# Out:
#                        qid                                           question  \
# qname
# S0                   QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo             QID12                                  Browser Meta Info
# S1                    QID1  <span style="font-size:22px; font-family: aria...
# MainBranch            QID2  Which of the following options best describes ...
# Employment           QID24  Which of the following best describes your cur...
# Country               QID6  Where do you live? <span style="font-weight: b...
# US_State              QID7  <p>In which state or territory of the USA do y...
# UK_Country            QID9  In which part of the United Kingdom do you liv...
# S2                  QID190  <span style="font-size:22px; font-family: aria...
# EdLevel              QID25  Which of the following best describes the high...
# Age1stCode          QID149  At what age did you write your first line of c...
# LearnCode           QID276  How did you learn to code? Select all that apply.
# YearsCode            QID32  Including any education, how many years have y...
# YearsCodePro         QID34  NOT including education, how many years have y...
# DevType              QID31  Which of the following describes your current ...
# OrgSize              QID29  Approximately how many people are employed by ...
# Currency             QID50  Which currency do you use day-to-day? If your ...
# CompTotal            QID51  What is your current total compensation (salar...
# CompFreq             QID52   Is that compensation weekly, monthly, or yearly?
# S3                   QID61  <span style="font-size:22px; font-family: aria...
# Language            QID233  Which <b>programming, scripting, and markup la...
# Database            QID262  Which <b>database environments </b>have you do...
# Platform            QID263  Which <b>cloud platforms</b> have you done ext...
# Webframe            QID264  Which <strong>web frameworks </strong><span st...
# MiscTech            QID265  Which <b>other frameworks and libraries</b> ha...
# ToolsTech           QID275  Which <strong>tools</strong> have you done ext...
# NEWCollabTools      QID274  Which <strong>development environments</strong...
# OpSys                QID71  What is the primary operating system in which ...
# NEWStuck            QID243  What do you do when you get stuck on a problem...
# S4                   QID91  <span style="font-size:22px; font-family: aria...
# NEWSOSites          QID266  Which of the following Stack Overflow sites ha...
# SOVisitFreq         QID100  How frequently would you say you visit Stack O...
# SOAccount           QID101              Do you have a Stack Overflow account?
# SOPartFreq          QID102  How frequently would you say you participate i...
# SOComm              QID106  Do you consider yourself a member of the Stack...
# NEWOtherComms       QID267  Are you a member of any other online developer...
# NEWOtherCommsNames  QID268  Please name up to 5 other online developer com...
# S5                  QID121  <span style="font-size:22px; font-family: aria...
# Age                 QID127                                  What is your age?
# Gender              QID122  Which of the following describe you, if any? P...
# Trans               QID153                    Do you identify as transgender?
# Sexuality           QID136  Which of the following describe you, if any? P...
# Ethnicity           QID126  Which of the following describe you, if any? P...
# Accessibility       QID124  Which of the following describe you, if any? P...
# MentalHealth        QID125  Which of the following describe you, if any? P...
# S6                  QID131  <span style="font-size:22px;"><strong>Final Qu...
# SurveyLength        QID132  How do you feel about the length of the survey...
# SurveyEase          QID133  How easy or difficult was this survey to compl...
#
#                     force_resp    type selector
# qname
# S0                       False      DB       TB
# MetaInfo                 False    Meta  Browser
# S1                       False      DB       TB
# MainBranch                True      MC     SAVR
# Employment               False      MC     MAVR
# Country                   True      MC       DL
# US_State                 False      MC       DL
# UK_Country               False      MC       DL
# S2                       False      DB       TB
# EdLevel                  False      MC     SAVR
# Age1stCode               False      MC     MAVR
# LearnCode                False      MC     MAVR
# YearsCode                False      MC       DL
# YearsCodePro             False      MC       DL
# DevType                  False      MC     MAVR
# OrgSize                  False      MC     MAVR
# Currency                  True      MC       SB
# CompTotal                False      TE       SL
# CompFreq                 False      MC     MAVR
# S3                       False      DB       TB
# Language                 False  Matrix   Likert
# Database                 False  Matrix   Likert
# Platform                 False  Matrix   Likert
# Webframe                 False  Matrix   Likert
# MiscTech                 False  Matrix   Likert
# ToolsTech                False  Matrix   Likert
# NEWCollabTools           False  Matrix   Likert
# OpSys                    False      MC     SAVR
# NEWStuck                 False      MC     MAVR
# S4                       False      DB       TB
# NEWSOSites               False      MC     MAVR
# SOVisitFreq              False      MC     MAVR
# SOAccount                False      MC     MAVR
# SOPartFreq               False      MC     MAVR
# SOComm                   False      MC     MAVR
# NEWOtherComms            False      MC     MAVR
# NEWOtherCommsNames       False  Matrix   Likert
# S5                       False      DB       TB
# Age                      False      MC     MAVR
# Gender                   False      MC     MAVR
# Trans                    False      MC     MAVR
# Sexuality                False      MC     MAVR
# Ethnicity                False      MC     MAVR
# Accessibility            False      MC     MAVR
# MentalHealth             False      MC     MAVR
# S6                       False      DB       TB
# SurveyLength             False      MC     MAVR
# SurveyEase               False      MC     MAVR

# %%
# Then, locate the row with index `Employment`
schema_df.loc['Employment']
# Out:
# qid                                                       QID24
# question      Which of the following best describes your cur...
# force_resp                                                False
# type                                                         MC
# selector                                                   MAVR
# Name: Employment, dtype: object

# %%
schema_df.loc['Employment', 'question']
# Out:
# 'Which of the following best describes your current <b>employment status</b>?'

# %%
# Now we can check any question
df.columns
# Out:
# Index(['MainBranch', 'Employment', 'Country', 'US_State', 'UK_Country',
#        'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode', 'YearsCodePro',
#        'DevType', 'OrgSize', 'Currency', 'CompTotal', 'CompFreq',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
schema_df.loc['NEWOtherComms', 'question']
# Out:
# 'Are you a member of any other online developer communities?'

# %%
# Sort the indices lexicographically.
schema_df.sort_index()
# Out:
#                        qid                                           question  \
# qname
# Accessibility       QID124  Which of the following describe you, if any? P...
# Age                 QID127                                  What is your age?
# Age1stCode          QID149  At what age did you write your first line of c...
# CompFreq             QID52   Is that compensation weekly, monthly, or yearly?
# CompTotal            QID51  What is your current total compensation (salar...
# Country               QID6  Where do you live? <span style="font-weight: b...
# Currency             QID50  Which currency do you use day-to-day? If your ...
# Database            QID262  Which <b>database environments </b>have you do...
# DevType              QID31  Which of the following describes your current ...
# EdLevel              QID25  Which of the following best describes the high...
# Employment           QID24  Which of the following best describes your cur...
# Ethnicity           QID126  Which of the following describe you, if any? P...
# Gender              QID122  Which of the following describe you, if any? P...
# Language            QID233  Which <b>programming, scripting, and markup la...
# LearnCode           QID276  How did you learn to code? Select all that apply.
# MainBranch            QID2  Which of the following options best describes ...
# MentalHealth        QID125  Which of the following describe you, if any? P...
# MetaInfo             QID12                                  Browser Meta Info
# MiscTech            QID265  Which <b>other frameworks and libraries</b> ha...
# NEWCollabTools      QID274  Which <strong>development environments</strong...
# NEWOtherComms       QID267  Are you a member of any other online developer...
# NEWOtherCommsNames  QID268  Please name up to 5 other online developer com...
# NEWSOSites          QID266  Which of the following Stack Overflow sites ha...
# NEWStuck            QID243  What do you do when you get stuck on a problem...
# OpSys                QID71  What is the primary operating system in which ...
# OrgSize              QID29  Approximately how many people are employed by ...
# Platform            QID263  Which <b>cloud platforms</b> have you done ext...
# S0                   QID16  <div><span style="font-size:19px;"><strong>Hel...
# S1                    QID1  <span style="font-size:22px; font-family: aria...
# S2                  QID190  <span style="font-size:22px; font-family: aria...
# S3                   QID61  <span style="font-size:22px; font-family: aria...
# S4                   QID91  <span style="font-size:22px; font-family: aria...
# S5                  QID121  <span style="font-size:22px; font-family: aria...
# S6                  QID131  <span style="font-size:22px;"><strong>Final Qu...
# SOAccount           QID101              Do you have a Stack Overflow account?
# SOComm              QID106  Do you consider yourself a member of the Stack...
# SOPartFreq          QID102  How frequently would you say you participate i...
# SOVisitFreq         QID100  How frequently would you say you visit Stack O...
# Sexuality           QID136  Which of the following describe you, if any? P...
# SurveyEase          QID133  How easy or difficult was this survey to compl...
# SurveyLength        QID132  How do you feel about the length of the survey...
# ToolsTech           QID275  Which <strong>tools</strong> have you done ext...
# Trans               QID153                    Do you identify as transgender?
# UK_Country            QID9  In which part of the United Kingdom do you liv...
# US_State              QID7  <p>In which state or territory of the USA do y...
# Webframe            QID264  Which <strong>web frameworks </strong><span st...
# YearsCode            QID32  Including any education, how many years have y...
# YearsCodePro         QID34  NOT including education, how many years have y...
#
#                     force_resp    type selector
# qname
# Accessibility            False      MC     MAVR
# Age                      False      MC     MAVR
# Age1stCode               False      MC     MAVR
# CompFreq                 False      MC     MAVR
# CompTotal                False      TE       SL
# Country                   True      MC       DL
# Currency                  True      MC       SB
# Database                 False  Matrix   Likert
# DevType                  False      MC     MAVR
# EdLevel                  False      MC     SAVR
# Employment               False      MC     MAVR
# Ethnicity                False      MC     MAVR
# Gender                   False      MC     MAVR
# Language                 False  Matrix   Likert
# LearnCode                False      MC     MAVR
# MainBranch                True      MC     SAVR
# MentalHealth             False      MC     MAVR
# MetaInfo                 False    Meta  Browser
# MiscTech                 False  Matrix   Likert
# NEWCollabTools           False  Matrix   Likert
# NEWOtherComms            False      MC     MAVR
# NEWOtherCommsNames       False  Matrix   Likert
# NEWSOSites               False      MC     MAVR
# NEWStuck                 False      MC     MAVR
# OpSys                    False      MC     SAVR
# OrgSize                  False      MC     MAVR
# Platform                 False  Matrix   Likert
# S0                       False      DB       TB
# S1                       False      DB       TB
# S2                       False      DB       TB
# S3                       False      DB       TB
# S4                       False      DB       TB
# S5                       False      DB       TB
# S6                       False      DB       TB
# SOAccount                False      MC     MAVR
# SOComm                   False      MC     MAVR
# SOPartFreq               False      MC     MAVR
# SOVisitFreq              False      MC     MAVR
# Sexuality                False      MC     MAVR
# SurveyEase               False      MC     MAVR
# SurveyLength             False      MC     MAVR
# ToolsTech                False  Matrix   Likert
# Trans                    False      MC     MAVR
# UK_Country               False      MC       DL
# US_State                 False      MC       DL
# Webframe                 False  Matrix   Likert
# YearsCode                False      MC       DL
# YearsCodePro             False      MC       DL

# %%
# Note that this does not change the dataframe.
schema_df.sort_index(ascending=False)
# Out:
#                        qid                                           question  \
# qname
# YearsCodePro         QID34  NOT including education, how many years have y...
# YearsCode            QID32  Including any education, how many years have y...
# Webframe            QID264  Which <strong>web frameworks </strong><span st...
# US_State              QID7  <p>In which state or territory of the USA do y...
# UK_Country            QID9  In which part of the United Kingdom do you liv...
# Trans               QID153                    Do you identify as transgender?
# ToolsTech           QID275  Which <strong>tools</strong> have you done ext...
# SurveyLength        QID132  How do you feel about the length of the survey...
# SurveyEase          QID133  How easy or difficult was this survey to compl...
# Sexuality           QID136  Which of the following describe you, if any? P...
# SOVisitFreq         QID100  How frequently would you say you visit Stack O...
# SOPartFreq          QID102  How frequently would you say you participate i...
# SOComm              QID106  Do you consider yourself a member of the Stack...
# SOAccount           QID101              Do you have a Stack Overflow account?
# S6                  QID131  <span style="font-size:22px;"><strong>Final Qu...
# S5                  QID121  <span style="font-size:22px; font-family: aria...
# S4                   QID91  <span style="font-size:22px; font-family: aria...
# S3                   QID61  <span style="font-size:22px; font-family: aria...
# S2                  QID190  <span style="font-size:22px; font-family: aria...
# S1                    QID1  <span style="font-size:22px; font-family: aria...
# S0                   QID16  <div><span style="font-size:19px;"><strong>Hel...
# Platform            QID263  Which <b>cloud platforms</b> have you done ext...
# OrgSize              QID29  Approximately how many people are employed by ...
# OpSys                QID71  What is the primary operating system in which ...
# NEWStuck            QID243  What do you do when you get stuck on a problem...
# NEWSOSites          QID266  Which of the following Stack Overflow sites ha...
# NEWOtherCommsNames  QID268  Please name up to 5 other online developer com...
# NEWOtherComms       QID267  Are you a member of any other online developer...
# NEWCollabTools      QID274  Which <strong>development environments</strong...
# MiscTech            QID265  Which <b>other frameworks and libraries</b> ha...
# MetaInfo             QID12                                  Browser Meta Info
# MentalHealth        QID125  Which of the following describe you, if any? P...
# MainBranch            QID2  Which of the following options best describes ...
# LearnCode           QID276  How did you learn to code? Select all that apply.
# Language            QID233  Which <b>programming, scripting, and markup la...
# Gender              QID122  Which of the following describe you, if any? P...
# Ethnicity           QID126  Which of the following describe you, if any? P...
# Employment           QID24  Which of the following best describes your cur...
# EdLevel              QID25  Which of the following best describes the high...
# DevType              QID31  Which of the following describes your current ...
# Database            QID262  Which <b>database environments </b>have you do...
# Currency             QID50  Which currency do you use day-to-day? If your ...
# Country               QID6  Where do you live? <span style="font-weight: b...
# CompTotal            QID51  What is your current total compensation (salar...
# CompFreq             QID52   Is that compensation weekly, monthly, or yearly?
# Age1stCode          QID149  At what age did you write your first line of c...
# Age                 QID127                                  What is your age?
# Accessibility       QID124  Which of the following describe you, if any? P...
#
#                     force_resp    type selector
# qname
# YearsCodePro             False      MC       DL
# YearsCode                False      MC       DL
# Webframe                 False  Matrix   Likert
# US_State                 False      MC       DL
# UK_Country               False      MC       DL
# Trans                    False      MC     MAVR
# ToolsTech                False  Matrix   Likert
# SurveyLength             False      MC     MAVR
# SurveyEase               False      MC     MAVR
# Sexuality                False      MC     MAVR
# SOVisitFreq              False      MC     MAVR
# SOPartFreq               False      MC     MAVR
# SOComm                   False      MC     MAVR
# SOAccount                False      MC     MAVR
# S6                       False      DB       TB
# S5                       False      DB       TB
# S4                       False      DB       TB
# S3                       False      DB       TB
# S2                       False      DB       TB
# S1                       False      DB       TB
# S0                       False      DB       TB
# Platform                 False  Matrix   Likert
# OrgSize                  False      MC     MAVR
# OpSys                    False      MC     SAVR
# NEWStuck                 False      MC     MAVR
# NEWSOSites               False      MC     MAVR
# NEWOtherCommsNames       False  Matrix   Likert
# NEWOtherComms            False      MC     MAVR
# NEWCollabTools           False  Matrix   Likert
# MiscTech                 False  Matrix   Likert
# MetaInfo                 False    Meta  Browser
# MentalHealth             False      MC     MAVR
# MainBranch                True      MC     SAVR
# LearnCode                False      MC     MAVR
# Language                 False  Matrix   Likert
# Gender                   False      MC     MAVR
# Ethnicity                False      MC     MAVR
# Employment               False      MC     MAVR
# EdLevel                  False      MC     SAVR
# DevType                  False      MC     MAVR
# Database                 False  Matrix   Likert
# Currency                  True      MC       SB
# Country                   True      MC       DL
# CompTotal                False      TE       SL
# CompFreq                 False      MC     MAVR
# Age1stCode               False      MC     MAVR
# Age                      False      MC     MAVR
# Accessibility            False      MC     MAVR

# %% [markdown]
# ## Filtering - Using Conditionals to Filter Rows and Columns

# %%
ppl_df
# Out:
#                      email      first      last
# 0  s.e.hristov99@gmail.com  SimoFirst  SimoLast
# 1        JaneDoe@gmail.com       Jane       Doe
# 2        JohnDoe@gmail.com       John       Doe

# %%
# Get all people with last name `Doe`.
ppl_df['last'] == 'Doe'
# Out:
# 0    False
# 1     True
# 2     True
# Name: last, dtype: bool

# %%
ppl_df[ppl_df['last'] == 'Doe']
# Out:
#                email first last
# 1  JaneDoe@gmail.com  Jane  Doe
# 2  JohnDoe@gmail.com  John  Doe

# %%
ppl_df[ppl_df['last'] == 'Doe']['email']
# Out:
# 1    JaneDoe@gmail.com
# 2    JohnDoe@gmail.com
# Name: email, dtype: object

# %%
ppl_df.loc[ppl_df['last'] == 'Doe']
# Out:
#                email first last
# 1  JaneDoe@gmail.com  Jane  Doe
# 2  JohnDoe@gmail.com  John  Doe

# %%
ppl_df.loc[ppl_df['last'] == 'Doe', 'email']
# Out:
# 1    JaneDoe@gmail.com
# 2    JohnDoe@gmail.com
# Name: email, dtype: object

# %% [markdown]
# > **Note**: Chaining multiple conditions happens with **&**, **|**, **~**, not with the Python keywords `and`, `or`, `not`.
#
# > **THE BRACKETS ARE IMPORTANT!**

# %%
# Get the rows in which the last name is `Doe` and the first name is `John`.
ppl_df[(ppl_df['last'] == 'Doe') & (ppl_df['first'] == 'John')]
# Out:
#                email first last
# 2  JohnDoe@gmail.com  John  Doe

# %%
ppl_df[(ppl_df['last'] == 'Doe') & (ppl_df['first'] == 'John')]['email']
# Out:
# 2    JohnDoe@gmail.com
# Name: email, dtype: object

# %%
# Get the rows in which the last name is `SimoLast` or the first name is `John`.
ppl_df[(ppl_df['last'] == 'SimoLast') | (ppl_df['first'] == 'John')]
# Out:
#                      email      first      last
# 0  s.e.hristov99@gmail.com  SimoFirst  SimoLast
# 2        JohnDoe@gmail.com       John       Doe

# %%
ppl_df[(ppl_df['last'] == 'SimoLast') | (ppl_df['first'] == 'John')]['email']
# Out:
# 0    s.e.hristov99@gmail.com
# 2          JohnDoe@gmail.com
# Name: email, dtype: object

# %%
# Get the opposite of the above condition.
ppl_df[~((ppl_df['last'] == 'SimoLast') | (ppl_df['first'] == 'John'))]['email']
# Out:
# 1    JaneDoe@gmail.com
# Name: email, dtype: object

# %%
df.columns
# Out:
# Index(['MainBranch', 'Employment', 'Country', 'US_State', 'UK_Country',
#        'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode', 'YearsCodePro',
#        'DevType', 'OrgSize', 'Currency', 'CompTotal', 'CompFreq',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %% [markdown]
# ### **Task**: Get all responces from people that earn a salary > 70 000.

# %%
# We'll use the last column `ConvertedCompYearly` to do that.
filt = (df['ConvertedCompYearly'] > 70000)
df[filt]

# %%
df[filt][['Country', 'LanguageHaveWorkedWith', 'ConvertedCompYearly']]

# %%
# Task: Get only responces from specific countries.
countries = ['United States', 'Germany', 'Bulgaria', 'United Kingdom', 'Canada', 'India']
filt = (df['Country'].isin(countries))

# %%
df.loc[filt, 'Country']
# Out:
# ResponseId
# 9          India
# 13       Germany
# 18        Canada
# 21       Germany
# 23         India
#           ...
# 83416    Germany
# 83418      India
# 83425    Germany
# 83433     Canada
# 83438     Canada
# Name: Country, Length: 19550, dtype: object

# %%
# Task: Get people who chose Python as the only programming language they know.
df['LanguageHaveWorkedWith']
# Out:
# ResponseId
# 1        C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 2                                    JavaScript;Python
# 3                             Assembly;C;Python;R;Rust
# 4                                JavaScript;TypeScript
# 5                       Bash/Shell;HTML/CSS;Python;SQL
#                              ...
# 83435                               Clojure;Kotlin;SQL
# 83436                                              NaN
# 83437                               Groovy;Java;Python
# 83438             Bash/Shell;JavaScript;Node.js;Python
# 83439           Delphi;Elixir;HTML/CSS;Java;JavaScript
# Name: LanguageHaveWorkedWith, Length: 83439, dtype: object

# %%
filt = df['LanguageHaveWorkedWith'].str.contains('Python', na=False)
df.loc[filt]
# Out:
#                                                    MainBranch  \
# ResponseId
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 5                              I am a developer by profession
# 6                      I am a student who is learning to code
# 10                             I am a developer by profession
# ...                                                       ...
# 83430                             I code primarily as a hobby
# 83431                          I am a developer by profession
# 83432                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 2                                          Student, full-time
# 3                                          Student, full-time
# 5           Independent contractor, freelancer, or self-em...
# 6                                          Student, part-time
# 10                                         Employed full-time
# ...                                                       ...
# 83430                      Not employed, but looking for work
# 83431                                      Employed full-time
# 83432       Independent contractor, freelancer, or self-em...
# 83437                                      Employed full-time
# 83438                                      Employed full-time
#
#                                                       Country    US_State  \
# ResponseId
# 2                                                 Netherlands         NaN
# 3                                          Russian Federation         NaN
# 5           United Kingdom of Great Britain and Northern I...         NaN
# 6                                    United States of America     Georgia
# 10                                                     Sweden         NaN
# ...                                                       ...         ...
# 83430                                United States of America  Washington
# 83431                                United States of America    Illinois
# 83432                                                Pakistan         NaN
# 83437                                United States of America  New Jersey
# 83438                                                  Canada         NaN
#
#            UK_Country                                            EdLevel  \
# ResponseId
# 2                 NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                 NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5             England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 6                 NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 10                NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...               ...                                                ...
# 83430             NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83431             NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 83432             NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83437             NaN  Secondary school (e.g. American high school, G...
# 83438             NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                Age1stCode                                          LearnCode  \
# ResponseId
# 2           11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3           11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 5            5 - 10 years                            Friend or family member
# 6           11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 10          11 - 17 years                                             School
# ...                   ...                                                ...
# 83430       18 - 24 years    Other online resources (ex: videos, blogs, etc)
# 83431       11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83432       11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83437       11 - 17 years                                             School
# 83438       11 - 17 years  Online Courses or Certification;Books / Physic...
#
#            YearsCode YearsCodePro  \
# ResponseId
# 2                  7          NaN
# 3                NaN          NaN
# 5                 17           10
# 6                NaN          NaN
# 10                 7            4
# ...              ...          ...
# 83430              6          NaN
# 83431             23           21
# 83432              9            4
# 83437             10            4
# 83438              5            3
#
#                                                       DevType  \
# ResponseId
# 2                                                         NaN
# 3                                                         NaN
# 5           Developer, desktop or enterprise applications;...
# 6                                                         NaN
# 10              Data scientist or machine learning specialist
# ...                                                       ...
# 83430                         Other (please specify):;Student
# 83431       Developer, front-end;Developer, full-stack;Dev...
# 83432       Developer, mobile;Developer, desktop or enterp...
# 83437       Data scientist or machine learning specialist;...
# 83438                                     Developer, back-end
#
#                                                       OrgSize  \
# ResponseId
# 2                                                         NaN
# 3                                                         NaN
# 5           Just me - I am a freelancer, sole proprietor, ...
# 6                                                         NaN
# 10                                         10 to 19 employees
# ...                                                       ...
# 83430                                                     NaN
# 83431                                      10 to 19 employees
# 83432                                        2 to 9 employees
# 83437                                10,000 or more employees
# 83438                                      20 to 99 employees
#
#                              Currency  CompTotal CompFreq  \
# ResponseId
# 2                                 NaN        NaN      NaN
# 3                                 NaN        NaN      NaN
# 5                 GBP\tPound sterling        NaN      NaN
# 6                                 NaN        NaN      NaN
# 10                 SEK\tSwedish krona    42000.0  Monthly
# ...                               ...        ...      ...
# 83430                             NaN        NaN      NaN
# 83431       USD\tUnited States dollar   125000.0   Yearly
# 83432            PKR\tPakistani rupee   150000.0  Monthly
# 83437       USD\tUnited States dollar     1800.0   Weekly
# 83438            CAD\tCanadian dollar    90000.0  Monthly
#
#                                        LanguageHaveWorkedWith  \
# ResponseId
# 2                                           JavaScript;Python
# 3                                    Assembly;C;Python;R;Rust
# 5                              Bash/Shell;HTML/CSS;Python;SQL
# 6           C;C#;C++;HTML/CSS;Java;JavaScript;Node.js;Powe...
# 10                                                 C++;Python
# ...                                                       ...
# 83430                  HTML/CSS;PHP;PowerShell;Python;SQL;VBA
# 83431             APL;Clojure;LISP;Python;Ruby;SQL;TypeScript
# 83432       C#;Dart;HTML/CSS;Java;JavaScript;Kotlin;Node.j...
# 83437                                      Groovy;Java;Python
# 83438                    Bash/Shell;JavaScript;Node.js;Python
#
#                                        LanguageWantToWorkWith  \
# ResponseId
# 2                                                         NaN
# 3                                           Julia;Python;Rust
# 5                              Bash/Shell;HTML/CSS;Python;SQL
# 6           C#;C++;Go;HTML/CSS;Java;JavaScript;Node.js;Obj...
# 10                                             Haskell;Python
# ...                                                       ...
# 83430       C#;Go;HTML/CSS;Java;JavaScript;PHP;Python;SQL;VBA
# 83431                              APL;Clojure;Haskell;LISP;R
# 83432       C#;Dart;HTML/CSS;JavaScript;Kotlin;Node.js;Pyt...
# 83437                                             Java;Python
# 83438                                                 Go;Rust
#
#                                       DatabaseHaveWorkedWith  \
# ResponseId
# 2                                                 PostgreSQL
# 3                                                     SQLite
# 5                             Elasticsearch;PostgreSQL;Redis
# 6                                    MySQL;PostgreSQL;SQLite
# 10                                                PostgreSQL
# ...                                                      ...
# 83430                               MongoDB;MySQL;PostgreSQL
# 83431                         MongoDB;MySQL;PostgreSQL;Redis
# 83432                                  Firebase;MySQL;SQLite
# 83437        DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438       Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
#
#                                        DatabaseWantToWorkWith  \
# ResponseId
# 2                                                         NaN
# 3                                                      SQLite
# 5                    Cassandra;Elasticsearch;PostgreSQL;Redis
# 6           Elasticsearch;Firebase;IBM DB2;MariaDB;Microso...
# 10                                                        NaN
# ...                                                       ...
# 83430       MariaDB;Microsoft SQL Server;MongoDB;MySQL;Pos...
# 83431                                              PostgreSQL
# 83432                  DynamoDB;Firebase;MongoDB;MySQL;SQLite
# 83437                                          DynamoDB;Redis
# 83438                                                     NaN
#
#                                    PlatformHaveWorkedWith  \
# ResponseId
# 2                                                     NaN
# 3                                                  Heroku
# 5                                                     NaN
# 6                                                     NaN
# 10                                                    NaN
# ...                                                   ...
# 83430                                              Heroku
# 83431       AWS;DigitalOcean;Google Cloud Platform;Heroku
# 83432                               Google Cloud Platform
# 83437                           AWS;Google Cloud Platform
# 83438                                              Heroku
#
#                                        PlatformWantToWorkWith  \
# ResponseId
# 2                                                         NaN
# 3                                                         NaN
# 5                                                         NaN
# 6                                                         NaN
# 10                                                        NaN
# ...                                                       ...
# 83430       AWS;Heroku;IBM Cloud or Watson;Microsoft Azure...
# 83431                  AWS;DigitalOcean;Google Cloud Platform
# 83432                               AWS;Google Cloud Platform
# 83437                                                     AWS
# 83438                                        AWS;DigitalOcean
#
#                    WebframeHaveWorkedWith  \
# ResponseId
# 2                    Angular;Flask;Vue.js
# 3                                   Flask
# 5                                   Flask
# 6           Express;Flask;jQuery;React.js
# 10                                    NaN
# ...                                   ...
# 83430                 Django;Flask;jQuery
# 83431       Django;React.js;Ruby on Rails
# 83432                        Flask;jQuery
# 83437                       FastAPI;Flask
# 83438       Django;Express;Flask;React.js
#
#                                        WebframeWantToWorkWith  \
# ResponseId
# 2                                                         NaN
# 3                                                       Flask
# 5                                                       Flask
# 6                               Express;Flask;jQuery;React.js
# 10                                                        NaN
# ...                                                       ...
# 83430       Angular.js;ASP.NET;ASP.NET Core ;Django;FastAP...
# 83431                                                     NaN
# 83432                     Angular;Django;Flask;jQuery;Laravel
# 83437                                           FastAPI;Flask
# 83438                                                     NaN
#
#                                  MiscTechHaveWorkedWith  \
# ResponseId
# 2                                               Cordova
# 3                 NumPy;Pandas;TensorFlow;Torch/PyTorch
# 5                      Apache Spark;Hadoop;NumPy;Pandas
# 6           Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 10          Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# ...                                                 ...
# 83430                                      NumPy;Pandas
# 83431                                               NaN
# 83432                                           Flutter
# 83437                         Hadoop;Keras;NumPy;Pandas
# 83438             NumPy;Pandas;TensorFlow;Torch/PyTorch
#
#                                        MiscTechWantToWorkWith  \
# ResponseId
# 2                                                         NaN
# 3                 Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 5                                         Hadoop;NumPy;Pandas
# 6           Keras;NumPy;Pandas;Qt;React Native;TensorFlow;...
# 10                       Keras;NumPy;TensorFlow;Torch/PyTorch
# ...                                                       ...
# 83430          .NET Framework;.NET Core / .NET 5;NumPy;Pandas
# 83431                                                     NaN
# 83432           Flutter;Hadoop;NumPy;TensorFlow;Torch/PyTorch
# 83437       Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83438                   NumPy;Pandas;TensorFlow;Torch/PyTorch
#
#                  ToolsTechHaveWorkedWith            ToolsTechWantToWorkWith  \
# ResponseId
# 2                        Docker;Git;Yarn                                Git
# 3                                    NaN                                NaN
# 5             Docker;Git;Kubernetes;Yarn         Docker;Git;Kubernetes;Yarn
# 6                                    Git  Docker;Git;Unity 3D;Unreal Engine
# 10                                   Git                                Git
# ...                                  ...                                ...
# 83430                                Git                 Docker;Git;Xamarin
# 83431                         Docker;Git     Docker;Git;Kubernetes;Unity 3D
# 83432                                Git                         Docker;Git
# 83437       Ansible;Docker;Git;Terraform    Docker;Git;Kubernetes;Terraform
# 83438       Ansible;Docker;Git;Terraform               Kubernetes;Terraform
#
#                                  NEWCollabToolsHaveWorkedWith  \
# ResponseId
# 2                   Android Studio;IntelliJ;Notepad++;PyCharm
# 3           IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 5                  Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# 6           IPython/Jupyter;Notepad++;PyCharm;Sublime Text...
# 10                     IPython/Jupyter;Vim;Visual Studio Code
# ...                                                       ...
# 83430          Atom;Notepad++;Sublime Text;Visual Studio Code
# 83431                                               Emacs;Vim
# 83432       Android Studio;IntelliJ;IPython/Jupyter;Notepa...
# 83437       Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83438                                    PyCharm;Sublime Text
#
#                                  NEWCollabToolsWantToWorkWith        OpSys  \
# ResponseId
# 2                                                         NaN      Windows
# 3           IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 5           Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# 6           Android Studio;IPython/Jupyter;Vim;Visual Stud...      Windows
# 10               Emacs;IPython/Jupyter;Vim;Visual Studio Code  Linux-based
# ...                                                       ...          ...
# 83430          Atom;Notepad++;Sublime Text;Visual Studio Code      Windows
# 83431                                                   Emacs  Linux-based
# 83432       Android Studio;IntelliJ;IPython/Jupyter;PyChar...      Windows
# 83437                  IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83438                                                     NaN        MacOS
#
#                                                      NEWStuck  \
# ResponseId
# 2                              Visit Stack Overflow;Google it
# 3           Visit Stack Overflow;Google it;Watch help / tu...
# 5           Visit Stack Overflow;Go for a walk or other ph...
# 6           Visit Stack Overflow;Go for a walk or other ph...
# 10          Call a coworker or friend;Visit Stack Overflow...
# ...                                                       ...
# 83430       Visit Stack Overflow;Google it;Watch help / tu...
# 83431       Call a coworker or friend;Visit Stack Overflow...
# 83432       Visit Stack Overflow;Go for a walk or other ph...
# 83437       Call a coworker or friend;Visit Stack Overflow...
# 83438       Call a coworker or friend;Visit Stack Overflow...
#
#                                NEWSOSites                      SOVisitFreq  \
# ResponseId
# 2                          Stack Overflow            Daily or almost daily
# 3           Stack Overflow;Stack Exchange           Multiple times per day
# 5           Stack Overflow;Stack Exchange            Daily or almost daily
# 6           Stack Overflow;Stack Exchange           Multiple times per day
# 10          Stack Overflow;Stack Exchange           Multiple times per day
# ...                                   ...                              ...
# 83430       Stack Overflow;Stack Exchange  A few times per month or weekly
# 83431       Stack Overflow;Stack Exchange             A few times per week
# 83432       Stack Overflow;Stack Exchange           Multiple times per day
# 83437       Stack Overflow;Stack Exchange             A few times per week
# 83438                      Stack Overflow  A few times per month or weekly
#
#                           SOAccount  \
# ResponseId
# 2                               Yes
# 3                               Yes
# 5                               Yes
# 6                               Yes
# 10                              Yes
# ...                             ...
# 83430       Not sure/can't remember
# 83431                            No
# 83432                           Yes
# 83437                           Yes
# 83438                           Yes
#
#                                                    SOPartFreq  \
# ResponseId
# 2                                       Daily or almost daily
# 3                                      Multiple times per day
# 5                                        A few times per week
# 6           I have never participated in Q&A on Stack Over...
# 10                                      Daily or almost daily
# ...                                                       ...
# 83430                                                     NaN
# 83431                                                     NaN
# 83432                         A few times per month or weekly
# 83437       I have never participated in Q&A on Stack Over...
# 83438                     Less than once per month or monthly
#
#                      SOComm NEWOtherComms              Age  \
# ResponseId
# 2           Yes, definitely            No  18-24 years old
# 3           Yes, definitely           Yes  18-24 years old
# 5             Yes, somewhat            No  25-34 years old
# 6             Yes, somewhat            No  18-24 years old
# 10            Yes, somewhat            No  25-34 years old
# ...                     ...           ...              ...
# 83430         Yes, somewhat            No  25-34 years old
# 83431        No, not really            No  45-54 years old
# 83432       Yes, definitely            No  18-24 years old
# 83437        No, not really            No  25-34 years old
# 83438        No, not really            No  25-34 years old
#
#                                 Gender Trans                Sexuality  \
# ResponseId
# 2                                  Man    No  Straight / Heterosexual
# 3                                  Man    No        Prefer not to say
# 5                                  Man    No                      NaN
# 6                    Prefer not to say    No  Straight / Heterosexual
# 10                                 Man    No  Straight / Heterosexual
# ...                                ...   ...                      ...
# 83430       Man;Or, in your own words:   Yes                    Queer
# 83431                              Man    No  Straight / Heterosexual
# 83432                              Man    No  Straight / Heterosexual
# 83437                              Man    No                      NaN
# 83438                              Man    No  Straight / Heterosexual
#
#                                Ethnicity  \
# ResponseId
# 2           White or of European descent
# 3                      Prefer not to say
# 5           White or of European descent
# 6                      Prefer not to say
# 10          White or of European descent
# ...                                  ...
# 83430       White or of European descent
# 83431       White or of European descent
# 83432                    Southeast Asian
# 83437       White or of European descent
# 83438       White or of European descent
#
#                                                 Accessibility  \
# ResponseId
# 2                                           None of the above
# 3                                           None of the above
# 5                                           None of the above
# 6                                           None of the above
# 10                                          None of the above
# ...                                                       ...
# 83430       I am unable to / find it difficult to walk or ...
# 83431                                       None of the above
# 83432                                       None of the above
# 83437                                       None of the above
# 83438                                       None of the above
#
#                                                  MentalHealth  \
# ResponseId
# 2                                           None of the above
# 3                                           None of the above
# 5                                                         NaN
# 6           I have a concentration and/or memory disorder ...
# 10                                          None of the above
# ...                                                       ...
# 83430                              I have an anxiety disorder
# 83431                                       None of the above
# 83432                                       None of the above
# 83437                                       None of the above
# 83438       I have a mood or emotional disorder (e.g. depr...
#
#                      SurveyLength                  SurveyEase  \
# ResponseId
# 2           Appropriate in length                        Easy
# 3           Appropriate in length                        Easy
# 5           Appropriate in length                        Easy
# 6                        Too long  Neither easy nor difficult
# 10          Appropriate in length  Neither easy nor difficult
# ...                           ...                         ...
# 83430       Appropriate in length  Neither easy nor difficult
# 83431       Appropriate in length                        Easy
# 83432       Appropriate in length                        Easy
# 83437       Appropriate in length  Neither easy nor difficult
# 83438       Appropriate in length  Neither easy nor difficult
#
#             ConvertedCompYearly
# ResponseId
# 2                           NaN
# 3                           NaN
# 5                           NaN
# 6                           NaN
# 10                      51552.0
# ...                         ...
# 83430                       NaN
# 83431                  125000.0
# 83432                   11676.0
# 83437                   90000.0
# 83438                  816816.0
#
# [39792 rows x 47 columns]

# %% [markdown]
# ## Updating Rows and Columns - Modifying Data Within DataFrames

# %%
ppl_df = pd.DataFrame(people)
ppl_df
# Out:
#        first      last                    email
# 0  SimoFirst  SimoLast  s.e.hristov99@gmail.com
# 1       Jane       Doe        JaneDoe@gmail.com
# 2       John       Doe        JohnDoe@gmail.com

# %% [markdown]
# **Column names**

# %%
# Rename all columns
ppl_df.columns = ['first_name', 'last_name', 'email']
ppl_df
# Out:
#   first_name last_name                    email
# 0  SimoFirst  SimoLast  s.e.hristov99@gmail.com
# 1       Jane       Doe        JaneDoe@gmail.com
# 2       John       Doe        JohnDoe@gmail.com

# %%
# Uppercase all of the column names
ppl_df.columns = ppl_df.columns.str.upper()
ppl_df
# Out:
#   FIRST_NAME LAST_NAME                    EMAIL
# 0  SimoFirst  SimoLast  s.e.hristov99@gmail.com
# 1       Jane       Doe        JaneDoe@gmail.com
# 2       John       Doe        JohnDoe@gmail.com

# %%
# Replace underlines with spaces
ppl_df.columns = ppl_df.columns.str.replace('_', ' ')
ppl_df
# Out:
#   FIRST NAME LAST NAME                    EMAIL
# 0  SimoFirst  SimoLast  s.e.hristov99@gmail.com
# 1       Jane       Doe        JaneDoe@gmail.com
# 2       John       Doe        JohnDoe@gmail.com

# %%
# Change only specific columns
ppl_df = ppl_df.rename(columns={
    'FIRST NAME': 'first',
    'LAST NAME': 'last',
})
ppl_df
# Out:
#        first      last                    EMAIL
# 0  SimoFirst  SimoLast  s.e.hristov99@gmail.com
# 1       Jane       Doe        JaneDoe@gmail.com
# 2       John       Doe        JohnDoe@gmail.com

# %% [markdown]
# **Row values**

# %%
ppl_df.columns = ['first', 'last', 'email']
ppl_df
# Out:
#        first      last                    email
# 0  SimoFirst  SimoLast  s.e.hristov99@gmail.com
# 1       Jane       Doe        JaneDoe@gmail.com
# 2       John       Doe        JohnDoe@gmail.com

# %%
# Task: Change John's last name to Smith
ppl_df.loc[2]
# Out:
# first                 John
# last                   Doe
# email    JohnDoe@gmail.com
# Name: 2, dtype: object

# %%
# solution 1: replace the whole sample
ppl_df.loc[2] = ['John', 'Smith', 'JohnSmith@email.com']
ppl_df
# Out:
#        first      last                    email
# 0  SimoFirst  SimoLast  s.e.hristov99@gmail.com
# 1       Jane       Doe        JaneDoe@gmail.com
# 2       John     Smith      JohnSmith@email.com

# %%
# solution 2: Change only the values for specific columns
ppl_df.loc[2, 'last'] = 'Smith'
ppl_df
# Out:
#        first      last                    email
# 0  SimoFirst  SimoLast  s.e.hristov99@gmail.com
# 1       Jane       Doe        JaneDoe@gmail.com
# 2       John     Smith      JohnSmith@email.com

# %%
# Change only the values for specific columns
ppl_df.loc[2, ['last', 'email']] = ['Doe', 'JohnDoe@email.com']
ppl_df
# Out:
#        first      last                    email
# 0  SimoFirst  SimoLast  s.e.hristov99@gmail.com
# 1       Jane       Doe        JaneDoe@gmail.com
# 2       John       Doe        JohnDoe@email.com

# %%
# Common mistake: Changing a value through a filter
filt = (ppl_df['email'] == 'JohnDoe@email.com')
ppl_df[filt]
# Out:
#   first last              email
# 2  John  Doe  JohnDoe@email.com

# %%
ppl_df[filt]['last'] = 'Smith'
ppl_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        first      last                    email
# 0  SimoFirst  SimoLast  s.e.hristov99@gmail.com
# 1       Jane       Doe        JaneDoe@gmail.com
# 2       John       Doe        JohnDoe@email.com

# %%
# Solution
ppl_df.loc[filt, 'last'] = 'Smith'
ppl_df
# Out:
#        first      last                    email
# 0  SimoFirst  SimoLast  s.e.hristov99@gmail.com
# 1       Jane       Doe        JaneDoe@gmail.com
# 2       John     Smith        JohnDoe@email.com

# %%
# Change all emails to lowercase.

# First way: just assign the column to its lowercase version.
ppl_df['email'] = ppl_df['email'].str.lower()
ppl_df
# Out:
#        first      last                    email
# 0  SimoFirst  SimoLast  s.e.hristov99@gmail.com
# 1       Jane       Doe        janedoe@gmail.com
# 2       John     Smith        johndoe@email.com

# %% [markdown]
# However, we could also use one of the following functions:
# - **map**: calling a function for every value in a series. *If the functions does not change a value, it replaces it with NaN*. ONLY WORKS ON SERIES
# - **replace**: calling a function for every value in a series. *If the functions does not change a value, it leaves it as it was*. ONLY WORKS ON SERIES
# - **apply**: calling a function for every value in a series or for every series in a dataframe.
# - **applymap**: calling a function for every value in a dataframe. ONLY WORKS ON DATAFRAMES

# %%
ppl_df['email'].apply(len)
# Out:
# 0    23
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
ppl_df['email'].apply(lambda email: email.upper())
# Out:
# 0    S.E.HRISTOV99@GMAIL.COM
# 1          JANEDOE@GMAIL.COM
# 2          JOHNDOE@EMAIL.COM
# Name: email, dtype: object

# %%
ppl_df['email'] = ppl_df['email'].apply(lambda email: email.upper())
ppl_df
# Out:
#        first      last                    email
# 0  SimoFirst  SimoLast  S.E.HRISTOV99@GMAIL.COM
# 1       Jane       Doe        JANEDOE@GMAIL.COM
# 2       John     Smith        JOHNDOE@EMAIL.COM

# %%
# The above examples, should not be that surprising, but see what it does when called for the dataframe
# It will apply the function to each of the row (series object).
ppl_df.apply(len) # Same as len(ppl_df['email'])
# Out:
# first    3
# last     3
# email    3
# dtype: int64

# %%
ppl_df.apply(len, axis='columns')
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
# Return the lexicographically smallest element for every row
ppl_df.apply(pd.Series.min)
# Out:
# first                 Jane
# last                   Doe
# email    JANEDOE@GMAIL.COM
# dtype: object

# %%
# Get the length of each string in the dataframe.
ppl_df.applymap(len)
# Out:
#    first  last  email
# 0      9     8     23
# 1      4     3     17
# 2      4     5     17

# %%
# Lowercase every string in the dataframe.
ppl_df.applymap(str.lower)
# Out:
#        first      last                    email
# 0  simofirst  simolast  s.e.hristov99@gmail.com
# 1       jane       doe        janedoe@gmail.com
# 2       john     smith        johndoe@email.com

# %%
# Get the length of every first name.
ppl_df['first'].map(len)
# Out:
# 0    9
# 1    4
# 2    4
# Name: first, dtype: int64

# %% [markdown]
# > **Note**: If you don't use the assignment operator (`=`), the dataframe stays unchanged.

# %%
ppl_df
# Out:
#        first      last                    email
# 0  SimoFirst  SimoLast  S.E.HRISTOV99@GMAIL.COM
# 1       Jane       Doe        JANEDOE@GMAIL.COM
# 2       John     Smith        JOHNDOE@EMAIL.COM

# %%
# Substitute certain values.
ppl_df['first'] = ppl_df['first'].map({
    'SimoFirst': 'firstsimo',
    'Jane': 'Jessy',
})
ppl_df
# Out:
#        first      last                    email
# 0  firstsimo  SimoLast  S.E.HRISTOV99@GMAIL.COM
# 1      Jessy       Doe        JANEDOE@GMAIL.COM
# 2        NaN     Smith        JOHNDOE@EMAIL.COM

# %%
ppl_df['last'] = ppl_df['last'].replace({
    'SimoLast': 'LastSimo',
    'Smith': 'Bobson',
})
ppl_df
# Out:
#        first      last                    email
# 0  firstsimo  LastSimo  S.E.HRISTOV99@GMAIL.COM
# 1      Jessy       Doe        JANEDOE@GMAIL.COM
# 2        NaN    Bobson        JOHNDOE@EMAIL.COM

# %%
# Rename the column that holds the yearly converted salary to `SalaryUSD`.
df.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
# 4                                          Employed full-time
# 5           Independent contractor, freelancer, or self-em...
#
#                                                       Country US_State  \
# ResponseId
# 1                                                    Slovakia      NaN
# 2                                                 Netherlands      NaN
# 3                                          Russian Federation      NaN
# 4                                                     Austria      NaN
# 5           United Kingdom of Great Britain and Northern I...      NaN
#
#            UK_Country                                            EdLevel  \
# ResponseId
# 1                 NaN  Secondary school (e.g. American high school, G...
# 2                 NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                 NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4                 NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5             England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                Age1stCode                                          LearnCode  \
# ResponseId
# 1           18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 2           11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3           11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 4           11 - 17 years                                                NaN
# 5            5 - 10 years                            Friend or family member
#
#            YearsCode YearsCodePro  \
# ResponseId
# 1                NaN          NaN
# 2                  7          NaN
# 3                NaN          NaN
# 4                NaN          NaN
# 5                 17           10
#
#                                                       DevType  \
# ResponseId
# 1                                           Developer, mobile
# 2                                                         NaN
# 3                                                         NaN
# 4                                        Developer, front-end
# 5           Developer, desktop or enterprise applications;...
#
#                                                       OrgSize  \
# ResponseId
# 1                                          20 to 99 employees
# 2                                                         NaN
# 3                                                         NaN
# 4                                        100 to 499 employees
# 5           Just me - I am a freelancer, sole proprietor, ...
#
#                        Currency  CompTotal CompFreq  \
# ResponseId
# 1             EUR European Euro     4800.0  Monthly
# 2                           NaN        NaN      NaN
# 3                           NaN        NaN      NaN
# 4             EUR European Euro        NaN  Monthly
# 5           GBP\tPound sterling        NaN      NaN
#
#                                    LanguageHaveWorkedWith  \
# ResponseId
# 1           C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 2                                       JavaScript;Python
# 3                                Assembly;C;Python;R;Rust
# 4                                   JavaScript;TypeScript
# 5                          Bash/Shell;HTML/CSS;Python;SQL
#
#                     LanguageWantToWorkWith          DatabaseHaveWorkedWith  \
# ResponseId
# 1                                    Swift               PostgreSQL;SQLite
# 2                                      NaN                      PostgreSQL
# 3                        Julia;Python;Rust                          SQLite
# 4                    JavaScript;TypeScript                             NaN
# 5           Bash/Shell;HTML/CSS;Python;SQL  Elasticsearch;PostgreSQL;Redis
#
#                               DatabaseWantToWorkWith PlatformHaveWorkedWith  \
# ResponseId
# 1                                             SQLite                    NaN
# 2                                                NaN                    NaN
# 3                                             SQLite                 Heroku
# 4                                                NaN                    NaN
# 5           Cassandra;Elasticsearch;PostgreSQL;Redis                    NaN
#
#            PlatformWantToWorkWith WebframeHaveWorkedWith  \
# ResponseId
# 1                             NaN        Laravel;Symfony
# 2                             NaN   Angular;Flask;Vue.js
# 3                             NaN                  Flask
# 4                             NaN         Angular;jQuery
# 5                             NaN                  Flask
#
#            WebframeWantToWorkWith                 MiscTechHaveWorkedWith  \
# ResponseId
# 1                             NaN                                    NaN
# 2                             NaN                                Cordova
# 3                           Flask  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 4                  Angular;jQuery                                    NaN
# 5                           Flask       Apache Spark;Hadoop;NumPy;Pandas
#
#                                  MiscTechWantToWorkWith  \
# ResponseId
# 1                                                   NaN
# 2                                                   NaN
# 3           Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 4                                                   NaN
# 5                                   Hadoop;NumPy;Pandas
#
#                ToolsTechHaveWorkedWith     ToolsTechWantToWorkWith  \
# ResponseId
# 1                                  NaN                         NaN
# 2                      Docker;Git;Yarn                         Git
# 3                                  NaN                         NaN
# 4                                  NaN                         NaN
# 5           Docker;Git;Kubernetes;Yarn  Docker;Git;Kubernetes;Yarn
#
#                                  NEWCollabToolsHaveWorkedWith  \
# ResponseId
# 1                                              PHPStorm;Xcode
# 2                   Android Studio;IntelliJ;Notepad++;PyCharm
# 3           IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 4                                                         NaN
# 5                  Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
#
#                                  NEWCollabToolsWantToWorkWith        OpSys  \
# ResponseId
# 1                                                  Atom;Xcode        MacOS
# 2                                                         NaN      Windows
# 3           IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 4                                                         NaN      Windows
# 5           Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
#
#                                                      NEWStuck  \
# ResponseId
# 1           Call a coworker or friend;Visit Stack Overflow...
# 2                              Visit Stack Overflow;Google it
# 3           Visit Stack Overflow;Google it;Watch help / tu...
# 4           Call a coworker or friend;Visit Stack Overflow...
# 5           Visit Stack Overflow;Go for a walk or other ph...
#
#                                NEWSOSites             SOVisitFreq SOAccount  \
# ResponseId
# 1                          Stack Overflow  Multiple times per day       Yes
# 2                          Stack Overflow   Daily or almost daily       Yes
# 3           Stack Overflow;Stack Exchange  Multiple times per day       Yes
# 4                          Stack Overflow   Daily or almost daily       Yes
# 5           Stack Overflow;Stack Exchange   Daily or almost daily       Yes
#
#                                  SOPartFreq           SOComm NEWOtherComms  \
# ResponseId
# 1           A few times per month or weekly  Yes, definitely            No
# 2                     Daily or almost daily  Yes, definitely            No
# 3                    Multiple times per day  Yes, definitely           Yes
# 4                     Daily or almost daily          Neutral            No
# 5                      A few times per week    Yes, somewhat            No
#
#                         Age Gender Trans                Sexuality  \
# ResponseId
# 1           25-34 years old    Man    No  Straight / Heterosexual
# 2           18-24 years old    Man    No  Straight / Heterosexual
# 3           18-24 years old    Man    No        Prefer not to say
# 4           35-44 years old    Man    No  Straight / Heterosexual
# 5           25-34 years old    Man    No                      NaN
#
#                                Ethnicity                Accessibility  \
# ResponseId
# 1           White or of European descent            None of the above
# 2           White or of European descent            None of the above
# 3                      Prefer not to say            None of the above
# 4           White or of European descent  I am deaf / hard of hearing
# 5           White or of European descent            None of the above
#
#                  MentalHealth           SurveyLength  \
# ResponseId
# 1           None of the above  Appropriate in length
# 2           None of the above  Appropriate in length
# 3           None of the above  Appropriate in length
# 4                         NaN  Appropriate in length
# 5                         NaN  Appropriate in length
#
#                             SurveyEase  ConvertedCompYearly
# ResponseId
# 1                                 Easy              62268.0
# 2                                 Easy                  NaN
# 3                                 Easy                  NaN
# 4           Neither easy nor difficult                  NaN
# 5                                 Easy                  NaN

# %%
df = df.rename(columns={
    'ConvertedCompYearly': 'SalaryUSD'
})
df.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
# 4                                          Employed full-time
# 5           Independent contractor, freelancer, or self-em...
#
#                                                       Country US_State  \
# ResponseId
# 1                                                    Slovakia      NaN
# 2                                                 Netherlands      NaN
# 3                                          Russian Federation      NaN
# 4                                                     Austria      NaN
# 5           United Kingdom of Great Britain and Northern I...      NaN
#
#            UK_Country                                            EdLevel  \
# ResponseId
# 1                 NaN  Secondary school (e.g. American high school, G...
# 2                 NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                 NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4                 NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5             England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                Age1stCode                                          LearnCode  \
# ResponseId
# 1           18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 2           11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3           11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 4           11 - 17 years                                                NaN
# 5            5 - 10 years                            Friend or family member
#
#            YearsCode YearsCodePro  \
# ResponseId
# 1                NaN          NaN
# 2                  7          NaN
# 3                NaN          NaN
# 4                NaN          NaN
# 5                 17           10
#
#                                                       DevType  \
# ResponseId
# 1                                           Developer, mobile
# 2                                                         NaN
# 3                                                         NaN
# 4                                        Developer, front-end
# 5           Developer, desktop or enterprise applications;...
#
#                                                       OrgSize  \
# ResponseId
# 1                                          20 to 99 employees
# 2                                                         NaN
# 3                                                         NaN
# 4                                        100 to 499 employees
# 5           Just me - I am a freelancer, sole proprietor, ...
#
#                        Currency  CompTotal CompFreq  \
# ResponseId
# 1             EUR European Euro     4800.0  Monthly
# 2                           NaN        NaN      NaN
# 3                           NaN        NaN      NaN
# 4             EUR European Euro        NaN  Monthly
# 5           GBP\tPound sterling        NaN      NaN
#
#                                    LanguageHaveWorkedWith  \
# ResponseId
# 1           C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 2                                       JavaScript;Python
# 3                                Assembly;C;Python;R;Rust
# 4                                   JavaScript;TypeScript
# 5                          Bash/Shell;HTML/CSS;Python;SQL
#
#                     LanguageWantToWorkWith          DatabaseHaveWorkedWith  \
# ResponseId
# 1                                    Swift               PostgreSQL;SQLite
# 2                                      NaN                      PostgreSQL
# 3                        Julia;Python;Rust                          SQLite
# 4                    JavaScript;TypeScript                             NaN
# 5           Bash/Shell;HTML/CSS;Python;SQL  Elasticsearch;PostgreSQL;Redis
#
#                               DatabaseWantToWorkWith PlatformHaveWorkedWith  \
# ResponseId
# 1                                             SQLite                    NaN
# 2                                                NaN                    NaN
# 3                                             SQLite                 Heroku
# 4                                                NaN                    NaN
# 5           Cassandra;Elasticsearch;PostgreSQL;Redis                    NaN
#
#            PlatformWantToWorkWith WebframeHaveWorkedWith  \
# ResponseId
# 1                             NaN        Laravel;Symfony
# 2                             NaN   Angular;Flask;Vue.js
# 3                             NaN                  Flask
# 4                             NaN         Angular;jQuery
# 5                             NaN                  Flask
#
#            WebframeWantToWorkWith                 MiscTechHaveWorkedWith  \
# ResponseId
# 1                             NaN                                    NaN
# 2                             NaN                                Cordova
# 3                           Flask  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 4                  Angular;jQuery                                    NaN
# 5                           Flask       Apache Spark;Hadoop;NumPy;Pandas
#
#                                  MiscTechWantToWorkWith  \
# ResponseId
# 1                                                   NaN
# 2                                                   NaN
# 3           Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 4                                                   NaN
# 5                                   Hadoop;NumPy;Pandas
#
#                ToolsTechHaveWorkedWith     ToolsTechWantToWorkWith  \
# ResponseId
# 1                                  NaN                         NaN
# 2                      Docker;Git;Yarn                         Git
# 3                                  NaN                         NaN
# 4                                  NaN                         NaN
# 5           Docker;Git;Kubernetes;Yarn  Docker;Git;Kubernetes;Yarn
#
#                                  NEWCollabToolsHaveWorkedWith  \
# ResponseId
# 1                                              PHPStorm;Xcode
# 2                   Android Studio;IntelliJ;Notepad++;PyCharm
# 3           IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 4                                                         NaN
# 5                  Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
#
#                                  NEWCollabToolsWantToWorkWith        OpSys  \
# ResponseId
# 1                                                  Atom;Xcode        MacOS
# 2                                                         NaN      Windows
# 3           IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 4                                                         NaN      Windows
# 5           Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
#
#                                                      NEWStuck  \
# ResponseId
# 1           Call a coworker or friend;Visit Stack Overflow...
# 2                              Visit Stack Overflow;Google it
# 3           Visit Stack Overflow;Google it;Watch help / tu...
# 4           Call a coworker or friend;Visit Stack Overflow...
# 5           Visit Stack Overflow;Go for a walk or other ph...
#
#                                NEWSOSites             SOVisitFreq SOAccount  \
# ResponseId
# 1                          Stack Overflow  Multiple times per day       Yes
# 2                          Stack Overflow   Daily or almost daily       Yes
# 3           Stack Overflow;Stack Exchange  Multiple times per day       Yes
# 4                          Stack Overflow   Daily or almost daily       Yes
# 5           Stack Overflow;Stack Exchange   Daily or almost daily       Yes
#
#                                  SOPartFreq           SOComm NEWOtherComms  \
# ResponseId
# 1           A few times per month or weekly  Yes, definitely            No
# 2                     Daily or almost daily  Yes, definitely            No
# 3                    Multiple times per day  Yes, definitely           Yes
# 4                     Daily or almost daily          Neutral            No
# 5                      A few times per week    Yes, somewhat            No
#
#                         Age Gender Trans                Sexuality  \
# ResponseId
# 1           25-34 years old    Man    No  Straight / Heterosexual
# 2           18-24 years old    Man    No  Straight / Heterosexual
# 3           18-24 years old    Man    No        Prefer not to say
# 4           35-44 years old    Man    No  Straight / Heterosexual
# 5           25-34 years old    Man    No                      NaN
#
#                                Ethnicity                Accessibility  \
# ResponseId
# 1           White or of European descent            None of the above
# 2           White or of European descent            None of the above
# 3                      Prefer not to say            None of the above
# 4           White or of European descent  I am deaf / hard of hearing
# 5           White or of European descent            None of the above
#
#                  MentalHealth           SurveyLength  \
# ResponseId
# 1           None of the above  Appropriate in length
# 2           None of the above  Appropriate in length
# 3           None of the above  Appropriate in length
# 4                         NaN  Appropriate in length
# 5                         NaN  Appropriate in length
#
#                             SurveyEase  SalaryUSD
# ResponseId
# 1                                 Easy    62268.0
# 2                                 Easy        NaN
# 3                                 Easy        NaN
# 4           Neither easy nor difficult        NaN
# 5                                 Easy        NaN

# %%
df['SalaryUSD']
# Out:
# ResponseId
# 1         62268.0
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
#            ...
# 83435    160500.0
# 83436      3960.0
# 83437     90000.0
# 83438    816816.0
# 83439     21168.0
# Name: SalaryUSD, Length: 83439, dtype: float64

# %%
# Convert every 'Yes' to True and every 'No' value to False.
df['SOAccount'] = df['SOAccount'].map({'Yes': True, 'No': False})

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
# 4                                          Employed full-time
# 5           Independent contractor, freelancer, or self-em...
# ...                                                       ...
# 83435                                      Employed full-time
# 83436       Independent contractor, freelancer, or self-em...
# 83437                                      Employed full-time
# 83438                                      Employed full-time
# 83439                                      Employed full-time
#
#                                                       Country    US_State  \
# ResponseId
# 1                                                    Slovakia         NaN
# 2                                                 Netherlands         NaN
# 3                                          Russian Federation         NaN
# 4                                                     Austria         NaN
# 5           United Kingdom of Great Britain and Northern I...         NaN
# ...                                                       ...         ...
# 83435                                United States of America       Texas
# 83436                                                   Benin         NaN
# 83437                                United States of America  New Jersey
# 83438                                                  Canada         NaN
# 83439                                                  Brazil         NaN
#
#            UK_Country                                            EdLevel  \
# ResponseId
# 1                 NaN  Secondary school (e.g. American high school, G...
# 2                 NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                 NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4                 NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5             England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...               ...                                                ...
# 83435             NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436             NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83437             NaN  Secondary school (e.g. American high school, G...
# 83438             NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83439             NaN                 Professional degree (JD, MD, etc.)
#
#                Age1stCode                                          LearnCode  \
# ResponseId
# 1           18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 2           11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3           11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 4           11 - 17 years                                                NaN
# 5            5 - 10 years                            Friend or family member
# ...                   ...                                                ...
# 83435       11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436       11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83437       11 - 17 years                                             School
# 83438       11 - 17 years  Online Courses or Certification;Books / Physic...
# 83439       11 - 17 years                                             School
#
#            YearsCode YearsCodePro  \
# ResponseId
# 1                NaN          NaN
# 2                  7          NaN
# 3                NaN          NaN
# 4                NaN          NaN
# 5                 17           10
# ...              ...          ...
# 83435              6            5
# 83436              4            2
# 83437             10            4
# 83438              5            3
# 83439             14            4
#
#                                                       DevType  \
# ResponseId
# 1                                           Developer, mobile
# 2                                                         NaN
# 3                                                         NaN
# 4                                        Developer, front-end
# 5           Developer, desktop or enterprise applications;...
# ...                                                       ...
# 83435                                     Developer, back-end
# 83436                                   Developer, full-stack
# 83437       Data scientist or machine learning specialist;...
# 83438                                     Developer, back-end
# 83439       Developer, front-end;Developer, full-stack;Dev...
#
#                                                       OrgSize  \
# ResponseId
# 1                                          20 to 99 employees
# 2                                                         NaN
# 3                                                         NaN
# 4                                        100 to 499 employees
# 5           Just me - I am a freelancer, sole proprietor, ...
# ...                                                       ...
# 83435                                      20 to 99 employees
# 83436       Just me - I am a freelancer, sole proprietor, ...
# 83437                                10,000 or more employees
# 83438                                      20 to 99 employees
# 83439                                            I don’t know
#
#                                Currency  CompTotal CompFreq  \
# ResponseId
# 1                     EUR European Euro     4800.0  Monthly
# 2                                   NaN        NaN      NaN
# 3                                   NaN        NaN      NaN
# 4                     EUR European Euro        NaN  Monthly
# 5                   GBP\tPound sterling        NaN      NaN
# ...                                 ...        ...      ...
# 83435         USD\tUnited States dollar   160500.0   Yearly
# 83436       XOF\tWest African CFA franc   200000.0  Monthly
# 83437         USD\tUnited States dollar     1800.0   Weekly
# 83438              CAD\tCanadian dollar    90000.0  Monthly
# 83439               BRL\tBrazilian real     7700.0  Monthly
#
#                                    LanguageHaveWorkedWith  \
# ResponseId
# 1           C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 2                                       JavaScript;Python
# 3                                Assembly;C;Python;R;Rust
# 4                                   JavaScript;TypeScript
# 5                          Bash/Shell;HTML/CSS;Python;SQL
# ...                                                   ...
# 83435                                  Clojure;Kotlin;SQL
# 83436                                                 NaN
# 83437                                  Groovy;Java;Python
# 83438                Bash/Shell;JavaScript;Node.js;Python
# 83439              Delphi;Elixir;HTML/CSS;Java;JavaScript
#
#                                        LanguageWantToWorkWith  \
# ResponseId
# 1                                                       Swift
# 2                                                         NaN
# 3                                           Julia;Python;Rust
# 4                                       JavaScript;TypeScript
# 5                              Bash/Shell;HTML/CSS;Python;SQL
# ...                                                       ...
# 83435                                                 Clojure
# 83436                                                     NaN
# 83437                                             Java;Python
# 83438                                                 Go;Rust
# 83439       Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
#
#                                       DatabaseHaveWorkedWith  \
# ResponseId
# 1                                          PostgreSQL;SQLite
# 2                                                 PostgreSQL
# 3                                                     SQLite
# 4                                                        NaN
# 5                             Elasticsearch;PostgreSQL;Redis
# ...                                                      ...
# 83435                                          Oracle;SQLite
# 83436         Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83437        DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438       Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83439                                      Oracle;PostgreSQL
#
#                                        DatabaseWantToWorkWith  \
# ResponseId
# 1                                                      SQLite
# 2                                                         NaN
# 3                                                      SQLite
# 4                                                         NaN
# 5                    Cassandra;Elasticsearch;PostgreSQL;Redis
# ...                                                       ...
# 83435                                                  SQLite
# 83436       Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83437                                          DynamoDB;Redis
# 83438                                                     NaN
# 83439       Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
#
#                PlatformHaveWorkedWith PlatformWantToWorkWith  \
# ResponseId
# 1                                 NaN                    NaN
# 2                                 NaN                    NaN
# 3                              Heroku                    NaN
# 4                                 NaN                    NaN
# 5                                 NaN                    NaN
# ...                               ...                    ...
# 83435                             AWS                    AWS
# 83436                             NaN                    NaN
# 83437       AWS;Google Cloud Platform                    AWS
# 83438                          Heroku       AWS;DigitalOcean
# 83439                 Microsoft Azure                    AWS
#
#                                   WebframeHaveWorkedWith  \
# ResponseId
# 1                                        Laravel;Symfony
# 2                                   Angular;Flask;Vue.js
# 3                                                  Flask
# 4                                         Angular;jQuery
# 5                                                  Flask
# ...                                                  ...
# 83435                                                NaN
# 83436       Django;jQuery;Laravel;React.js;Ruby on Rails
# 83437                                      FastAPI;Flask
# 83438                      Django;Express;Flask;React.js
# 83439                                     Angular;Spring
#
#                                        WebframeWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                                                       Flask
# 4                                              Angular;jQuery
# 5                                                       Flask
# ...                                                       ...
# 83435                                                     NaN
# 83436       Django;Express;jQuery;Laravel;React.js;Ruby on...
# 83437                                           FastAPI;Flask
# 83438                                                     NaN
# 83439                          Express;Laravel;Spring;Symfony
#
#                            MiscTechHaveWorkedWith  \
# ResponseId
# 1                                             NaN
# 2                                         Cordova
# 3           NumPy;Pandas;TensorFlow;Torch/PyTorch
# 4                                             NaN
# 5                Apache Spark;Hadoop;NumPy;Pandas
# ...                                           ...
# 83435                                         NaN
# 83436                                  Flutter;Qt
# 83437                   Hadoop;Keras;NumPy;Pandas
# 83438       NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83439                                         NaN
#
#                                        MiscTechWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                 Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 4                                                         NaN
# 5                                         Hadoop;NumPy;Pandas
# ...                                                       ...
# 83435                                                     NaN
# 83436                                                     NaN
# 83437       Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83438                   NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83439                                                     NaN
#
#                  ToolsTechHaveWorkedWith          ToolsTechWantToWorkWith  \
# ResponseId
# 1                                    NaN                              NaN
# 2                        Docker;Git;Yarn                              Git
# 3                                    NaN                              NaN
# 4                                    NaN                              NaN
# 5             Docker;Git;Kubernetes;Yarn       Docker;Git;Kubernetes;Yarn
# ...                                  ...                              ...
# 83435                         Docker;Git                   Git;Kubernetes
# 83436         Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83437       Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83438       Ansible;Docker;Git;Terraform             Kubernetes;Terraform
# 83439                         Docker;Git            Docker;Git;Kubernetes
#
#                                  NEWCollabToolsHaveWorkedWith  \
# ResponseId
# 1                                              PHPStorm;Xcode
# 2                   Android Studio;IntelliJ;Notepad++;PyCharm
# 3           IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 4                                                         NaN
# 5                  Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# ...                                                       ...
# 83435            IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83436       Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83437       Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83438                                    PyCharm;Sublime Text
# 83439                             IntelliJ;Visual Studio Code
#
#                                  NEWCollabToolsWantToWorkWith        OpSys  \
# ResponseId
# 1                                                  Atom;Xcode        MacOS
# 2                                                         NaN      Windows
# 3           IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 4                                                         NaN      Windows
# 5           Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# ...                                                       ...          ...
# 83435                                        Sublime Text;Vim        MacOS
# 83436       Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83437                  IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83438                                                     NaN        MacOS
# 83439                    IntelliJ;PHPStorm;Visual Studio Code  Linux-based
#
#                                                      NEWStuck  \
# ResponseId
# 1           Call a coworker or friend;Visit Stack Overflow...
# 2                              Visit Stack Overflow;Google it
# 3           Visit Stack Overflow;Google it;Watch help / tu...
# 4           Call a coworker or friend;Visit Stack Overflow...
# 5           Visit Stack Overflow;Go for a walk or other ph...
# ...                                                       ...
# 83435                     Call a coworker or friend;Google it
# 83436       Call a coworker or friend;Visit Stack Overflow...
# 83437       Call a coworker or friend;Visit Stack Overflow...
# 83438       Call a coworker or friend;Visit Stack Overflow...
# 83439       Call a coworker or friend;Visit Stack Overflow...
#
#                                                    NEWSOSites  \
# ResponseId
# 1                                              Stack Overflow
# 2                                              Stack Overflow
# 3                               Stack Overflow;Stack Exchange
# 4                                              Stack Overflow
# 5                               Stack Overflow;Stack Exchange
# ...                                                       ...
# 83435                           Stack Overflow;Stack Exchange
# 83436                           Stack Overflow;Stack Exchange
# 83437                           Stack Overflow;Stack Exchange
# 83438                                          Stack Overflow
# 83439       Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                                 SOVisitFreq SOAccount  \
# ResponseId
# 1                    Multiple times per day      True
# 2                     Daily or almost daily      True
# 3                    Multiple times per day      True
# 4                     Daily or almost daily      True
# 5                     Daily or almost daily      True
# ...                                     ...       ...
# 83435                  A few times per week     False
# 83436                Multiple times per day      True
# 83437                  A few times per week      True
# 83438       A few times per month or weekly      True
# 83439                  A few times per week      True
#
#                                                    SOPartFreq  \
# ResponseId
# 1                             A few times per month or weekly
# 2                                       Daily or almost daily
# 3                                      Multiple times per day
# 4                                       Daily or almost daily
# 5                                        A few times per week
# ...                                                       ...
# 83435                                                     NaN
# 83436       I have never participated in Q&A on Stack Over...
# 83437       I have never participated in Q&A on Stack Over...
# 83438                     Less than once per month or monthly
# 83439                                    A few times per week
#
#                      SOComm NEWOtherComms              Age Gender Trans  \
# ResponseId
# 1           Yes, definitely            No  25-34 years old    Man    No
# 2           Yes, definitely            No  18-24 years old    Man    No
# 3           Yes, definitely           Yes  18-24 years old    Man    No
# 4                   Neutral            No  35-44 years old    Man    No
# 5             Yes, somewhat            No  25-34 years old    Man    No
# ...                     ...           ...              ...    ...   ...
# 83435        No, not at all            No  25-34 years old    Man    No
# 83436         Yes, somewhat            No  18-24 years old    Man    No
# 83437        No, not really            No  25-34 years old    Man    No
# 83438        No, not really            No  25-34 years old    Man    No
# 83439         Yes, somewhat            No  18-24 years old    Man    No
#
#                           Sexuality                     Ethnicity  \
# ResponseId
# 1           Straight / Heterosexual  White or of European descent
# 2           Straight / Heterosexual  White or of European descent
# 3                 Prefer not to say             Prefer not to say
# 4           Straight / Heterosexual  White or of European descent
# 5                               NaN  White or of European descent
# ...                             ...                           ...
# 83435       Straight / Heterosexual  White or of European descent
# 83436       Straight / Heterosexual   Black or of African descent
# 83437                           NaN  White or of European descent
# 83438       Straight / Heterosexual  White or of European descent
# 83439       Straight / Heterosexual        Hispanic or Latino/a/x
#
#                           Accessibility  \
# ResponseId
# 1                     None of the above
# 2                     None of the above
# 3                     None of the above
# 4           I am deaf / hard of hearing
# 5                     None of the above
# ...                                 ...
# 83435                 None of the above
# 83436                 None of the above
# 83437                 None of the above
# 83438                 None of the above
# 83439                 None of the above
#
#                                                  MentalHealth  \
# ResponseId
# 1                                           None of the above
# 2                                           None of the above
# 3                                           None of the above
# 4                                                         NaN
# 5                                                         NaN
# ...                                                       ...
# 83435       I have a concentration and/or memory disorder ...
# 83436                                       None of the above
# 83437                                       None of the above
# 83438       I have a mood or emotional disorder (e.g. depr...
# 83439                                       None of the above
#
#                      SurveyLength                  SurveyEase  SalaryUSD
# ResponseId
# 1           Appropriate in length                        Easy    62268.0
# 2           Appropriate in length                        Easy        NaN
# 3           Appropriate in length                        Easy        NaN
# 4           Appropriate in length  Neither easy nor difficult        NaN
# 5           Appropriate in length                        Easy        NaN
# ...                           ...                         ...        ...
# 83435       Appropriate in length                        Easy   160500.0
# 83436       Appropriate in length                        Easy     3960.0
# 83437       Appropriate in length  Neither easy nor difficult    90000.0
# 83438       Appropriate in length  Neither easy nor difficult   816816.0
# 83439       Appropriate in length                        Easy    21168.0
#
# [83439 rows x 47 columns]

# %% [markdown]
# ## Add/Remove Rows and Columns From DataFrames

# %%
ppl_df = pd.DataFrame(people)
ppl_df
# Out:
#        first      last                    email
# 0  SimoFirst  SimoLast  s.e.hristov99@gmail.com
# 1       Jane       Doe        JaneDoe@gmail.com
# 2       John       Doe        JohnDoe@gmail.com

# %%
# Add a new column called `name` which is the concatenation of the `first` and `last` columns.
ppl_df['name'] = ppl_df['first'] + ' ' + ppl_df['last']  # ppl_df.name will not work, because Python will think that it already exists
ppl_df
# Out:
#        first      last                    email                name
# 0  SimoFirst  SimoLast  s.e.hristov99@gmail.com  SimoFirst SimoLast
# 1       Jane       Doe        JaneDoe@gmail.com            Jane Doe
# 2       John       Doe        JohnDoe@gmail.com            John Doe

# %%
# Remove the `first` and `last` columns.
ppl_df = ppl_df.drop(['first', 'last'], axis=1)
ppl_df
# Out:
#                      email                name
# 0  s.e.hristov99@gmail.com  SimoFirst SimoLast
# 1        JaneDoe@gmail.com            Jane Doe
# 2        JohnDoe@gmail.com            John Doe

# %%
# Split the `name` column into two new columns.
ppl_df['name'].str.split()
# Out:
# 0    [SimoFirst, SimoLast]
# 1              [Jane, Doe]
# 2              [John, Doe]
# Name: name, dtype: object

# %%
ppl_df['name'].str.split(expand=True)
# Out:
#            0         1
# 0  SimoFirst  SimoLast
# 1       Jane       Doe
# 2       John       Doe

# %%
ppl_df[['first', 'last']] = ppl_df['name'].str.split(expand=True)
ppl_df
# Out:
#                      email                name      first      last
# 0  s.e.hristov99@gmail.com  SimoFirst SimoLast  SimoFirst  SimoLast
# 1        JaneDoe@gmail.com            Jane Doe       Jane       Doe
# 2        JohnDoe@gmail.com            John Doe       John       Doe

# %%
# Add a row of data.
ppl_df.append({'first': 'Elon'}, ignore_index=True)
# Out:
#                      email                name      first      last
# 0  s.e.hristov99@gmail.com  SimoFirst SimoLast  SimoFirst  SimoLast
# 1        JaneDoe@gmail.com            Jane Doe       Jane       Doe
# 2        JohnDoe@gmail.com            John Doe       John       Doe
# 3                      NaN                 NaN       Elon       NaN

# %%
# Note again that this actually returns a new dataframe and doesn't change the current one.
ppl_df
# Out:
#                      email                name      first      last
# 0  s.e.hristov99@gmail.com  SimoFirst SimoLast  SimoFirst  SimoLast
# 1        JaneDoe@gmail.com            Jane Doe       Jane       Doe
# 2        JohnDoe@gmail.com            John Doe       John       Doe

# %%
# Concatenate dataframes.
people = {
  'first': ['Bob', 'John'],
  'last': ['Bobson', 'Johnson'],
  'email': ['bob@email.com', 'john@email.com']
}
ppl_df2 = pd.DataFrame(people)
# Note that the columns don't match in order and in number. Also, there are conflicting indices.
ppl_df2
# Out:
#   first     last           email
# 0   Bob   Bobson   bob@email.com
# 1  John  Johnson  john@email.com

# %%
ppl_df = ppl_df.append(ppl_df2, ignore_index=True)
ppl_df
# Out:
#                      email                name      first      last
# 0  s.e.hristov99@gmail.com  SimoFirst SimoLast  SimoFirst  SimoLast
# 1        JaneDoe@gmail.com            Jane Doe       Jane       Doe
# 2        JohnDoe@gmail.com            John Doe       John       Doe
# 3            bob@email.com                 NaN        Bob    Bobson
# 4           john@email.com                 NaN       John   Johnson

# %%
# Remove rows by index.
ppl_df.drop(index=3)
# Out:
#                      email                name      first      last
# 0  s.e.hristov99@gmail.com  SimoFirst SimoLast  SimoFirst  SimoLast
# 1        JaneDoe@gmail.com            Jane Doe       Jane       Doe
# 2        JohnDoe@gmail.com            John Doe       John       Doe
# 4           john@email.com                 NaN       John   Johnson

# %%
# Remove columns by a predicate

# Remove all rows that have last name `Doe`.
pred = (ppl_df['last'] == 'Doe')
ppl_df.drop(index=ppl_df[pred].index)
# Out:
#                      email                name      first      last
# 0  s.e.hristov99@gmail.com  SimoFirst SimoLast  SimoFirst  SimoLast
# 3            bob@email.com                 NaN        Bob    Bobson
# 4           john@email.com                 NaN       John   Johnson

# %% [markdown]
# ## Sorting Data

# %%
# Add a new entry `Adam`.
ppl_df = ppl_df.append({
    'first': 'Adam',
    'last': 'Doe',
    'email': 'a@email.com',
}, ignore_index=True)
ppl_df
# Out:
#                      email                name      first      last
# 0  s.e.hristov99@gmail.com  SimoFirst SimoLast  SimoFirst  SimoLast
# 1        JaneDoe@gmail.com            Jane Doe       Jane       Doe
# 2        JohnDoe@gmail.com            John Doe       John       Doe
# 3            bob@email.com                 NaN        Bob    Bobson
# 4           john@email.com                 NaN       John   Johnson
# 5              a@email.com                 NaN       Adam       Doe

# %%
# Drop the name column.
ppl_df = ppl_df.drop(['name'], axis=1)
ppl_df
# Out:
#                      email      first      last
# 0  s.e.hristov99@gmail.com  SimoFirst  SimoLast
# 1        JaneDoe@gmail.com       Jane       Doe
# 2        JohnDoe@gmail.com       John       Doe
# 3            bob@email.com        Bob    Bobson
# 4           john@email.com       John   Johnson
# 5              a@email.com       Adam       Doe

# %%
# Sort values by last name in ascending order.
ppl_df.sort_values(by='last')
# Out:
#                      email      first      last
# 3            bob@email.com        Bob    Bobson
# 1        JaneDoe@gmail.com       Jane       Doe
# 2        JohnDoe@gmail.com       John       Doe
# 5              a@email.com       Adam       Doe
# 4           john@email.com       John   Johnson
# 0  s.e.hristov99@gmail.com  SimoFirst  SimoLast

# %%
# Sort values by last name in descending order.
ppl_df.sort_values(by='last', ascending=False)
# Out:
#                      email      first      last
# 0  s.e.hristov99@gmail.com  SimoFirst  SimoLast
# 4           john@email.com       John   Johnson
# 1        JaneDoe@gmail.com       Jane       Doe
# 2        JohnDoe@gmail.com       John       Doe
# 5              a@email.com       Adam       Doe
# 3            bob@email.com        Bob    Bobson

# %%
# Sort by multiple columns.
ppl_df.sort_values(by=['last', 'first'], ascending=False)
# Out:
#                      email      first      last
# 0  s.e.hristov99@gmail.com  SimoFirst  SimoLast
# 4           john@email.com       John   Johnson
# 2        JohnDoe@gmail.com       John       Doe
# 1        JaneDoe@gmail.com       Jane       Doe
# 5              a@email.com       Adam       Doe
# 3            bob@email.com        Bob    Bobson

# %%
# Sort the last name in descending order but sort the first name in ascending order.
ppl_df.sort_values(by=['last', 'first'], ascending=[False, True])
# Out:
#                      email      first      last
# 0  s.e.hristov99@gmail.com  SimoFirst  SimoLast
# 4           john@email.com       John   Johnson
# 5              a@email.com       Adam       Doe
# 1        JaneDoe@gmail.com       Jane       Doe
# 2        JohnDoe@gmail.com       John       Doe
# 3            bob@email.com        Bob    Bobson

# %%
# Notice how the indices are not sorted. Let's ignore them when sorting the values.
ppl_df = ppl_df.sort_values(by=['last', 'first'], ascending=[False, True], ignore_index=True)
ppl_df
# Out:
#                      email      first      last
# 0  s.e.hristov99@gmail.com  SimoFirst  SimoLast
# 1           john@email.com       John   Johnson
# 2              a@email.com       Adam       Doe
# 3        JaneDoe@gmail.com       Jane       Doe
# 4        JohnDoe@gmail.com       John       Doe
# 5            bob@email.com        Bob    Bobson

# %%
# We can also sort series objects.
ppl_df['last'].sort_values()
# Out:
# 5      Bobson
# 2         Doe
# 3         Doe
# 4         Doe
# 1     Johnson
# 0    SimoLast
# Name: last, dtype: object

# %%
# Sort result by country name.
df = df.sort_values(by='Country')
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 37432                  I am a student who is learning to code
# 11462                          I am a developer by profession
# 67131                          I am a developer by profession
# 62971       I am not primarily a developer, but I write co...
# 14883                          I am a developer by profession
# ...                                                       ...
# 13195                          I am a developer by profession
# 80997                             I code primarily as a hobby
# 73742                          I am a developer by profession
# 73193                          I am a developer by profession
# 38429                          I am a developer by profession
#
#                                         Employment      Country US_State  \
# ResponseId
# 37432                           Student, part-time  Afghanistan      NaN
# 11462           Not employed, but looking for work  Afghanistan      NaN
# 67131                                          NaN  Afghanistan      NaN
# 62971           Not employed, but looking for work  Afghanistan      NaN
# 14883                           Employed full-time  Afghanistan      NaN
# ...                                            ...          ...      ...
# 13195                           Employed full-time     Zimbabwe      NaN
# 80997       Not employed, and not looking for work     Zimbabwe      NaN
# 73742                           Student, part-time     Zimbabwe      NaN
# 73193                           Employed full-time     Zimbabwe      NaN
# 38429                           Employed full-time     Zimbabwe      NaN
#
#            UK_Country                                            EdLevel  \
# ResponseId
# 37432             NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 11462             NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 67131             NaN                                                NaN
# 62971             NaN  Some college/university study without earning ...
# 14883             NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...               ...                                                ...
# 13195             NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 80997             NaN                          Primary/elementary school
# 73742             NaN  Some college/university study without earning ...
# 73193             NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 38429             NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                       Age1stCode  \
# ResponseId
# 37432       Younger than 5 years
# 11462              11 - 17 years
# 67131                        NaN
# 62971              18 - 24 years
# 14883              18 - 24 years
# ...                          ...
# 13195              18 - 24 years
# 80997              11 - 17 years
# 73742              11 - 17 years
# 73193              18 - 24 years
# 38429               5 - 10 years
#
#                                                     LearnCode  \
# ResponseId
# 37432                                  Books / Physical media
# 11462       Other online resources (ex: videos, blogs, etc...
# 67131                                                     NaN
# 62971                                  Books / Physical media
# 14883       Coding Bootcamp;Other online resources (ex: vi...
# ...                                                       ...
# 13195       Other online resources (ex: videos, blogs, etc...
# 80997       Other online resources (ex: videos, blogs, etc...
# 73742       Other online resources (ex: videos, blogs, etc...
# 73193       Other online resources (ex: videos, blogs, etc...
# 38429       Coding Bootcamp;Other online resources (ex: vi...
#
#                    YearsCode YearsCodePro  \
# ResponseId
# 37432                    NaN          NaN
# 11462                      7          NaN
# 67131                    NaN          NaN
# 62971                      6          NaN
# 14883                      8            4
# ...                      ...          ...
# 13195                     18           14
# 80997       Less than 1 year          NaN
# 73742                      5          NaN
# 73193                      5            1
# 38429                     10            6
#
#                                                       DevType  \
# ResponseId
# 37432                                                     NaN
# 11462       Developer, mobile;Developer, front-end;Develop...
# 67131                                                     NaN
# 62971           Developer, desktop or enterprise applications
# 14883       Developer, front-end;Developer, full-stack;Dev...
# ...                                                       ...
# 13195       Developer, back-end;Database administrator;Sys...
# 80997                                                     NaN
# 73742                                                     NaN
# 73193                                   Developer, full-stack
# 38429       Developer, mobile;Developer, front-end;Develop...
#
#                              OrgSize                   Currency  CompTotal  \
# ResponseId
# 37432                            NaN                        NaN        NaN
# 11462                            NaN                        NaN        NaN
# 67131                            NaN        AFN\tAfghan afghani        NaN
# 62971                            NaN                        NaN        NaN
# 14883             20 to 99 employees        AFN\tAfghan afghani     6500.0
# ...                              ...                        ...        ...
# 13195               2 to 9 employees  USD\tUnited States dollar        NaN
# 80997                            NaN                        NaN        NaN
# 73742                            NaN                        NaN        NaN
# 73193             10 to 19 employees  USD\tUnited States dollar      200.0
# 38429       10,000 or more employees  USD\tUnited States dollar        NaN
#
#            CompFreq                             LanguageHaveWorkedWith  \
# ResponseId
# 37432           NaN                                         C++;Python
# 11462           NaN                         C#;HTML/CSS;SQL;TypeScript
# 67131           NaN                                                NaN
# 62971           NaN                                C;C#;C++;Delphi;SQL
# 14883        Weekly                        HTML/CSS;JavaScript;PHP;SQL
# ...             ...                                                ...
# 13195           NaN                                               Rust
# 80997           NaN                 HTML/CSS;JavaScript;Node.js;Python
# 73742           NaN  Bash/Shell;C#;Go;HTML/CSS;JavaScript;PowerShel...
# 73193       Monthly                                                 C#
# 38429           NaN                                          Dart;Java
#
#                                    LanguageWantToWorkWith  \
# ResponseId
# 37432                                                 NaN
# 11462          C#;HTML/CSS;Java;JavaScript;SQL;TypeScript
# 67131                                                 NaN
# 62971                                                 NaN
# 14883                 HTML/CSS;JavaScript;Node.js;PHP;SQL
# ...                                                   ...
# 13195                                                Rust
# 80997       Assembly;C#;C++;Go;Java;Kotlin;Node.js;Python
# 73742                                                 NaN
# 73193                                                  C#
# 38429                                           Dart;Java
#
#                                        DatabaseHaveWorkedWith  \
# ResponseId
# 37432                                                  Oracle
# 11462       Firebase;Microsoft SQL Server;MongoDB;MySQL;SQ...
# 67131                                                     NaN
# 62971                          Cassandra;Elasticsearch;SQLite
# 14883       Elasticsearch;Firebase;MongoDB;MySQL;Redis;SQLite
# ...                                                       ...
# 13195                                                     NaN
# 80997                                                     NaN
# 73742                                       PostgreSQL;SQLite
# 73193                                                     NaN
# 38429                         Microsoft SQL Server;PostgreSQL
#
#                           DatabaseWantToWorkWith  \
# ResponseId
# 37432                                        NaN
# 11462        Firebase;Microsoft SQL Server;MySQL
# 67131                                        NaN
# 62971                                        NaN
# 14883       Elasticsearch;Firebase;MariaDB;MySQL
# ...                                          ...
# 13195                                        NaN
# 80997                                        NaN
# 73742                                        NaN
# 73193                                        NaN
# 38429            Microsoft SQL Server;PostgreSQL
#
#                                  PlatformHaveWorkedWith  \
# ResponseId
# 37432                                   Microsoft Azure
# 11462                                   Microsoft Azure
# 67131                                               NaN
# 62971                                               AWS
# 14883       AWS;DigitalOcean;Heroku;IBM Cloud or Watson
# ...                                                 ...
# 13195                                               NaN
# 80997                                               NaN
# 73742                                               NaN
# 73193                                               NaN
# 38429                                               NaN
#
#              PlatformWantToWorkWith  \
# ResponseId
# 37432                           NaN
# 11462               Microsoft Azure
# 67131                           NaN
# 62971                           NaN
# 14883       AWS;DigitalOcean;Heroku
# ...                             ...
# 13195                           NaN
# 80997                           NaN
# 73742                           NaN
# 73193                           NaN
# 38429                           NaN
#
#                                        WebframeHaveWorkedWith  \
# ResponseId
# 37432                                                  Django
# 11462                                   Angular;ASP.NET Core
# 67131                                                     NaN
# 62971       Angular;Angular.js;ASP.NET;ASP.NET Core ;Djang...
# 14883       Angular;Angular.js;Drupal;jQuery;Laravel;React.js
# ...                                                       ...
# 13195                                                     NaN
# 80997                                                React.js
# 73742                          Angular;Django;jQuery;React.js
# 73193                                          ASP.NET;jQuery
# 38429                                          Angular;Spring
#
#                                        WebframeWantToWorkWith  \
# ResponseId
# 37432                                                     NaN
# 11462                            Angular;ASP.NET Core ;Spring
# 67131                                                     NaN
# 62971                                                     NaN
# 14883       Angular;Angular.js;Drupal;jQuery;Laravel;React.js
# ...                                                       ...
# 13195                                                     NaN
# 80997                        Angular.js;Django;Express;jQuery
# 73742                                                     NaN
# 73193                                          ASP.NET;jQuery
# 38429                                          Angular;Spring
#
#                                        MiscTechHaveWorkedWith  \
# ResponseId
# 37432                                           Qt;TensorFlow
# 11462                       .NET Framework;.NET Core / .NET 5
# 67131                                                     NaN
# 62971       .NET Framework;.NET Core / .NET 5;Apache Spark...
# 14883                                          .NET Framework
# ...                                                       ...
# 13195                                                     NaN
# 80997                                                     NaN
# 73742                                            NumPy;Pandas
# 73193                                          .NET Framework
# 38429                                                 Flutter
#
#                        MiscTechWantToWorkWith   ToolsTechHaveWorkedWith  \
# ResponseId
# 37432                                     NaN                  Unity 3D
# 11462       .NET Framework;.NET Core / .NET 5                       Git
# 67131                                     NaN                       NaN
# 62971                                     NaN  Ansible;Chef;Deno;Docker
# 14883                                     NaN                Docker;Git
# ...                                       ...                       ...
# 13195                                     NaN                       Git
# 80997                                     NaN                       NaN
# 73742                                     NaN                       Git
# 73193                          .NET Framework                       Git
# 38429                                 Flutter     Docker;Git;Kubernetes
#
#            ToolsTechWantToWorkWith  \
# ResponseId
# 37432                          NaN
# 11462                          Git
# 67131                          NaN
# 62971                          NaN
# 14883                   Docker;Git
# ...                            ...
# 13195                          Git
# 80997                          NaN
# 73742                          NaN
# 73193                          Git
# 38429        Docker;Git;Kubernetes
#
#                                  NEWCollabToolsHaveWorkedWith  \
# ResponseId
# 37432                    Notepad++;PyCharm;Visual Studio Code
# 11462       Eclipse;IntelliJ;Notepad++;Visual Studio;Visua...
# 67131                                                     NaN
# 62971           Android Studio;Atom;Eclipse;IntelliJ;NetBeans
# 14883       Atom;Eclipse;NetBeans;Notepad++;PHPStorm;Subli...
# ...                                                       ...
# 13195                                                     Vim
# 80997                    Notepad++;PyCharm;Visual Studio Code
# 73742       Android Studio;IPython/Jupyter;Sublime Text;Vi...
# 73193                        Visual Studio;Visual Studio Code
# 38429       Android Studio;Eclipse;IntelliJ;NetBeans;Notep...
#
#                                  NEWCollabToolsWantToWorkWith        OpSys  \
# ResponseId
# 37432                                                     NaN      Windows
# 11462       Eclipse;IntelliJ;Notepad++;Visual Studio;Visua...      Windows
# 67131                                                     NaN          NaN
# 62971                                                     NaN      Windows
# 14883               Notepad++;Sublime Text;Visual Studio Code  Linux-based
# ...                                                       ...          ...
# 13195                                                     Vim  Linux-based
# 80997               Android Studio;PyCharm;Visual Studio Code      Windows
# 73742                                                     NaN      Windows
# 73193                        Visual Studio;Visual Studio Code      Windows
# 38429       Android Studio;Eclipse;IntelliJ;NetBeans;Notep...      Windows
#
#                                                      NEWStuck  \
# ResponseId
# 37432       Visit Stack Overflow;Go for a walk or other ph...
# 11462       Call a coworker or friend;Visit Stack Overflow...
# 67131                                                     NaN
# 62971                                    Visit Stack Overflow
# 14883       Call a coworker or friend;Visit Stack Overflow...
# ...                                                       ...
# 13195       Visit Stack Overflow;Google it;Watch help / tu...
# 80997       Watch help / tutorial videos;Do other work and...
# 73742       Call a coworker or friend;Visit Stack Overflow...
# 73193                          Visit Stack Overflow;Google it
# 38429       Visit Stack Overflow;Go for a walk or other ph...
#
#                                                    NEWSOSites  \
# ResponseId
# 37432       Stack Overflow;Stack Exchange;Stack Overflow f...
# 11462                           Stack Overflow;Stack Exchange
# 67131                                                     NaN
# 62971                                          Stack Overflow
# 14883                           Stack Overflow;Stack Exchange
# ...                                                       ...
# 13195                           Stack Overflow;Stack Exchange
# 80997                                          Stack Overflow
# 73742                                          Stack Overflow
# 73193                                          Stack Overflow
# 38429                                          Stack Overflow
#
#                                 SOVisitFreq SOAccount  \
# ResponseId
# 37432       A few times per month or weekly      True
# 11462                 Daily or almost daily      True
# 67131                                   NaN       NaN
# 62971       A few times per month or weekly       NaN
# 14883                 Daily or almost daily      True
# ...                                     ...       ...
# 13195                  A few times per week      True
# 80997       A few times per month or weekly      True
# 73742                  A few times per week      True
# 73193       A few times per month or weekly      True
# 38429                  A few times per week     False
#
#                                                    SOPartFreq  \
# ResponseId
# 37432                         A few times per month or weekly
# 11462                         A few times per month or weekly
# 67131                                                     NaN
# 62971                                                     NaN
# 14883                         A few times per month or weekly
# ...                                                       ...
# 13195       I have never participated in Q&A on Stack Over...
# 80997       I have never participated in Q&A on Stack Over...
# 73742       I have never participated in Q&A on Stack Over...
# 73193                     Less than once per month or monthly
# 38429                                                     NaN
#
#                      SOComm NEWOtherComms                 Age  \
# ResponseId
# 37432        No, not at all            No  Under 18 years old
# 11462         Yes, somewhat            No     18-24 years old
# 67131                   NaN           NaN                 NaN
# 62971              Not sure            No     25-34 years old
# 14883         Yes, somewhat           Yes     25-34 years old
# ...                     ...           ...                 ...
# 13195         Yes, somewhat           Yes     35-44 years old
# 80997        No, not really            No  Under 18 years old
# 73742       Yes, definitely           Yes     18-24 years old
# 73193       Yes, definitely            No     25-34 years old
# 38429               Neutral            No     25-34 years old
#
#                             Gender                   Trans  \
# ResponseId
# 37432       Or, in your own words:  Or, in your own words:
# 11462                          Man                      No
# 67131                          NaN                     NaN
# 62971                          Man                      No
# 14883                          Man                      No
# ...                            ...                     ...
# 13195                          Man                      No
# 80997                          Man                      No
# 73742                          Man                      No
# 73193                          Man                      No
# 38429                        Woman                      No
#
#                                                     Sexuality  \
# ResponseId
# 37432       Straight / Heterosexual;Bisexual;Prefer to sel...
# 11462                                 Straight / Heterosexual
# 67131                                                     NaN
# 62971                                 Straight / Heterosexual
# 14883                                                     NaN
# ...                                                       ...
# 13195                                 Straight / Heterosexual
# 80997                                 Straight / Heterosexual
# 73742                                 Straight / Heterosexual
# 73193                                 Straight / Heterosexual
# 38429                                 Straight / Heterosexual
#
#                                                     Ethnicity  \
# ResponseId
# 37432       White or of European descent;I don't know;Mult...
# 11462                                          Middle Eastern
# 67131                                                     NaN
# 62971       Multiracial;Indigenous (such as Native America...
# 14883                                             South Asian
# ...                                                       ...
# 13195                             Black or of African descent
# 80997                             Black or of African descent
# 73742                             Black or of African descent
# 73193                             Black or of African descent
# 38429                             Black or of African descent
#
#                                   Accessibility            MentalHealth  \
# ResponseId
# 37432                    Or, in your own words:  Or, in your own words:
# 11462                         None of the above       None of the above
# 67131                                       NaN                     NaN
# 62971                         None of the above       None of the above
# 14883                         None of the above       None of the above
# ...                                         ...                     ...
# 13195                         None of the above       None of the above
# 80997       I am blind / have difficulty seeing       None of the above
# 73742                         None of the above       None of the above
# 73193                         None of the above       None of the above
# 38429                         None of the above       None of the above
#
#                      SurveyLength                  SurveyEase  SalaryUSD
# ResponseId
# 37432                    Too long                   Difficult        NaN
# 11462       Appropriate in length                        Easy        NaN
# 67131                         NaN                         NaN        NaN
# 62971                    Too long                   Difficult        NaN
# 14883       Appropriate in length                        Easy     4200.0
# ...                           ...                         ...        ...
# 13195                    Too long                        Easy        NaN
# 80997       Appropriate in length                        Easy        NaN
# 73742       Appropriate in length  Neither easy nor difficult        NaN
# 73193       Appropriate in length                        Easy     2400.0
# 38429       Appropriate in length  Neither easy nor difficult        NaN
#
# [83439 rows x 47 columns]

# %%
# Sort the countries in asceding order and the salaries in descending order.
df[['Country', 'SalaryUSD']]
# Out:
#                 Country  SalaryUSD
# ResponseId
# 37432       Afghanistan        NaN
# 11462       Afghanistan        NaN
# 67131       Afghanistan        NaN
# 62971       Afghanistan        NaN
# 14883       Afghanistan     4200.0
# ...                 ...        ...
# 13195          Zimbabwe        NaN
# 80997          Zimbabwe        NaN
# 73742          Zimbabwe        NaN
# 73193          Zimbabwe     2400.0
# 38429          Zimbabwe        NaN
#
# [83439 rows x 2 columns]

# %%
df = df.sort_values(by=['Country', 'SalaryUSD'], ascending=[True, False])
df[['Country', 'SalaryUSD']]
# Out:
#                 Country   SalaryUSD
# ResponseId
# 65400       Afghanistan  30468516.0
# 22667       Afghanistan    155496.0
# 27199       Afghanistan     51804.0
# 31087       Afghanistan     23964.0
# 44641       Afghanistan     15132.0
# ...                 ...         ...
# 56303          Zimbabwe         NaN
# 13195          Zimbabwe         NaN
# 80997          Zimbabwe         NaN
# 73742          Zimbabwe         NaN
# 38429          Zimbabwe         NaN
#
# [83439 rows x 2 columns]

# %%
# Get the 10 highest salaries from the survey.
df['SalaryUSD'].nlargest(10)
# Out:
# ResponseId
# 66911    45241312.0
# 65400    30468516.0
# 40587    21822250.0
# 28792    20000000.0
# 12701    19200000.0
# 9609     17500000.0
# 5306     15000000.0
# 12904    14411628.0
# 66489    12750000.0
# 47564    12500000.0
# Name: SalaryUSD, dtype: float64

# %%
# Get the entries with the 10 highest salaries.
df.nlargest(10, 'SalaryUSD')
# Out:
#                                                    MainBranch  \
# ResponseId
# 66911                          I am a developer by profession
# 65400                          I am a developer by profession
# 40587                          I am a developer by profession
# 28792                          I am a developer by profession
# 12701                          I am a developer by profession
# 9609        I am not primarily a developer, but I write co...
# 5306                           I am a developer by profession
# 12904                          I am a developer by profession
# 66489                          I am a developer by profession
# 47564                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 66911                                     I prefer not to say
# 65400                                      Employed full-time
# 40587                                      Employed full-time
# 28792                                      Employed full-time
# 12701                                      Employed full-time
# 9609                                       Employed full-time
# 5306        Independent contractor, freelancer, or self-em...
# 12904                                      Employed full-time
# 66489                                      Employed full-time
# 47564                                      Employed full-time
#
#                              Country    US_State UK_Country  \
# ResponseId
# 66911                        Belgium         NaN        NaN
# 65400                    Afghanistan         NaN        NaN
# 40587       United States of America  California        NaN
# 28792                          India         NaN        NaN
# 12701                          India         NaN        NaN
# 9609        United States of America    New York        NaN
# 5306        United States of America  New Jersey        NaN
# 12904                         Serbia         NaN        NaN
# 66489       United States of America  Washington        NaN
# 47564       United States of America    Colorado        NaN
#
#                                                       EdLevel  \
# ResponseId
# 66911                               Primary/elementary school
# 65400         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 40587       Some college/university study without earning ...
# 28792            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 12701         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 9609             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5306                       Professional degree (JD, MD, etc.)
# 12904            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 66489       Some college/university study without earning ...
# 47564            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                       Age1stCode  \
# ResponseId
# 66911              55 - 64 years
# 65400              25 - 34 years
# 40587       Younger than 5 years
# 28792              35 - 44 years
# 12701              25 - 34 years
# 9609               18 - 24 years
# 5306               11 - 17 years
# 12904              11 - 17 years
# 66489              18 - 24 years
# 47564              11 - 17 years
#
#                                                     LearnCode YearsCode  \
# ResponseId
# 66911                                  Books / Physical media         1
# 65400                         Online Courses or Certification         7
# 40587       Other online resources (ex: videos, blogs, etc...        37
# 28792       Coding Bootcamp;Other online resources (ex: vi...        11
# 12701                                            Online Forum         5
# 9609                                                   School        25
# 5306           Friend or family member;Books / Physical media        25
# 12904       Other online resources (ex: videos, blogs, etc...         6
# 66489       School;Online Courses or Certification;Books /...         5
# 47564                                  Books / Physical media        24
#
#            YearsCodePro                                            DevType  \
# ResponseId
# 66911                21                                                NaN
# 65400                 3  Developer, desktop or enterprise applications;...
# 40587                13                            Other (please specify):
# 28792                 9  Developer, desktop or enterprise applications;...
# 12701                 5                              Developer, full-stack
# 9609                 21               Senior Executive (C-Suite, VP, etc.)
# 5306                  5            Developer, full-stack;DevOps specialist
# 12904                 1  Developer, front-end;Developer, full-stack;Dev...
# 66489                 3  Developer, desktop or enterprise applications;...
# 47564                13                               Developer, front-end
#
#                                                       OrgSize  \
# ResponseId
# 66911       Just me - I am a freelancer, sole proprietor, ...
# 65400                                    500 to 999 employees
# 40587                                10,000 or more employees
# 28792                                    100 to 499 employees
# 12701                                    100 to 499 employees
# 9609                                       20 to 99 employees
# 5306        Just me - I am a freelancer, sole proprietor, ...
# 12904                                    100 to 499 employees
# 66489                                      20 to 99 employees
# 47564                                10,000 or more employees
#
#                                      Currency     CompTotal CompFreq  \
# ResponseId
# 66911                       ALL\tAlbanian lek  5.123468e+09   Yearly
# 65400       ANG Netherlands Antillean guilder  4.544242e+06  Monthly
# 40587               USD\tUnited States dollar  4.364450e+05   Weekly
# 28792               USD\tUnited States dollar  2.000000e+07   Yearly
# 12701               USD\tUnited States dollar  1.600000e+06  Monthly
# 9609                USD\tUnited States dollar  3.500000e+05   Weekly
# 5306                USD\tUnited States dollar  3.000000e+05   Weekly
# 12904                       EUR European Euro  1.111000e+06  Monthly
# 66489               USD\tUnited States dollar  2.550000e+05   Weekly
# 47564               USD\tUnited States dollar  2.500000e+05   Weekly
#
#                                        LanguageHaveWorkedWith  \
# ResponseId
# 66911                                                     APL
# 65400       Bash/Shell;C++;Elixir;LISP;Node.js;Ruby;Rust;S...
# 40587       Bash/Shell;HTML/CSS;Java;JavaScript;Node.js;Py...
# 28792       C#;C++;Groovy;HTML/CSS;Java;JavaScript;Node.js...
# 12701                                              JavaScript
# 9609        Bash/Shell;Go;HTML/CSS;Java;JavaScript;Kotlin;...
# 5306                                                   Python
# 12904                            C#;JavaScript;Node.js;Python
# 66489       Bash/Shell;Go;HTML/CSS;Java;JavaScript;Kotlin;...
# 47564                Go;HTML/CSS;JavaScript;Python;TypeScript
#
#                                        LanguageWantToWorkWith  \
# ResponseId
# 66911                                                     NaN
# 65400            Clojure;Crystal;Dart;Matlab;Node.js;Python;R
# 40587       Bash/Shell;Haskell;HTML/CSS;Java;JavaScript;No...
# 28792                                              Ruby;Swift
# 12701                                              JavaScript
# 9609                                                      NaN
# 5306                                          Python;Rust;SQL
# 12904                                               C#;Python
# 66489                                  Node.js;SQL;TypeScript
# 47564              HTML/CSS;JavaScript;Python;Rust;TypeScript
#
#                                        DatabaseHaveWorkedWith  \
# ResponseId
# 66911                                               Couchbase
# 65400                         Couchbase;Elasticsearch;MariaDB
# 40587                                    MariaDB;MySQL;SQLite
# 28792       Microsoft SQL Server;MySQL;Oracle;PostgreSQL;S...
# 12701                                MongoDB;MySQL;PostgreSQL
# 9609        Elasticsearch;IBM DB2;MariaDB;MongoDB;MySQL;Or...
# 5306                                                      NaN
# 12904                                        MySQL;PostgreSQL
# 66489       DynamoDB;Elasticsearch;Firebase;MySQL;PostgreS...
# 47564                                              PostgreSQL
#
#               DatabaseWantToWorkWith     PlatformHaveWorkedWith  \
# ResponseId
# 66911                            NaN                        AWS
# 65400                   MySQL;Oracle    AWS;IBM Cloud or Watson
# 40587           MariaDB;MySQL;SQLite            Microsoft Azure
# 28792                        MongoDB    AWS;DigitalOcean;Heroku
# 12701       MongoDB;MySQL;PostgreSQL                 AWS;Heroku
# 9609                             NaN           AWS;DigitalOcean
# 5306                             NaN  AWS;Google Cloud Platform
# 12904               MySQL;PostgreSQL                        NaN
# 66489                 DynamoDB;Redis  AWS;Google Cloud Platform
# 47564                     PostgreSQL                        AWS
#
#                          PlatformWantToWorkWith  \
# ResponseId
# 66911                                       NaN
# 65400               Oracle Cloud Infrastructure
# 40587                           Microsoft Azure
# 28792       IBM Cloud or Watson;Microsoft Azure
# 12701                                AWS;Heroku
# 9609                                        NaN
# 5306                                        NaN
# 12904                                       NaN
# 66489                                       AWS
# 47564                                       NaN
#
#                                        WebframeHaveWorkedWith  \
# ResponseId
# 66911                                                     NaN
# 65400                           ASP.NET;Drupal;Laravel;Svelte
# 40587                                                   Flask
# 28792         Angular.js;Drupal;Laravel;Ruby on Rails;Symfony
# 12701                                                React.js
# 9609                                    Angular;jQuery;Spring
# 5306                                                    Flask
# 12904       Angular;ASP.NET;ASP.NET Core ;Django;jQuery;Re...
# 66489                                 Express;React.js;Spring
# 47564                                         React.js;Vue.js
#
#                                        WebframeWantToWorkWith  \
# ResponseId
# 66911                                                     NaN
# 65400       Angular;ASP.NET;Django;Express;Flask;jQuery;Ru...
# 40587                           Express;Flask;React.js;Svelte
# 28792                                         Angular;ASP.NET
# 12701                                                React.js
# 9609                                                      NaN
# 5306                                                   Django
# 12904                   Angular;ASP.NET Core ;Django;React.js
# 66489                                        Express;React.js
# 47564                                         React.js;Vue.js
#
#                                MiscTechHaveWorkedWith MiscTechWantToWorkWith  \
# ResponseId
# 66911                                             NaN                    NaN
# 65400       .NET Framework;Apache Spark;Hadoop;Pandas      Flutter;Pandas;Qt
# 40587                                             NaN                    NaN
# 28792                     Apache Spark;Cordova;Hadoop         .NET Framework
# 12701                                             NaN                    NaN
# 9609                                              NaN                    NaN
# 5306                                              NaN                    NaN
# 12904               .NET Framework;.NET Core / .NET 5     .NET Core / .NET 5
# 66489                                    NumPy;Pandas           NumPy;Pandas
# 47564                                             NaN                    NaN
#
#                  ToolsTechHaveWorkedWith        ToolsTechWantToWorkWith  \
# ResponseId
# 66911                                NaN                            NaN
# 65400              Docker;Flow;Terraform                Chef;Docker;Git
# 40587                                Git                     Docker;Git
# 28792                                Git  Chef;Docker;Kubernetes;Puppet
# 12701                                Git                            Git
# 9609                      Git;Kubernetes                            NaN
# 5306        Ansible;Docker;Git;Terraform                     Docker;Git
# 12904                         Docker;Git                     Docker;Git
# 66489                    Docker;Git;Yarn                            Git
# 47564         Docker;Git;Kubernetes;Yarn                       Git;Yarn
#
#                                  NEWCollabToolsHaveWorkedWith  \
# ResponseId
# 66911                                        IntelliJ;PyCharm
# 65400                              NetBeans;PHPStorm;RubyMine
# 40587                             IntelliJ;Visual Studio Code
# 28792       Android Studio;Atom;Eclipse;IPython/Jupyter;Ne...
# 12701                              Eclipse;Visual Studio Code
# 9609        Android Studio;IntelliJ;Notepad++;PHPStorm;Vim...
# 5306                                                      Vim
# 12904                PyCharm;Visual Studio;Visual Studio Code
# 66489       Atom;IntelliJ;PyCharm;Sublime Text;Visual Stud...
# 47564                                      Visual Studio Code
#
#                          NEWCollabToolsWantToWorkWith  \
# ResponseId
# 66911                                             NaN
# 65400                                Eclipse;NetBeans
# 40587       IntelliJ;Visual Studio;Visual Studio Code
# 28792                              Visual Studio Code
# 12701                      Eclipse;Visual Studio Code
# 9609                                              NaN
# 5306                                              Vim
# 12904        PyCharm;Visual Studio;Visual Studio Code
# 66489                              Visual Studio Code
# 47564                              Visual Studio Code
#
#                               OpSys  \
# ResponseId
# 66911       Other (please specify):
# 65400                   Linux-based
# 40587                         MacOS
# 28792                         MacOS
# 12701                       Windows
# 9609                        Windows
# 5306                    Linux-based
# 12904                       Windows
# 66489                         MacOS
# 47564                         MacOS
#
#                                                      NEWStuck  \
# ResponseId
# 66911       Visit Stack Overflow;Go for a walk or other ph...
# 65400                 Watch help / tutorial videos;Play games
# 40587       Visit Stack Overflow;Google it;Do other work a...
# 28792       Visit Stack Overflow;Google it;Visit another d...
# 12701       Visit Stack Overflow;Google it;Visit another d...
# 9609                      Call a coworker or friend;Google it
# 5306                                  Other (please specify):
# 12904       Visit Stack Overflow;Google it;Watch help / tu...
# 66489            Call a coworker or friend;Google it;Meditate
# 47564       Go for a walk or other physical activity;Googl...
#
#                                                    NEWSOSites  \
# ResponseId
# 66911       Stack Overflow for Teams (private knowledge sh...
# 65400       Stack Overflow;Stack Overflow for Teams (priva...
# 40587       Stack Overflow;Stack Exchange;Stack Overflow f...
# 28792       Stack Overflow;Stack Exchange;Stack Overflow f...
# 12701                                          Stack Exchange
# 9609                                           Stack Overflow
# 5306                            Stack Overflow;Stack Exchange
# 12904                           Stack Overflow;Stack Exchange
# 66489                           Stack Overflow;Stack Exchange
# 47564                                          Stack Overflow
#
#                                     SOVisitFreq SOAccount  \
# ResponseId
# 66911       Less than once per month or monthly      True
# 65400           A few times per month or weekly       NaN
# 40587                    Multiple times per day      True
# 28792           A few times per month or weekly      True
# 12701                      A few times per week      True
# 9609        Less than once per month or monthly     False
# 5306                       A few times per week      True
# 12904                     Daily or almost daily     False
# 66489                     Daily or almost daily      True
# 47564           A few times per month or weekly      True
#
#                                                    SOPartFreq          SOComm  \
# ResponseId
# 66911       I have never participated in Q&A on Stack Over...  No, not at all
# 65400                                                     NaN  No, not at all
# 40587                                   Daily or almost daily   Yes, somewhat
# 28792                         A few times per month or weekly         Neutral
# 12701                                    A few times per week         Neutral
# 9609                                                      NaN         Neutral
# 5306                      Less than once per month or monthly   Yes, somewhat
# 12904                                                     NaN         Neutral
# 66489       I have never participated in Q&A on Stack Over...  No, not really
# 47564       I have never participated in Q&A on Stack Over...         Neutral
#
#            NEWOtherComms              Age  \
# ResponseId
# 66911                Yes  55-64 years old
# 65400                Yes  35-44 years old
# 40587                Yes  35-44 years old
# 28792                Yes  35-44 years old
# 12701                Yes  35-44 years old
# 9609                 Yes  35-44 years old
# 5306                 Yes  35-44 years old
# 12904                 No  18-24 years old
# 66489                 No  25-34 years old
# 47564                 No  35-44 years old
#
#                                                        Gender  \
# ResponseId
# 66911                                                     NaN
# 65400       Man;Non-binary, genderqueer, or gender non-con...
# 40587                                                     Man
# 28792                                                     Man
# 12701                                                     Man
# 9609                                                      Man
# 5306                                                      Man
# 12904                                                     Man
# 66489                                                     Man
# 47564                                       Prefer not to say
#
#                         Trans  \
# ResponseId
# 66911                     Yes
# 65400                     Yes
# 40587                      No
# 28792                      No
# 12701                      No
# 9609                       No
# 5306                       No
# 12904                      No
# 66489                      No
# 47564       Prefer not to say
#
#                                                     Sexuality  \
# ResponseId
# 66911                                                     NaN
# 65400       Bisexual;Prefer to self-describe:;Gay or Lesbi...
# 40587                                                Bisexual
# 28792                                       Prefer not to say
# 12701                                 Straight / Heterosexual
# 9609                                  Straight / Heterosexual
# 5306                                                      NaN
# 12904                                 Straight / Heterosexual
# 66489                                 Straight / Heterosexual
# 47564                                       Prefer not to say
#
#                                                     Ethnicity  \
# ResponseId
# 66911                             Black or of African descent
# 65400       South Asian;Hispanic or Latino/a/x;Black or of...
# 40587                            White or of European descent
# 28792                                       Prefer not to say
# 12701                                             South Asian
# 9609                             White or of European descent
# 5306                             White or of European descent
# 12904                            White or of European descent
# 66489                                       Prefer not to say
# 47564                                       Prefer not to say
#
#                                                 Accessibility  \
# ResponseId
# 66911                     I am blind / have difficulty seeing
# 65400       I am unable to / find it difficult to walk or ...
# 40587                     I am blind / have difficulty seeing
# 28792                                       Prefer not to say
# 12701                                       None of the above
# 9609                                        None of the above
# 5306                                        None of the above
# 12904                                       None of the above
# 66489                                       Prefer not to say
# 47564                                       None of the above
#
#                                                  MentalHealth  \
# ResponseId
# 66911       I have a concentration and/or memory disorder ...
# 65400       I have a mood or emotional disorder (e.g. depr...
# 40587       I have a concentration and/or memory disorder ...
# 28792                                       None of the above
# 12701                                       None of the above
# 9609                                        None of the above
# 5306                                        None of the above
# 12904                                       None of the above
# 66489                                       Prefer not to say
# 47564                              I have an anxiety disorder
#
#                      SurveyLength                  SurveyEase   SalaryUSD
# ResponseId
# 66911                   Too short                         NaN  45241312.0
# 65400                   Too short                   Difficult  30468516.0
# 40587       Appropriate in length                        Easy  21822250.0
# 28792       Appropriate in length                        Easy  20000000.0
# 12701       Appropriate in length                        Easy  19200000.0
# 9609        Appropriate in length                        Easy  17500000.0
# 5306                     Too long                        Easy  15000000.0
# 12904                    Too long  Neither easy nor difficult  14411628.0
# 66489       Appropriate in length                        Easy  12750000.0
# 47564       Appropriate in length  Neither easy nor difficult  12500000.0

# %%
# Get the entries with the 10 lowest salaries.
df.nsmallest(10, 'SalaryUSD')
# Out:
#                                                    MainBranch  \
# ResponseId
# 1925                           I am a developer by profession
# 46465       I am not primarily a developer, but I write co...
# 24286                          I am a developer by profession
# 15164                          I am a developer by profession
# 56791                          I am a developer by profession
# 22033                          I am a developer by profession
# 59044                          I am a developer by profession
# 22454                          I am a developer by profession
# 45142       I am not primarily a developer, but I write co...
# 53307                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1925                                       Employed full-time
# 46465                                      Employed full-time
# 24286       Independent contractor, freelancer, or self-em...
# 15164                                      Employed full-time
# 56791                                      Employed full-time
# 22033                                      Employed full-time
# 59044                                      Employed full-time
# 22454                                      Employed full-time
# 45142                                      Employed full-time
# 53307                                      Employed full-time
#
#                              Country      US_State UK_Country  \
# ResponseId
# 1925        United States of America  Pennsylvania        NaN
# 46465       United States of America    Washington        NaN
# 24286       United States of America    California        NaN
# 15164                          China           NaN        NaN
# 56791                         Taiwan           NaN        NaN
# 22033              Republic of Korea           NaN        NaN
# 59044                         Taiwan           NaN        NaN
# 22454                          Japan           NaN        NaN
# 45142                          China           NaN        NaN
# 53307                          Japan           NaN        NaN
#
#                                                       EdLevel  \
# ResponseId
# 1925          Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 46465            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 24286            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 15164                               Primary/elementary school
# 56791         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 22033                     Associate degree (A.A., A.S., etc.)
# 59044         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 22454       Secondary school (e.g. American high school, G...
# 45142         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 53307       Some college/university study without earning ...
#
#                       Age1stCode  \
# ResponseId
# 1925               11 - 17 years
# 46465              11 - 17 years
# 24286              11 - 17 years
# 15164       Younger than 5 years
# 56791              11 - 17 years
# 22033              18 - 24 years
# 59044              18 - 24 years
# 22454               5 - 10 years
# 45142              11 - 17 years
# 53307              11 - 17 years
#
#                                                     LearnCode  \
# ResponseId
# 1925                           School;Other (please specify):
# 46465       Coding Bootcamp;Other online resources (ex: vi...
# 24286                                  Books / Physical media
# 15164                                  Books / Physical media
# 56791                                                  School
# 22033       Coding Bootcamp;Other online resources (ex: vi...
# 59044       Other online resources (ex: videos, blogs, etc...
# 22454         Other online resources (ex: videos, blogs, etc)
# 45142       Other online resources (ex: videos, blogs, etc...
# 53307       Other online resources (ex: videos, blogs, etc...
#
#                    YearsCode      YearsCodePro  \
# ResponseId
# 1925                      30                25
# 46465                     27                12
# 24286                     16                 9
# 15164                      5                 1
# 56791                     12                 2
# 22033                      5  Less than 1 year
# 59044                     20               NaN
# 22454       Less than 1 year                 6
# 45142                     12                 1
# 53307                     25                17
#
#                                                       DevType  \
# ResponseId
# 1925        Developer, mobile;Developer, front-end;Develop...
# 46465       Engineer, data;Data scientist or machine learn...
# 24286       Other (please specify):;Data scientist or mach...
# 15164                                     Academic researcher
# 56791       Developer, full-stack;Database administrator;S...
# 22033                                    Developer, front-end
# 59044                                    Developer, front-end
# 22454                                   Developer, full-stack
# 45142                                               Scientist
# 53307       Developer, mobile;Data scientist or machine le...
#
#                              OrgSize                    Currency  CompTotal  \
# ResponseId
# 1925        1,000 to 4,999 employees   USD\tUnited States dollar        1.0
# 46465             10 to 19 employees   USD\tUnited States dollar        1.0
# 24286               2 to 9 employees   USD\tUnited States dollar        1.0
# 15164               2 to 9 employees  CNY\tChinese Yuan Renminbi       11.0
# 56791           100 to 499 employees      TWD\tNew Taiwan dollar       50.0
# 22033             20 to 99 employees       KRW\tSouth Korean won     3800.0
# 59044           100 to 499 employees      TWD\tNew Taiwan dollar       90.0
# 22454             20 to 99 employees           JPY\tJapanese yen      450.0
# 45142       1,000 to 4,999 employees  CNY\tChinese Yuan Renminbi       35.0
# 53307       10,000 or more employees           JPY\tJapanese yen      600.0
#
#            CompFreq                             LanguageHaveWorkedWith  \
# ResponseId
# 1925         Yearly              C#;HTML/CSS;JavaScript;PowerShell;SQL
# 46465        Yearly                                        Perl;Python
# 24286        Yearly                                         Python;SQL
# 15164        Yearly                                        Objective-C
# 56791        Yearly             HTML/CSS;JavaScript;Node.js;Python;SQL
# 22033        Yearly                              JavaScript;TypeScript
# 59044        Yearly  HTML/CSS;JavaScript;Node.js;PowerShell;TypeScript
# 22454        Yearly                         C#;HTML/CSS;SQL;TypeScript
# 45142        Yearly                        C++;Java;Python;R;Scala;SQL
# 53307        Yearly  Bash/Shell;HTML/CSS;Java;JavaScript;Kotlin;Nod...
#
#                                        LanguageWantToWorkWith  \
# ResponseId
# 1925                    C#;HTML/CSS;JavaScript;PowerShell;SQL
# 46465                               JavaScript;Node.js;Python
# 24286                                                  Python
# 15164                                                     NaN
# 56791                                                     NaN
# 22033                                   JavaScript;TypeScript
# 59044                  HTML/CSS;JavaScript;Node.js;TypeScript
# 22454                              C#;HTML/CSS;SQL;TypeScript
# 45142                                              C++;Python
# 53307       Bash/Shell;C#;HTML/CSS;Java;Kotlin;Python;SQL;...
#
#                                 DatabaseHaveWorkedWith  \
# ResponseId
# 1925                              Microsoft SQL Server
# 46465                                           SQLite
# 24286                                 PostgreSQL;Redis
# 15164                                            MySQL
# 56791                          MySQL;PostgreSQL;SQLite
# 22033                           MySQL;PostgreSQL;Redis
# 59044       Elasticsearch;Firebase;MongoDB;MySQL;Redis
# 22454                                           Oracle
# 45142                                              NaN
# 53307                 Firebase;MySQL;PostgreSQL;SQLite
#
#                DatabaseWantToWorkWith        PlatformHaveWorkedWith  \
# ResponseId
# 1925             Microsoft SQL Server           AWS;Microsoft Azure
# 46465                             NaN         Google Cloud Platform
# 24286                PostgreSQL;Redis                           AWS
# 15164                             NaN               Microsoft Azure
# 56791                             NaN                           NaN
# 22033          MySQL;PostgreSQL;Redis     AWS;Google Cloud Platform
# 59044                        Firebase  DigitalOcean;Microsoft Azure
# 22454                          Oracle           AWS;Microsoft Azure
# 45142                             NaN                           NaN
# 53307       MariaDB;PostgreSQL;SQLite                           AWS
#
#                PlatformWantToWorkWith  \
# ResponseId
# 1925                              NaN
# 46465                             NaN
# 24286                             AWS
# 15164                             NaN
# 56791                             NaN
# 22033       AWS;Google Cloud Platform
# 59044                             NaN
# 22454             AWS;Microsoft Azure
# 45142                             NaN
# 53307                             AWS
#
#                                      WebframeHaveWorkedWith  \
# ResponseId
# 1925        Angular;Angular.js;ASP.NET;ASP.NET Core ;jQuery
# 46465                                                 Flask
# 24286                                          Django;Flask
# 15164                                                Vue.js
# 56791                                         Django;jQuery
# 22033                                              React.js
# 59044                                       Angular;Express
# 22454                                 Angular;ASP.NET Core
# 45142                                                   NaN
# 53307           Angular;Express;Flask;Laravel;Spring;Vue.js
#
#                                      WebframeWantToWorkWith  \
# ResponseId
# 1925        Angular;Angular.js;ASP.NET;ASP.NET Core ;jQuery
# 46465                                                 Flask
# 24286                                          Django;Flask
# 15164                                                   NaN
# 56791                                                   NaN
# 22033                                React.js;Svelte;Vue.js
# 59044                                               Angular
# 22454                                 Angular;ASP.NET Core
# 45142                                                   NaN
# 53307                 Angular;ASP.NET Core ;FastAPI;Laravel
#
#                                  MiscTechHaveWorkedWith  \
# ResponseId
# 1925                  .NET Framework;.NET Core / .NET 5
# 46465                                           Flutter
# 24286                           NumPy;Pandas;TensorFlow
# 15164                                               NaN
# 56791                                               NaN
# 22033                               Hadoop;React Native
# 59044                                               NaN
# 22454                                .NET Core / .NET 5
# 45142                 Hadoop;NumPy;Pandas;Torch/PyTorch
# 53307       Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
#
#                                    MiscTechWantToWorkWith  \
# ResponseId
# 1925                    .NET Framework;.NET Core / .NET 5
# 46465                                                 NaN
# 24286                             NumPy;Pandas;TensorFlow
# 15164                                                 NaN
# 56791                                                 NaN
# 22033                         Flutter;Hadoop;React Native
# 59044                                                 NaN
# 22454                                  .NET Core / .NET 5
# 45142                          NumPy;Pandas;Torch/PyTorch
# 53307       .NET Core / .NET 5;NumPy;Pandas;Torch/PyTorch
#
#                ToolsTechHaveWorkedWith          ToolsTechWantToWorkWith  \
# ResponseId
# 1925             Docker;Git;Kubernetes            Docker;Git;Kubernetes
# 46465                              Git                              Git
# 24286             Docker;Git;Terraform             Docker;Git;Terraform
# 15164                              NaN                              NaN
# 56791                       Docker;Git                              NaN
# 22033       Docker;Git;Kubernetes;Yarn  Deno;Docker;Git;Kubernetes;Yarn
# 59044               Ansible;Docker;Git                       Docker;Git
# 22454                              NaN                              NaN
# 45142                              Git                              Git
# 53307                       Docker;Git       Git;Unity 3D;Unreal Engine
#
#                                  NEWCollabToolsHaveWorkedWith  \
# ResponseId
# 1925               Notepad++;Visual Studio;Visual Studio Code
# 46465            Android Studio;IntelliJ;PyCharm;Sublime Text
# 24286                                 IPython/Jupyter;PyCharm
# 15164                                                     NaN
# 56791                                                 PyCharm
# 22033                             Visual Studio Code;Webstorm
# 59044       IntelliJ;Notepad++;Vim;Visual Studio Code;Webs...
# 22454                        Visual Studio;Visual Studio Code
# 45142       IntelliJ;PyCharm;RStudio;Visual Studio;Visual ...
# 53307       Android Studio;IntelliJ;IPython/Jupyter;PHPSto...
#
#                                  NEWCollabToolsWantToWorkWith        OpSys  \
# ResponseId
# 1925               Notepad++;Visual Studio;Visual Studio Code      Windows
# 46465                                    PyCharm;Sublime Text        MacOS
# 24286                                 IPython/Jupyter;PyCharm        MacOS
# 15164                                                     NaN        MacOS
# 56791                                                     NaN      Windows
# 22033                             Visual Studio Code;Webstorm        MacOS
# 59044       IntelliJ;Notepad++;Vim;Visual Studio Code;Webs...        MacOS
# 22454                        Visual Studio;Visual Studio Code      Windows
# 45142                                      Visual Studio Code      Windows
# 53307       Android Studio;IntelliJ;PHPStorm;PyCharm;Vim;V...  Linux-based
#
#                                                      NEWStuck  \
# ResponseId
# 1925        Call a coworker or friend;Visit Stack Overflow...
# 46465       Go for a walk or other physical activity;Do ot...
# 24286       Visit Stack Overflow;Go for a walk or other ph...
# 15164                                               Google it
# 56791       Call a coworker or friend;Visit Stack Overflow...
# 22033       Visit Stack Overflow;Go for a walk or other ph...
# 59044       Go for a walk or other physical activity;Googl...
# 22454                      Call a coworker or friend;Meditate
# 45142       Visit Stack Overflow;Google it;Do other work a...
# 53307       Visit Stack Overflow;Google it;Watch help / tu...
#
#                                                    NEWSOSites  \
# ResponseId
# 1925                            Stack Overflow;Stack Exchange
# 46465                                          Stack Overflow
# 24286                           Stack Overflow;Stack Exchange
# 15164       Stack Overflow for Teams (private knowledge sh...
# 56791                                          Stack Overflow
# 22033                                          Stack Overflow
# 59044                                          Stack Overflow
# 22454                                          Stack Overflow
# 45142                           Stack Overflow;Stack Exchange
# 53307                           Stack Overflow;Stack Exchange
#
#                                     SOVisitFreq SOAccount  \
# ResponseId
# 1925                       A few times per week      True
# 46465       Less than once per month or monthly     False
# 24286                      A few times per week      True
# 15164       Less than once per month or monthly      True
# 56791                     Daily or almost daily      True
# 22033                     Daily or almost daily      True
# 59044                    Multiple times per day      True
# 22454           A few times per month or weekly       NaN
# 45142                     Daily or almost daily      True
# 53307                     Daily or almost daily     False
#
#                                                    SOPartFreq  \
# ResponseId
# 1925                                     A few times per week
# 46465                                                     NaN
# 24286                                    A few times per week
# 15164       I have never participated in Q&A on Stack Over...
# 56791                     Less than once per month or monthly
# 22033                     Less than once per month or monthly
# 59044       I have never participated in Q&A on Stack Over...
# 22454                                                     NaN
# 45142                         A few times per month or weekly
# 53307                                                     NaN
#
#                      SOComm NEWOtherComms              Age Gender  \
# ResponseId
# 1925        Yes, definitely            No  45-54 years old    Man
# 46465        No, not at all            No  35-44 years old    Man
# 24286         Yes, somewhat           Yes  35-44 years old    Man
# 15164        No, not at all           Yes  35-44 years old  Woman
# 56791        No, not really            No  25-34 years old  Woman
# 22033         Yes, somewhat            No  25-34 years old    Man
# 59044         Yes, somewhat            No  25-34 years old    Man
# 22454        No, not at all            No  35-44 years old    Man
# 45142         Yes, somewhat           Yes  18-24 years old    Man
# 53307               Neutral            No  35-44 years old    Man
#
#                         Trans                 Sexuality  \
# ResponseId
# 1925                       No                       NaN
# 46465       Prefer not to say         Prefer not to say
# 24286                      No  Prefer to self-describe:
# 15164                     Yes                  Bisexual
# 56791                      No   Straight / Heterosexual
# 22033                      No                       NaN
# 59044                      No         Prefer not to say
# 22454                      No                       NaN
# 45142                      No   Straight / Heterosexual
# 53307                      No   Straight / Heterosexual
#
#                                Ethnicity                        Accessibility  \
# ResponseId
# 1925        White or of European descent                    None of the above
# 46465                  Prefer not to say                    Prefer not to say
# 24286       White or of European descent                    None of the above
# 15164        Black or of African descent  I am blind / have difficulty seeing
# 56791                         East Asian                    None of the above
# 22033                         East Asian                    None of the above
# 59044                    Southeast Asian                    None of the above
# 22454                         East Asian                    None of the above
# 45142                         East Asian                    None of the above
# 53307                         East Asian                    None of the above
#
#                                                  MentalHealth  \
# ResponseId
# 1925                                        None of the above
# 46465                                       Prefer not to say
# 24286                                       None of the above
# 15164       I have a concentration and/or memory disorder ...
# 56791                                       None of the above
# 22033                              I have an anxiety disorder
# 59044                                       None of the above
# 22454                                                     NaN
# 45142       I have a mood or emotional disorder (e.g. depr...
# 53307                                       None of the above
#
#                      SurveyLength                  SurveyEase  SalaryUSD
# ResponseId
# 1925                     Too long  Neither easy nor difficult        1.0
# 46465                    Too long                        Easy        1.0
# 24286       Appropriate in length                        Easy        1.0
# 15164                   Too short                        Easy        2.0
# 56791       Appropriate in length                        Easy        2.0
# 22033       Appropriate in length                        Easy        3.0
# 59044       Appropriate in length                        Easy        3.0
# 22454       Appropriate in length                        Easy        4.0
# 45142                    Too long                        Easy        5.0
# 53307       Appropriate in length                        Easy        5.0

# %% [markdown]
# ## Grouping and Aggregating - Analyzing and Exploring Your Data

# %%
df = pd.read_csv(DATA_PATH)
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# 2                                     Student, full-time
# 3                                     Employed full-time
# 4      Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                                                  Country    US_State  \
# 0                                               Slovakia         NaN
# 1                                            Netherlands         NaN
# 2                                     Russian Federation         NaN
# 3                                                Austria         NaN
# 4      United Kingdom of Great Britain and Northern I...         NaN
# ...                                                  ...         ...
# 83434                           United States of America       Texas
# 83435                                              Benin         NaN
# 83436                           United States of America  New Jersey
# 83437                                             Canada         NaN
# 83438                                             Brazil         NaN
#
#       UK_Country                                            EdLevel  \
# 0            NaN  Secondary school (e.g. American high school, G...
# 1            NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2            NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3            NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4        England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...          ...                                                ...
# 83434        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83435        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436        NaN  Secondary school (e.g. American high school, G...
# 83437        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83438        NaN                 Professional degree (JD, MD, etc.)
#
#           Age1stCode                                          LearnCode  \
# 0      18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 1      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 2      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3      11 - 17 years                                                NaN
# 4       5 - 10 years                            Friend or family member
# ...              ...                                                ...
# 83434  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83435  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436  11 - 17 years                                             School
# 83437  11 - 17 years  Online Courses or Certification;Books / Physic...
# 83438  11 - 17 years                                             School
#
#       YearsCode YearsCodePro  \
# 0           NaN          NaN
# 1             7          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4            17           10
# ...         ...          ...
# 83434         6            5
# 83435         4            2
# 83436        10            4
# 83437         5            3
# 83438        14            4
#
#                                                  DevType  \
# 0                                      Developer, mobile
# 1                                                    NaN
# 2                                                    NaN
# 3                                   Developer, front-end
# 4      Developer, desktop or enterprise applications;...
# ...                                                  ...
# 83434                                Developer, back-end
# 83435                              Developer, full-stack
# 83436  Data scientist or machine learning specialist;...
# 83437                                Developer, back-end
# 83438  Developer, front-end;Developer, full-stack;Dev...
#
#                                                  OrgSize  \
# 0                                     20 to 99 employees
# 1                                                    NaN
# 2                                                    NaN
# 3                                   100 to 499 employees
# 4      Just me - I am a freelancer, sole proprietor, ...
# ...                                                  ...
# 83434                                 20 to 99 employees
# 83435  Just me - I am a freelancer, sole proprietor, ...
# 83436                           10,000 or more employees
# 83437                                 20 to 99 employees
# 83438                                       I don’t know
#
#                           Currency  CompTotal CompFreq  \
# 0                EUR European Euro     4800.0  Monthly
# 1                              NaN        NaN      NaN
# 2                              NaN        NaN      NaN
# 3                EUR European Euro        NaN  Monthly
# 4              GBP\tPound sterling        NaN      NaN
# ...                            ...        ...      ...
# 83434    USD\tUnited States dollar   160500.0   Yearly
# 83435  XOF\tWest African CFA franc   200000.0  Monthly
# 83436    USD\tUnited States dollar     1800.0   Weekly
# 83437         CAD\tCanadian dollar    90000.0  Monthly
# 83438          BRL\tBrazilian real     7700.0  Monthly
#
#                               LanguageHaveWorkedWith  \
# 0      C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1                                  JavaScript;Python
# 2                           Assembly;C;Python;R;Rust
# 3                              JavaScript;TypeScript
# 4                     Bash/Shell;HTML/CSS;Python;SQL
# ...                                              ...
# 83434                             Clojure;Kotlin;SQL
# 83435                                            NaN
# 83436                             Groovy;Java;Python
# 83437           Bash/Shell;JavaScript;Node.js;Python
# 83438         Delphi;Elixir;HTML/CSS;Java;JavaScript
#
#                                   LanguageWantToWorkWith  \
# 0                                                  Swift
# 1                                                    NaN
# 2                                      Julia;Python;Rust
# 3                                  JavaScript;TypeScript
# 4                         Bash/Shell;HTML/CSS;Python;SQL
# ...                                                  ...
# 83434                                            Clojure
# 83435                                                NaN
# 83436                                        Java;Python
# 83437                                            Go;Rust
# 83438  Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
#
#                                  DatabaseHaveWorkedWith  \
# 0                                     PostgreSQL;SQLite
# 1                                            PostgreSQL
# 2                                                SQLite
# 3                                                   NaN
# 4                        Elasticsearch;PostgreSQL;Redis
# ...                                                 ...
# 83434                                     Oracle;SQLite
# 83435    Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83436   DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83437  Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438                                 Oracle;PostgreSQL
#
#                                   DatabaseWantToWorkWith  \
# 0                                                 SQLite
# 1                                                    NaN
# 2                                                 SQLite
# 3                                                    NaN
# 4               Cassandra;Elasticsearch;PostgreSQL;Redis
# ...                                                  ...
# 83434                                             SQLite
# 83435  Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83436                                     DynamoDB;Redis
# 83437                                                NaN
# 83438  Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
#
#           PlatformHaveWorkedWith PlatformWantToWorkWith  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                         Heroku                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
# ...                          ...                    ...
# 83434                        AWS                    AWS
# 83435                        NaN                    NaN
# 83436  AWS;Google Cloud Platform                    AWS
# 83437                     Heroku       AWS;DigitalOcean
# 83438            Microsoft Azure                    AWS
#
#                              WebframeHaveWorkedWith  \
# 0                                   Laravel;Symfony
# 1                              Angular;Flask;Vue.js
# 2                                             Flask
# 3                                    Angular;jQuery
# 4                                             Flask
# ...                                             ...
# 83434                                           NaN
# 83435  Django;jQuery;Laravel;React.js;Ruby on Rails
# 83436                                 FastAPI;Flask
# 83437                 Django;Express;Flask;React.js
# 83438                                Angular;Spring
#
#                                   WebframeWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                  Flask
# 3                                         Angular;jQuery
# 4                                                  Flask
# ...                                                  ...
# 83434                                                NaN
# 83435  Django;Express;jQuery;Laravel;React.js;Ruby on...
# 83436                                      FastAPI;Flask
# 83437                                                NaN
# 83438                     Express;Laravel;Spring;Symfony
#
#                       MiscTechHaveWorkedWith  \
# 0                                        NaN
# 1                                    Cordova
# 2      NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                        NaN
# 4           Apache Spark;Hadoop;NumPy;Pandas
# ...                                      ...
# 83434                                    NaN
# 83435                             Flutter;Qt
# 83436              Hadoop;Keras;NumPy;Pandas
# 83437  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                    NaN
#
#                                   MiscTechWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2            Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                                    NaN
# 4                                    Hadoop;NumPy;Pandas
# ...                                                  ...
# 83434                                                NaN
# 83435                                                NaN
# 83436  Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83437              NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                                NaN
#
#             ToolsTechHaveWorkedWith          ToolsTechWantToWorkWith  \
# 0                               NaN                              NaN
# 1                   Docker;Git;Yarn                              Git
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4        Docker;Git;Kubernetes;Yarn       Docker;Git;Kubernetes;Yarn
# ...                             ...                              ...
# 83434                    Docker;Git                   Git;Kubernetes
# 83435    Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83436  Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83437  Ansible;Docker;Git;Terraform             Kubernetes;Terraform
# 83438                    Docker;Git            Docker;Git;Kubernetes
#
#                             NEWCollabToolsHaveWorkedWith  \
# 0                                         PHPStorm;Xcode
# 1              Android Studio;IntelliJ;Notepad++;PyCharm
# 2      IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                    NaN
# 4             Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# ...                                                  ...
# 83434       IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83435  Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83436  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83437                               PyCharm;Sublime Text
# 83438                        IntelliJ;Visual Studio Code
#
#                             NEWCollabToolsWantToWorkWith        OpSys  \
# 0                                             Atom;Xcode        MacOS
# 1                                                    NaN      Windows
# 2      IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                    NaN      Windows
# 4      Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# ...                                                  ...          ...
# 83434                                   Sublime Text;Vim        MacOS
# 83435  Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83436             IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83437                                                NaN        MacOS
# 83438               IntelliJ;PHPStorm;Visual Studio Code  Linux-based
#
#                                                 NEWStuck  \
# 0      Call a coworker or friend;Visit Stack Overflow...
# 1                         Visit Stack Overflow;Google it
# 2      Visit Stack Overflow;Google it;Watch help / tu...
# 3      Call a coworker or friend;Visit Stack Overflow...
# 4      Visit Stack Overflow;Go for a walk or other ph...
# ...                                                  ...
# 83434                Call a coworker or friend;Google it
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
# 83438  Call a coworker or friend;Visit Stack Overflow...
#
#                                               NEWSOSites  \
# 0                                         Stack Overflow
# 1                                         Stack Overflow
# 2                          Stack Overflow;Stack Exchange
# 3                                         Stack Overflow
# 4                          Stack Overflow;Stack Exchange
# ...                                                  ...
# 83434                      Stack Overflow;Stack Exchange
# 83435                      Stack Overflow;Stack Exchange
# 83436                      Stack Overflow;Stack Exchange
# 83437                                     Stack Overflow
# 83438  Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                            SOVisitFreq SOAccount  \
# 0               Multiple times per day       Yes
# 1                Daily or almost daily       Yes
# 2               Multiple times per day       Yes
# 3                Daily or almost daily       Yes
# 4                Daily or almost daily       Yes
# ...                                ...       ...
# 83434             A few times per week        No
# 83435           Multiple times per day       Yes
# 83436             A few times per week       Yes
# 83437  A few times per month or weekly       Yes
# 83438             A few times per week       Yes
#
#                                               SOPartFreq           SOComm  \
# 0                        A few times per month or weekly  Yes, definitely
# 1                                  Daily or almost daily  Yes, definitely
# 2                                 Multiple times per day  Yes, definitely
# 3                                  Daily or almost daily          Neutral
# 4                                   A few times per week    Yes, somewhat
# ...                                                  ...              ...
# 83434                                                NaN   No, not at all
# 83435  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 83436  I have never participated in Q&A on Stack Over...   No, not really
# 83437                Less than once per month or monthly   No, not really
# 83438                               A few times per week    Yes, somewhat
#
#       NEWOtherComms              Age Gender Trans                Sexuality  \
# 0                No  25-34 years old    Man    No  Straight / Heterosexual
# 1                No  18-24 years old    Man    No  Straight / Heterosexual
# 2               Yes  18-24 years old    Man    No        Prefer not to say
# 3                No  35-44 years old    Man    No  Straight / Heterosexual
# 4                No  25-34 years old    Man    No                      NaN
# ...             ...              ...    ...   ...                      ...
# 83434            No  25-34 years old    Man    No  Straight / Heterosexual
# 83435            No  18-24 years old    Man    No  Straight / Heterosexual
# 83436            No  25-34 years old    Man    No                      NaN
# 83437            No  25-34 years old    Man    No  Straight / Heterosexual
# 83438            No  18-24 years old    Man    No  Straight / Heterosexual
#
#                           Ethnicity                Accessibility  \
# 0      White or of European descent            None of the above
# 1      White or of European descent            None of the above
# 2                 Prefer not to say            None of the above
# 3      White or of European descent  I am deaf / hard of hearing
# 4      White or of European descent            None of the above
# ...                             ...                          ...
# 83434  White or of European descent            None of the above
# 83435   Black or of African descent            None of the above
# 83436  White or of European descent            None of the above
# 83437  White or of European descent            None of the above
# 83438        Hispanic or Latino/a/x            None of the above
#
#                                             MentalHealth  \
# 0                                      None of the above
# 1                                      None of the above
# 2                                      None of the above
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
#
#                 SurveyLength                  SurveyEase  ConvertedCompYearly
# 0      Appropriate in length                        Easy              62268.0
# 1      Appropriate in length                        Easy                  NaN
# 2      Appropriate in length                        Easy                  NaN
# 3      Appropriate in length  Neither easy nor difficult                  NaN
# 4      Appropriate in length                        Easy                  NaN
# ...                      ...                         ...                  ...
# 83434  Appropriate in length                        Easy             160500.0
# 83435  Appropriate in length                        Easy               3960.0
# 83436  Appropriate in length  Neither easy nor difficult              90000.0
# 83437  Appropriate in length  Neither easy nor difficult             816816.0
# 83438  Appropriate in length                        Easy              21168.0
#
# [83439 rows x 48 columns]

# %%
df = df.rename(columns={
    'ConvertedCompYearly': 'SalaryUSD'
})

# %% [markdown]
# > **Mean**: the average of a data set;
#
# > **Mode**: the most common number in a data set;
#
# > **Median**: the middle of the set of numbers.
#
# > **Aggregation**: taking multiple values and returning a single result;

# %%
# What is the most common salary?
df['SalaryUSD'].mode()
# Out:
# 0    150000.0
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# ResponseId    41720.0
# CompTotal     67000.0
# SalaryUSD     56211.0
# dtype: float64

# %%
df.describe()
# Out:
#          ResponseId     CompTotal     SalaryUSD
# count  83439.000000  4.718300e+04  4.684400e+04
# mean   41720.000000  2.119407e+69  1.184262e+05
# std    24086.908893  4.603702e+71  5.272944e+05
# min        1.000000  0.000000e+00  1.000000e+00
# 25%    20860.500000  1.600000e+04  2.702500e+04
# 50%    41720.000000  6.700000e+04  5.621100e+04
# 75%    62579.500000  1.400000e+05  1.000000e+05
# max    83439.000000  1.000000e+74  4.524131e+07

# %%
# How many people gave information about their salary?
df['SalaryUSD'].count()
# Out:
# 46844

# %%
df['SalaryUSD'].count() / df.shape[0]
# Out:
# 0.5614161243543188

# %%
# What percentage of the respondents have a StackOverflow account?
df['SOAccount'].value_counts(normalize=True) # Preferred over: df['SOAccount'].value_counts() / df.shape[0]
# Out:
# Yes                        0.821727
# No                         0.127355
# Not sure/can't remember    0.050918
# Name: SOAccount, dtype: float64

# %%
# What is the most popular OS for work?
schema_df.loc['OpSys', 'question']
# Out:
# 'What is the primary operating system in which you work? *'

# %%
df['OpSys'].value_counts()
# Out:
# Windows                              37758
# Linux-based                          21088
# MacOS                                20984
# Windows Subsystem for Linux (WSL)     2743
# Other (please specify):                575
# BSD                                    146
# Name: OpSys, dtype: int64

# %%
# What do people do when they get stuck on a problem?
schema_df.loc['NEWStuck', 'question']
# Out:
# 'What do you do when you get stuck on a problem? Select all that apply.'

# %%
df['NEWStuck'].value_counts().head(15)
# Out:
# Visit Stack Overflow;Google it                                                                                                                                      5094
# Visit Stack Overflow;Google it;Watch help / tutorial videos                                                                                                         4483
# Google it                                                                                                                                                           3404
# Call a coworker or friend;Visit Stack Overflow;Google it                                                                                                            2905
# Visit Stack Overflow;Google it;Do other work and come back later                                                                                                    2703
# Call a coworker or friend;Visit Stack Overflow;Google it;Watch help / tutorial videos                                                                               2589
# Visit Stack Overflow;Google it;Watch help / tutorial videos;Do other work and come back later                                                                       2378
# Call a coworker or friend;Visit Stack Overflow;Google it;Do other work and come back later                                                                          2148
# Visit Stack Overflow;Go for a walk or other physical activity;Google it;Do other work and come back later                                                           2012
# Call a coworker or friend;Visit Stack Overflow;Google it;Watch help / tutorial videos;Do other work and come back later                                             1896
# Call a coworker or friend;Visit Stack Overflow;Go for a walk or other physical activity;Google it;Watch help / tutorial videos;Do other work and come back later    1806
# Call a coworker or friend;Visit Stack Overflow;Go for a walk or other physical activity;Google it;Do other work and come back later                                 1748
# Visit Stack Overflow;Go for a walk or other physical activity;Google it                                                                                             1669
# Visit Stack Overflow;Go for a walk or other physical activity;Google it;Watch help / tutorial videos;Do other work and come back later                              1602
# Visit Stack Overflow;Go for a walk or other physical activity;Google it;Watch help / tutorial videos                                                                1336
# Name: NEWStuck, dtype: int64

# %% [markdown]
# ### **Grouping**: splitting into groups, applying a function, combining results.

# %%
# Let's get a breakdown for the most popular OS by country.

# Get the countries of the majority of respondents.
df['Country'].value_counts()
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Saint Kitts and Nevis                                       1
# Dominica                                                    1
# Saint Vincent and the Grenadines                            1
# Tuvalu                                                      1
# Papua New Guinea                                            1
# Name: Country, Length: 181, dtype: int64

# %%
country_group = df.groupby(['Country'])
country_group # Splitting into groups.

# %%
country_group.get_group('United States of America')
# Out:
#        ResponseId                              MainBranch  \
# 5               6  I am a student who is learning to code
# 6               7             I code primarily as a hobby
# 15             16  I am a student who is learning to code
# 36             37          I am a developer by profession
# 37             38          I am a developer by profession
# ...           ...                                     ...
# 83427       83428          I am a developer by profession
# 83429       83430             I code primarily as a hobby
# 83430       83431          I am a developer by profession
# 83434       83435          I am a developer by profession
# 83436       83437          I am a developer by profession
#
#                                Employment                   Country  \
# 5                      Student, part-time  United States of America
# 6                     I prefer not to say  United States of America
# 15                     Student, full-time  United States of America
# 36                     Employed full-time  United States of America
# 37                     Employed full-time  United States of America
# ...                                   ...                       ...
# 83427                  Employed full-time  United States of America
# 83429  Not employed, but looking for work  United States of America
# 83430                  Employed full-time  United States of America
# 83434                  Employed full-time  United States of America
# 83436                  Employed full-time  United States of America
#
#                    US_State UK_Country  \
# 5                   Georgia        NaN
# 6             New Hampshire        NaN
# 15                 Missouri        NaN
# 36     District of Columbia        NaN
# 37            Massachusetts        NaN
# ...                     ...        ...
# 83427          Pennsylvania        NaN
# 83429            Washington        NaN
# 83430              Illinois        NaN
# 83434                 Texas        NaN
# 83436            New Jersey        NaN
#
#                                                  EdLevel     Age1stCode  \
# 5           Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 6      Secondary school (e.g. American high school, G...  11 - 17 years
# 15     Secondary school (e.g. American high school, G...   5 - 10 years
# 36          Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 37     Some college/university study without earning ...  18 - 24 years
# ...                                                  ...            ...
# 83427       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83429       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# 83430    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
# 83434       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83436  Secondary school (e.g. American high school, G...  11 - 17 years
#
#                                                LearnCode YearsCode  \
# 5      Other online resources (ex: videos, blogs, etc...       NaN
# 6      Other online resources (ex: videos, blogs, etc...         3
# 15                               Other (please specify):         7
# 36     Other online resources (ex: videos, blogs, etc...         8
# 37       Other online resources (ex: videos, blogs, etc)        20
# ...                                                  ...       ...
# 83427  Other online resources (ex: videos, blogs, etc...        13
# 83429    Other online resources (ex: videos, blogs, etc)         6
# 83430  Other online resources (ex: videos, blogs, etc...        23
# 83434  Other online resources (ex: videos, blogs, etc...         6
# 83436                                             School        10
#
#            YearsCodePro                                            DevType  \
# 5                   NaN                                                NaN
# 6                   NaN                                                NaN
# 15                  NaN                                                NaN
# 36     Less than 1 year        Developer, embedded applications or devices
# 37                   15                                Developer, back-end
# ...                 ...                                                ...
# 83427                 2  Developer, front-end;Developer, desktop or ent...
# 83429               NaN                    Other (please specify):;Student
# 83430                21  Developer, front-end;Developer, full-stack;Dev...
# 83434                 5                                Developer, back-end
# 83436                 4  Data scientist or machine learning specialist;...
#
#                         OrgSize                   Currency  CompTotal  \
# 5                           NaN                        NaN        NaN
# 6                           NaN                        NaN        NaN
# 15                          NaN                        NaN        NaN
# 36           20 to 99 employees  USD\tUnited States dollar   103000.0
# 37     1,000 to 4,999 employees  USD\tUnited States dollar   300000.0
# ...                         ...                        ...        ...
# 83427  1,000 to 4,999 employees  USD\tUnited States dollar    86000.0
# 83429                       NaN                        NaN        NaN
# 83430        10 to 19 employees  USD\tUnited States dollar   125000.0
# 83434        20 to 99 employees  USD\tUnited States dollar   160500.0
# 83436  10,000 or more employees  USD\tUnited States dollar     1800.0
#
#       CompFreq                             LanguageHaveWorkedWith  \
# 5          NaN  C;C#;C++;HTML/CSS;Java;JavaScript;Node.js;Powe...
# 6          NaN                                HTML/CSS;JavaScript
# 15         NaN                                  Bash/Shell;Python
# 36      Yearly                        Assembly;C;Java;Kotlin;Rust
# 37      Yearly                                                 Go
# ...        ...                                                ...
# 83427   Weekly                                        Java;Python
# 83429      NaN             HTML/CSS;PHP;PowerShell;Python;SQL;VBA
# 83430   Yearly        APL;Clojure;LISP;Python;Ruby;SQL;TypeScript
# 83434   Yearly                                 Clojure;Kotlin;SQL
# 83436   Weekly                                 Groovy;Java;Python
#
#                                   LanguageWantToWorkWith  \
# 5      C#;C++;Go;HTML/CSS;Java;JavaScript;Node.js;Obj...
# 6                                HTML/CSS;JavaScript;PHP
# 15                                     Bash/Shell;Python
# 36                              Assembly;Kotlin;Rust;SQL
# 37                                               Go;Rust
# ...                                                  ...
# 83427                                     C#;Java;Python
# 83429  C#;Go;HTML/CSS;Java;JavaScript;PHP;Python;SQL;VBA
# 83430                         APL;Clojure;Haskell;LISP;R
# 83434                                            Clojure
# 83436                                        Java;Python
#
#                                 DatabaseHaveWorkedWith  \
# 5                              MySQL;PostgreSQL;SQLite
# 6                                                  NaN
# 15                                                 NaN
# 36                                                 NaN
# 37                                                 NaN
# ...                                                ...
# 83427                                              NaN
# 83429                         MongoDB;MySQL;PostgreSQL
# 83430                   MongoDB;MySQL;PostgreSQL;Redis
# 83434                                    Oracle;SQLite
# 83436  DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
#
#                                   DatabaseWantToWorkWith  \
# 5      Elasticsearch;Firebase;IBM DB2;MariaDB;Microso...
# 6                                                    NaN
# 15                                                   NaN
# 36                                                   NaN
# 37                                                   NaN
# ...                                                  ...
# 83427                                                NaN
# 83429  MariaDB;Microsoft SQL Server;MongoDB;MySQL;Pos...
# 83430                                         PostgreSQL
# 83434                                             SQLite
# 83436                                     DynamoDB;Redis
#
#                               PlatformHaveWorkedWith  \
# 5                                                NaN
# 6                                                NaN
# 15                                               NaN
# 36                                               NaN
# 37         AWS;Google Cloud Platform;Microsoft Azure
# ...                                              ...
# 83427                                            NaN
# 83429                                         Heroku
# 83430  AWS;DigitalOcean;Google Cloud Platform;Heroku
# 83434                                            AWS
# 83436                      AWS;Google Cloud Platform
#
#                                   PlatformWantToWorkWith  \
# 5                                                    NaN
# 6                                                    NaN
# 15                                                   NaN
# 36                                                   NaN
# 37                                                   NaN
# ...                                                  ...
# 83427                                                NaN
# 83429  AWS;Heroku;IBM Cloud or Watson;Microsoft Azure...
# 83430             AWS;DigitalOcean;Google Cloud Platform
# 83434                                                AWS
# 83436                                                AWS
#
#               WebframeHaveWorkedWith  \
# 5      Express;Flask;jQuery;React.js
# 6                             jQuery
# 15                               NaN
# 36                               NaN
# 37                               NaN
# ...                              ...
# 83427                  Angular;Flask
# 83429            Django;Flask;jQuery
# 83430  Django;React.js;Ruby on Rails
# 83434                            NaN
# 83436                  FastAPI;Flask
#
#                                   WebframeWantToWorkWith  \
# 5                          Express;Flask;jQuery;React.js
# 6                                                 jQuery
# 15                                                   NaN
# 36                                                   NaN
# 37                                                   NaN
# ...                                                  ...
# 83427                                            Angular
# 83429  Angular.js;ASP.NET;ASP.NET Core ;Django;FastAP...
# 83430                                                NaN
# 83434                                                NaN
# 83436                                      FastAPI;Flask
#
#                             MiscTechHaveWorkedWith  \
# 5      Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 6                                              NaN
# 15                                             NaN
# 36                                             NaN
# 37                                             NaN
# ...                                            ...
# 83427                                          NaN
# 83429                                 NumPy;Pandas
# 83430                                          NaN
# 83434                                          NaN
# 83436                    Hadoop;Keras;NumPy;Pandas
#
#                                   MiscTechWantToWorkWith  \
# 5      Keras;NumPy;Pandas;Qt;React Native;TensorFlow;...
# 6                                                    NaN
# 15                                                   NaN
# 36                                                   NaN
# 37                                                   NaN
# ...                                                  ...
# 83427                                                NaN
# 83429     .NET Framework;.NET Core / .NET 5;NumPy;Pandas
# 83430                                                NaN
# 83434                                                NaN
# 83436  Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
#
#               ToolsTechHaveWorkedWith            ToolsTechWantToWorkWith  \
# 5                                 Git  Docker;Git;Unity 3D;Unreal Engine
# 6                                 NaN                                NaN
# 15                                Git                                Git
# 36                         Docker;Git                                Git
# 37               Docker;Git;Terraform                      Git;Terraform
# ...                               ...                                ...
# 83427  Ansible;Git;Terraform;Unity 3D     Ansible;Git;Terraform;Unity 3D
# 83429                             Git                 Docker;Git;Xamarin
# 83430                      Docker;Git     Docker;Git;Kubernetes;Unity 3D
# 83434                      Docker;Git                     Git;Kubernetes
# 83436    Ansible;Docker;Git;Terraform    Docker;Git;Kubernetes;Terraform
#
#                             NEWCollabToolsHaveWorkedWith  \
# 5      IPython/Jupyter;Notepad++;PyCharm;Sublime Text...
# 6                                                    NaN
# 15                                      Emacs;Neovim;Vim
# 36                             IntelliJ;PyCharm;Webstorm
# 37                                Vim;Visual Studio Code
# ...                                                  ...
# 83427  Eclipse;IntelliJ;NetBeans;Sublime Text;Visual ...
# 83429     Atom;Notepad++;Sublime Text;Visual Studio Code
# 83430                                          Emacs;Vim
# 83434       IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83436  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
#
#                             NEWCollabToolsWantToWorkWith        OpSys  \
# 5      Android Studio;IPython/Jupyter;Vim;Visual Stud...      Windows
# 6                                                    NaN      Windows
# 15                                            Neovim;Vim  Linux-based
# 36     Android Studio;IntelliJ;PyCharm;Sublime Text;W...  Linux-based
# 37                                Vim;Visual Studio Code        MacOS
# ...                                                  ...          ...
# 83427           IntelliJ;Sublime Text;Visual Studio Code      Windows
# 83429     Atom;Notepad++;Sublime Text;Visual Studio Code      Windows
# 83430                                              Emacs  Linux-based
# 83434                                   Sublime Text;Vim        MacOS
# 83436             IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
#
#                                                 NEWStuck  \
# 5      Visit Stack Overflow;Go for a walk or other ph...
# 6      Call a coworker or friend;Visit Stack Overflow...
# 15     Call a coworker or friend;Visit Stack Overflow...
# 36     Visit Stack Overflow;Google it;Do other work a...
# 37     Google it;Do other work and come back later;Me...
# ...                                                  ...
# 83427  Call a coworker or friend;Visit Stack Overflow...
# 83429  Visit Stack Overflow;Google it;Watch help / tu...
# 83430  Call a coworker or friend;Visit Stack Overflow...
# 83434                Call a coworker or friend;Google it
# 83436  Call a coworker or friend;Visit Stack Overflow...
#
#                           NEWSOSites                      SOVisitFreq  \
# 5      Stack Overflow;Stack Exchange           Multiple times per day
# 6                     Stack Overflow            Daily or almost daily
# 15     Stack Overflow;Stack Exchange           Multiple times per day
# 36     Stack Overflow;Stack Exchange            Daily or almost daily
# 37     Stack Overflow;Stack Exchange            Daily or almost daily
# ...                              ...                              ...
# 83427  Stack Overflow;Stack Exchange           Multiple times per day
# 83429  Stack Overflow;Stack Exchange  A few times per month or weekly
# 83430  Stack Overflow;Stack Exchange             A few times per week
# 83434  Stack Overflow;Stack Exchange             A few times per week
# 83436  Stack Overflow;Stack Exchange             A few times per week
#
#                      SOAccount  \
# 5                          Yes
# 6                          Yes
# 15                         Yes
# 36                         Yes
# 37                         Yes
# ...                        ...
# 83427                      Yes
# 83429  Not sure/can't remember
# 83430                       No
# 83434                       No
# 83436                      Yes
#
#                                               SOPartFreq           SOComm  \
# 5      I have never participated in Q&A on Stack Over...    Yes, somewhat
# 6                                   A few times per week    Yes, somewhat
# 15                   Less than once per month or monthly          Neutral
# 36                                  A few times per week    Yes, somewhat
# 37                                 Daily or almost daily  Yes, definitely
# ...                                                  ...              ...
# 83427                    A few times per month or weekly    Yes, somewhat
# 83429                                                NaN    Yes, somewhat
# 83430                                                NaN   No, not really
# 83434                                                NaN   No, not at all
# 83436  I have never participated in Q&A on Stack Over...   No, not really
#
#       NEWOtherComms                 Age                      Gender Trans  \
# 5                No     18-24 years old           Prefer not to say    No
# 6                No   Prefer not to say           Prefer not to say    No
# 15               No  Under 18 years old                         Man    No
# 36              Yes     18-24 years old                         Man    No
# 37               No     35-44 years old                         Man    No
# ...             ...                 ...                         ...   ...
# 83427            No     25-34 years old                         Man    No
# 83429            No     25-34 years old  Man;Or, in your own words:   Yes
# 83430            No     45-54 years old                         Man    No
# 83434            No     25-34 years old                         Man    No
# 83436            No     25-34 years old                         Man    No
#
#                      Sexuality                     Ethnicity  \
# 5      Straight / Heterosexual             Prefer not to say
# 6                          NaN                  I don't know
# 15     Straight / Heterosexual  White or of European descent
# 36     Straight / Heterosexual  White or of European descent
# 37     Straight / Heterosexual  White or of European descent
# ...                        ...                           ...
# 83427  Straight / Heterosexual  White or of European descent
# 83429                    Queer  White or of European descent
# 83430  Straight / Heterosexual  White or of European descent
# 83434  Straight / Heterosexual  White or of European descent
# 83436                      NaN  White or of European descent
#
#                                            Accessibility  \
# 5                                      None of the above
# 6                                      None of the above
# 15                                     None of the above
# 36                                     None of the above
# 37                                     None of the above
# ...                                                  ...
# 83427                                  None of the above
# 83429  I am unable to / find it difficult to walk or ...
# 83430                                  None of the above
# 83434                                  None of the above
# 83436                                  None of the above
#
#                                             MentalHealth  \
# 5      I have a concentration and/or memory disorder ...
# 6                                      None of the above
# 15     I have a concentration and/or memory disorder ...
# 36                                     Prefer not to say
# 37     I have a concentration and/or memory disorder ...
# ...                                                  ...
# 83427  I have an anxiety disorder;Or, in your own words:
# 83429                         I have an anxiety disorder
# 83430                                  None of the above
# 83434  I have a concentration and/or memory disorder ...
# 83436                                  None of the above
#
#                 SurveyLength                  SurveyEase  SalaryUSD
# 5                   Too long  Neither easy nor difficult        NaN
# 6      Appropriate in length  Neither easy nor difficult        NaN
# 15                  Too long                        Easy        NaN
# 36                 Too short                        Easy   103000.0
# 37     Appropriate in length                        Easy   300000.0
# ...                      ...                         ...        ...
# 83427              Too short                        Easy  4300000.0
# 83429  Appropriate in length  Neither easy nor difficult        NaN
# 83430  Appropriate in length                        Easy   125000.0
# 83434  Appropriate in length                        Easy   160500.0
# 83436  Appropriate in length  Neither easy nor difficult    90000.0
#
# [15288 rows x 48 columns]

# %%
# We can simulate groupby. However, the difference is that groupby does this
# for every country.
cond = (df['Country'] == 'United States of America')
df[cond]
# Out:
#        ResponseId                              MainBranch  \
# 5               6  I am a student who is learning to code
# 6               7             I code primarily as a hobby
# 15             16  I am a student who is learning to code
# 36             37          I am a developer by profession
# 37             38          I am a developer by profession
# ...           ...                                     ...
# 83427       83428          I am a developer by profession
# 83429       83430             I code primarily as a hobby
# 83430       83431          I am a developer by profession
# 83434       83435          I am a developer by profession
# 83436       83437          I am a developer by profession
#
#                                Employment                   Country  \
# 5                      Student, part-time  United States of America
# 6                     I prefer not to say  United States of America
# 15                     Student, full-time  United States of America
# 36                     Employed full-time  United States of America
# 37                     Employed full-time  United States of America
# ...                                   ...                       ...
# 83427                  Employed full-time  United States of America
# 83429  Not employed, but looking for work  United States of America
# 83430                  Employed full-time  United States of America
# 83434                  Employed full-time  United States of America
# 83436                  Employed full-time  United States of America
#
#                    US_State UK_Country  \
# 5                   Georgia        NaN
# 6             New Hampshire        NaN
# 15                 Missouri        NaN
# 36     District of Columbia        NaN
# 37            Massachusetts        NaN
# ...                     ...        ...
# 83427          Pennsylvania        NaN
# 83429            Washington        NaN
# 83430              Illinois        NaN
# 83434                 Texas        NaN
# 83436            New Jersey        NaN
#
#                                                  EdLevel     Age1stCode  \
# 5           Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 6      Secondary school (e.g. American high school, G...  11 - 17 years
# 15     Secondary school (e.g. American high school, G...   5 - 10 years
# 36          Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 37     Some college/university study without earning ...  18 - 24 years
# ...                                                  ...            ...
# 83427       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83429       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# 83430    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
# 83434       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83436  Secondary school (e.g. American high school, G...  11 - 17 years
#
#                                                LearnCode YearsCode  \
# 5      Other online resources (ex: videos, blogs, etc...       NaN
# 6      Other online resources (ex: videos, blogs, etc...         3
# 15                               Other (please specify):         7
# 36     Other online resources (ex: videos, blogs, etc...         8
# 37       Other online resources (ex: videos, blogs, etc)        20
# ...                                                  ...       ...
# 83427  Other online resources (ex: videos, blogs, etc...        13
# 83429    Other online resources (ex: videos, blogs, etc)         6
# 83430  Other online resources (ex: videos, blogs, etc...        23
# 83434  Other online resources (ex: videos, blogs, etc...         6
# 83436                                             School        10
#
#            YearsCodePro                                            DevType  \
# 5                   NaN                                                NaN
# 6                   NaN                                                NaN
# 15                  NaN                                                NaN
# 36     Less than 1 year        Developer, embedded applications or devices
# 37                   15                                Developer, back-end
# ...                 ...                                                ...
# 83427                 2  Developer, front-end;Developer, desktop or ent...
# 83429               NaN                    Other (please specify):;Student
# 83430                21  Developer, front-end;Developer, full-stack;Dev...
# 83434                 5                                Developer, back-end
# 83436                 4  Data scientist or machine learning specialist;...
#
#                         OrgSize                   Currency  CompTotal  \
# 5                           NaN                        NaN        NaN
# 6                           NaN                        NaN        NaN
# 15                          NaN                        NaN        NaN
# 36           20 to 99 employees  USD\tUnited States dollar   103000.0
# 37     1,000 to 4,999 employees  USD\tUnited States dollar   300000.0
# ...                         ...                        ...        ...
# 83427  1,000 to 4,999 employees  USD\tUnited States dollar    86000.0
# 83429                       NaN                        NaN        NaN
# 83430        10 to 19 employees  USD\tUnited States dollar   125000.0
# 83434        20 to 99 employees  USD\tUnited States dollar   160500.0
# 83436  10,000 or more employees  USD\tUnited States dollar     1800.0
#
#       CompFreq                             LanguageHaveWorkedWith  \
# 5          NaN  C;C#;C++;HTML/CSS;Java;JavaScript;Node.js;Powe...
# 6          NaN                                HTML/CSS;JavaScript
# 15         NaN                                  Bash/Shell;Python
# 36      Yearly                        Assembly;C;Java;Kotlin;Rust
# 37      Yearly                                                 Go
# ...        ...                                                ...
# 83427   Weekly                                        Java;Python
# 83429      NaN             HTML/CSS;PHP;PowerShell;Python;SQL;VBA
# 83430   Yearly        APL;Clojure;LISP;Python;Ruby;SQL;TypeScript
# 83434   Yearly                                 Clojure;Kotlin;SQL
# 83436   Weekly                                 Groovy;Java;Python
#
#                                   LanguageWantToWorkWith  \
# 5      C#;C++;Go;HTML/CSS;Java;JavaScript;Node.js;Obj...
# 6                                HTML/CSS;JavaScript;PHP
# 15                                     Bash/Shell;Python
# 36                              Assembly;Kotlin;Rust;SQL
# 37                                               Go;Rust
# ...                                                  ...
# 83427                                     C#;Java;Python
# 83429  C#;Go;HTML/CSS;Java;JavaScript;PHP;Python;SQL;VBA
# 83430                         APL;Clojure;Haskell;LISP;R
# 83434                                            Clojure
# 83436                                        Java;Python
#
#                                 DatabaseHaveWorkedWith  \
# 5                              MySQL;PostgreSQL;SQLite
# 6                                                  NaN
# 15                                                 NaN
# 36                                                 NaN
# 37                                                 NaN
# ...                                                ...
# 83427                                              NaN
# 83429                         MongoDB;MySQL;PostgreSQL
# 83430                   MongoDB;MySQL;PostgreSQL;Redis
# 83434                                    Oracle;SQLite
# 83436  DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
#
#                                   DatabaseWantToWorkWith  \
# 5      Elasticsearch;Firebase;IBM DB2;MariaDB;Microso...
# 6                                                    NaN
# 15                                                   NaN
# 36                                                   NaN
# 37                                                   NaN
# ...                                                  ...
# 83427                                                NaN
# 83429  MariaDB;Microsoft SQL Server;MongoDB;MySQL;Pos...
# 83430                                         PostgreSQL
# 83434                                             SQLite
# 83436                                     DynamoDB;Redis
#
#                               PlatformHaveWorkedWith  \
# 5                                                NaN
# 6                                                NaN
# 15                                               NaN
# 36                                               NaN
# 37         AWS;Google Cloud Platform;Microsoft Azure
# ...                                              ...
# 83427                                            NaN
# 83429                                         Heroku
# 83430  AWS;DigitalOcean;Google Cloud Platform;Heroku
# 83434                                            AWS
# 83436                      AWS;Google Cloud Platform
#
#                                   PlatformWantToWorkWith  \
# 5                                                    NaN
# 6                                                    NaN
# 15                                                   NaN
# 36                                                   NaN
# 37                                                   NaN
# ...                                                  ...
# 83427                                                NaN
# 83429  AWS;Heroku;IBM Cloud or Watson;Microsoft Azure...
# 83430             AWS;DigitalOcean;Google Cloud Platform
# 83434                                                AWS
# 83436                                                AWS
#
#               WebframeHaveWorkedWith  \
# 5      Express;Flask;jQuery;React.js
# 6                             jQuery
# 15                               NaN
# 36                               NaN
# 37                               NaN
# ...                              ...
# 83427                  Angular;Flask
# 83429            Django;Flask;jQuery
# 83430  Django;React.js;Ruby on Rails
# 83434                            NaN
# 83436                  FastAPI;Flask
#
#                                   WebframeWantToWorkWith  \
# 5                          Express;Flask;jQuery;React.js
# 6                                                 jQuery
# 15                                                   NaN
# 36                                                   NaN
# 37                                                   NaN
# ...                                                  ...
# 83427                                            Angular
# 83429  Angular.js;ASP.NET;ASP.NET Core ;Django;FastAP...
# 83430                                                NaN
# 83434                                                NaN
# 83436                                      FastAPI;Flask
#
#                             MiscTechHaveWorkedWith  \
# 5      Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 6                                              NaN
# 15                                             NaN
# 36                                             NaN
# 37                                             NaN
# ...                                            ...
# 83427                                          NaN
# 83429                                 NumPy;Pandas
# 83430                                          NaN
# 83434                                          NaN
# 83436                    Hadoop;Keras;NumPy;Pandas
#
#                                   MiscTechWantToWorkWith  \
# 5      Keras;NumPy;Pandas;Qt;React Native;TensorFlow;...
# 6                                                    NaN
# 15                                                   NaN
# 36                                                   NaN
# 37                                                   NaN
# ...                                                  ...
# 83427                                                NaN
# 83429     .NET Framework;.NET Core / .NET 5;NumPy;Pandas
# 83430                                                NaN
# 83434                                                NaN
# 83436  Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
#
#               ToolsTechHaveWorkedWith            ToolsTechWantToWorkWith  \
# 5                                 Git  Docker;Git;Unity 3D;Unreal Engine
# 6                                 NaN                                NaN
# 15                                Git                                Git
# 36                         Docker;Git                                Git
# 37               Docker;Git;Terraform                      Git;Terraform
# ...                               ...                                ...
# 83427  Ansible;Git;Terraform;Unity 3D     Ansible;Git;Terraform;Unity 3D
# 83429                             Git                 Docker;Git;Xamarin
# 83430                      Docker;Git     Docker;Git;Kubernetes;Unity 3D
# 83434                      Docker;Git                     Git;Kubernetes
# 83436    Ansible;Docker;Git;Terraform    Docker;Git;Kubernetes;Terraform
#
#                             NEWCollabToolsHaveWorkedWith  \
# 5      IPython/Jupyter;Notepad++;PyCharm;Sublime Text...
# 6                                                    NaN
# 15                                      Emacs;Neovim;Vim
# 36                             IntelliJ;PyCharm;Webstorm
# 37                                Vim;Visual Studio Code
# ...                                                  ...
# 83427  Eclipse;IntelliJ;NetBeans;Sublime Text;Visual ...
# 83429     Atom;Notepad++;Sublime Text;Visual Studio Code
# 83430                                          Emacs;Vim
# 83434       IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83436  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
#
#                             NEWCollabToolsWantToWorkWith        OpSys  \
# 5      Android Studio;IPython/Jupyter;Vim;Visual Stud...      Windows
# 6                                                    NaN      Windows
# 15                                            Neovim;Vim  Linux-based
# 36     Android Studio;IntelliJ;PyCharm;Sublime Text;W...  Linux-based
# 37                                Vim;Visual Studio Code        MacOS
# ...                                                  ...          ...
# 83427           IntelliJ;Sublime Text;Visual Studio Code      Windows
# 83429     Atom;Notepad++;Sublime Text;Visual Studio Code      Windows
# 83430                                              Emacs  Linux-based
# 83434                                   Sublime Text;Vim        MacOS
# 83436             IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
#
#                                                 NEWStuck  \
# 5      Visit Stack Overflow;Go for a walk or other ph...
# 6      Call a coworker or friend;Visit Stack Overflow...
# 15     Call a coworker or friend;Visit Stack Overflow...
# 36     Visit Stack Overflow;Google it;Do other work a...
# 37     Google it;Do other work and come back later;Me...
# ...                                                  ...
# 83427  Call a coworker or friend;Visit Stack Overflow...
# 83429  Visit Stack Overflow;Google it;Watch help / tu...
# 83430  Call a coworker or friend;Visit Stack Overflow...
# 83434                Call a coworker or friend;Google it
# 83436  Call a coworker or friend;Visit Stack Overflow...
#
#                           NEWSOSites                      SOVisitFreq  \
# 5      Stack Overflow;Stack Exchange           Multiple times per day
# 6                     Stack Overflow            Daily or almost daily
# 15     Stack Overflow;Stack Exchange           Multiple times per day
# 36     Stack Overflow;Stack Exchange            Daily or almost daily
# 37     Stack Overflow;Stack Exchange            Daily or almost daily
# ...                              ...                              ...
# 83427  Stack Overflow;Stack Exchange           Multiple times per day
# 83429  Stack Overflow;Stack Exchange  A few times per month or weekly
# 83430  Stack Overflow;Stack Exchange             A few times per week
# 83434  Stack Overflow;Stack Exchange             A few times per week
# 83436  Stack Overflow;Stack Exchange             A few times per week
#
#                      SOAccount  \
# 5                          Yes
# 6                          Yes
# 15                         Yes
# 36                         Yes
# 37                         Yes
# ...                        ...
# 83427                      Yes
# 83429  Not sure/can't remember
# 83430                       No
# 83434                       No
# 83436                      Yes
#
#                                               SOPartFreq           SOComm  \
# 5      I have never participated in Q&A on Stack Over...    Yes, somewhat
# 6                                   A few times per week    Yes, somewhat
# 15                   Less than once per month or monthly          Neutral
# 36                                  A few times per week    Yes, somewhat
# 37                                 Daily or almost daily  Yes, definitely
# ...                                                  ...              ...
# 83427                    A few times per month or weekly    Yes, somewhat
# 83429                                                NaN    Yes, somewhat
# 83430                                                NaN   No, not really
# 83434                                                NaN   No, not at all
# 83436  I have never participated in Q&A on Stack Over...   No, not really
#
#       NEWOtherComms                 Age                      Gender Trans  \
# 5                No     18-24 years old           Prefer not to say    No
# 6                No   Prefer not to say           Prefer not to say    No
# 15               No  Under 18 years old                         Man    No
# 36              Yes     18-24 years old                         Man    No
# 37               No     35-44 years old                         Man    No
# ...             ...                 ...                         ...   ...
# 83427            No     25-34 years old                         Man    No
# 83429            No     25-34 years old  Man;Or, in your own words:   Yes
# 83430            No     45-54 years old                         Man    No
# 83434            No     25-34 years old                         Man    No
# 83436            No     25-34 years old                         Man    No
#
#                      Sexuality                     Ethnicity  \
# 5      Straight / Heterosexual             Prefer not to say
# 6                          NaN                  I don't know
# 15     Straight / Heterosexual  White or of European descent
# 36     Straight / Heterosexual  White or of European descent
# 37     Straight / Heterosexual  White or of European descent
# ...                        ...                           ...
# 83427  Straight / Heterosexual  White or of European descent
# 83429                    Queer  White or of European descent
# 83430  Straight / Heterosexual  White or of European descent
# 83434  Straight / Heterosexual  White or of European descent
# 83436                      NaN  White or of European descent
#
#                                            Accessibility  \
# 5                                      None of the above
# 6                                      None of the above
# 15                                     None of the above
# 36                                     None of the above
# 37                                     None of the above
# ...                                                  ...
# 83427                                  None of the above
# 83429  I am unable to / find it difficult to walk or ...
# 83430                                  None of the above
# 83434                                  None of the above
# 83436                                  None of the above
#
#                                             MentalHealth  \
# 5      I have a concentration and/or memory disorder ...
# 6                                      None of the above
# 15     I have a concentration and/or memory disorder ...
# 36                                     Prefer not to say
# 37     I have a concentration and/or memory disorder ...
# ...                                                  ...
# 83427  I have an anxiety disorder;Or, in your own words:
# 83429                         I have an anxiety disorder
# 83430                                  None of the above
# 83434  I have a concentration and/or memory disorder ...
# 83436                                  None of the above
#
#                 SurveyLength                  SurveyEase  SalaryUSD
# 5                   Too long  Neither easy nor difficult        NaN
# 6      Appropriate in length  Neither easy nor difficult        NaN
# 15                  Too long                        Easy        NaN
# 36                 Too short                        Easy   103000.0
# 37     Appropriate in length                        Easy   300000.0
# ...                      ...                         ...        ...
# 83427              Too short                        Easy  4300000.0
# 83429  Appropriate in length  Neither easy nor difficult        NaN
# 83430  Appropriate in length                        Easy   125000.0
# 83434  Appropriate in length                        Easy   160500.0
# 83436  Appropriate in length  Neither easy nor difficult    90000.0
#
# [15288 rows x 48 columns]

# %%
df[cond]['OpSys'].value_counts(normalize=True)
# Out:
# Windows                              0.382403
# MacOS                                0.356525
# Linux-based                          0.221764
# Windows Subsystem for Linux (WSL)    0.027712
# Other (please specify):              0.009762
# BSD                                  0.001834
# Name: OpSys, dtype: float64

# %%
country_group['OpSys'].value_counts(normalize=True).head(50) # Appyling a function.
# Out:
# Country      OpSys
# Afghanistan  Windows                              0.459016
#              Linux-based                          0.295082
#              MacOS                                0.098361
#              Other (please specify):              0.098361
#              BSD                                  0.032787
#              Windows Subsystem for Linux (WSL)    0.016393
# Albania      Windows                              0.614286
#              Linux-based                          0.228571
#              MacOS                                0.100000
#              Windows Subsystem for Linux (WSL)    0.028571
#              BSD                                  0.014286
#              Other (please specify):              0.014286
# Algeria      Windows                              0.565217
#              Linux-based                          0.282609
#              MacOS                                0.086957
#              BSD                                  0.021739
#              Other (please specify):              0.021739
#              Windows Subsystem for Linux (WSL)    0.021739
# Andorra      Linux-based                          0.500000
#              Windows                              0.166667
#              Windows Subsystem for Linux (WSL)    0.166667
#              MacOS                                0.083333
#              Other (please specify):              0.083333
# Angola       Windows                              0.518519
#              Linux-based                          0.222222
#              MacOS                                0.148148
#              Windows Subsystem for Linux (WSL)    0.111111
# Argentina    Windows                              0.378194
#              Linux-based                          0.352641
#              MacOS                                0.238501
#              Windows Subsystem for Linux (WSL)    0.023850
#              Other (please specify):              0.006814
# Armenia      Windows                              0.406593
#              MacOS                                0.296703
#              Linux-based                          0.230769
#              Windows Subsystem for Linux (WSL)    0.054945
#              Other (please specify):              0.010989
# Australia    Windows                              0.454435
#              MacOS                                0.304374
#              Linux-based                          0.191373
#              Windows Subsystem for Linux (WSL)    0.038882
#              Other (please specify):              0.009113
#              BSD                                  0.001823
# Austria      Windows                              0.472772
#              Linux-based                          0.308168
#              MacOS                                0.188119
#              Windows Subsystem for Linux (WSL)    0.023515
#              BSD                                  0.003713
#              Other (please specify):              0.003713
# Azerbaijan   Windows                              0.562500
# Name: OpSys, dtype: float64

# %%
country_group['OpSys'].value_counts(normalize=True).loc['Bulgaria']
# Out:
# OpSys
# Windows                              0.534826
# Linux-based                          0.243781
# MacOS                                0.184080
# Windows Subsystem for Linux (WSL)    0.019900
# Other (please specify):              0.012438
# BSD                                  0.004975
# Name: OpSys, dtype: float64

# %%
country_group['OpSys'].value_counts(normalize=True).loc['China']
# Out:
# OpSys
# Windows                              0.465700
# MacOS                                0.257005
# Linux-based                          0.208696
# Windows Subsystem for Linux (WSL)    0.058937
# BSD                                  0.006763
# Other (please specify):              0.002899
# Name: OpSys, dtype: float64

# %%
country_group['OpSys'].value_counts(normalize=True).loc['Russian Federation']
# Out:
# OpSys
# Windows                              0.417799
# Linux-based                          0.302989
# MacOS                                0.240489
# Windows Subsystem for Linux (WSL)    0.027853
# Other (please specify):              0.008152
# BSD                                  0.002717
# Name: OpSys, dtype: float64

# %%
# Get the median salaries
country_group['SalaryUSD'].median()
# Out:
# Country
# Afghanistan                              9792.0
# Albania                                 15900.0
# Algeria                                  9875.0
# Andorra                                 94045.5
# Angola                                   9750.0
#                                          ...
# Venezuela, Bolivarian Republic of...    12000.0
# Viet Nam                                12678.0
# Yemen                                    3954.0
# Zambia                                   9816.0
# Zimbabwe                                 7200.0
# Name: SalaryUSD, Length: 181, dtype: float64

# %%
country_group['SalaryUSD'].median().loc['Germany']
# Out:
# 64859.0

# %%
country_group['SalaryUSD'].median().loc['Bulgaria']
# Out:
# 33486.0

# %%
country_group['SalaryUSD'].median().loc['United States of America']
# Out:
# 125000.0

# %%
# See the median and mean salaries
country_group['SalaryUSD'].agg(['median', 'mean'])
# Out:
#                                        median          mean
# Country
# Afghanistan                            9792.0  2.794748e+06
# Albania                               15900.0  4.499814e+04
# Algeria                                9875.0  1.446114e+04
# Andorra                               94045.5  8.928200e+04
# Angola                                 9750.0  2.155680e+04
# ...                                       ...           ...
# Venezuela, Bolivarian Republic of...  12000.0  2.246505e+04
# Viet Nam                              12678.0  1.995289e+04
# Yemen                                  3954.0  5.628667e+03
# Zambia                                 9816.0  1.991491e+04
# Zimbabwe                               7200.0  1.141477e+04
#
# [181 rows x 2 columns]

# %%
# What percentage of people from each country know Python?

# (note: using the following approaches we'll ignore NaN values)

# using the filtering approach. Works, but we'll have to manually go through each country.
cond = (df['Country'] == 'India')
df[cond]['LanguageHaveWorkedWith'].str.contains('Python').value_counts(normalize=True).loc[True]
# Out:
# 0.5088981814645531

# %%
# using the groupby approach
num_ppl_using_py_by_country = country_group['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum() / x.count())
num_ppl_using_py_by_country
# Out:
# Country
# Afghanistan                             0.327869
# Albania                                 0.422535
# Algeria                                 0.422222
# Andorra                                 0.400000
# Angola                                  0.200000
#                                           ...
# Venezuela, Bolivarian Republic of...    0.413462
# Viet Nam                                0.454068
# Yemen                                   0.315789
# Zambia                                  0.545455
# Zimbabwe                                0.500000
# Name: LanguageHaveWorkedWith, Length: 181, dtype: float64

# %%
num_ppl_using_py_by_country.loc['India']
# Out:
# 0.5088981814645531

# %%
num_ppl_using_py_by_country.loc['Bulgaria']
# Out:
# 0.2947103274559194

# %%
pd.DataFrame(num_ppl_using_py_by_country.sort_values(ascending=False))
# Out:
#                                   LanguageHaveWorkedWith
# Country
# Tuvalu                                               1.0
# Liechtenstein                                        1.0
# Brunei Darussalam                                    1.0
# Sierra Leone                                         1.0
# Saint Lucia                                          1.0
# ...                                                  ...
# Mali                                                 0.0
# Monaco                                               0.0
# Papua New Guinea                                     0.0
# Saint Kitts and Nevis                                0.0
# Saint Vincent and the Grenadines                     0.0
#
# [181 rows x 1 columns]

# %% [markdown]
# ## Cleaning Data - Casting Datatypes and Handling Missing Values

# %%
people = {
    'first': ['SimoFirst', 'Jane', 'John', 'Chris', np.nan, None, 'NA'],
    'last': ['SimoLast', 'Doe', 'Doe', 'Sirhc', np.nan, np.nan, 'Missing'],
    'email': ['s.e.hristov99@gmail.com', 'JaneDoe@gmail.com', 'JohnDoe@gmail.com', None, np.nan, 'Anon@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing'],
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-77ef32379c9e> in <module>()
#       1 people = {
# ----> 2     'first': ['SimoFirst', 'Jane', 'John', 'Chris', np.nan, None, 'NA'],
#       3     'last': ['SimoLast', 'Doe', 'Doe', 'Sirhc', np.nan, np.nan, 'Missing'],
#       4     'email': ['s.e.hristov99@gmail.com', 'JaneDoe@gmail.com', 'JohnDoe@gmail.com', None, np.nan, 'Anon@email.com', 'NA'],
#       5     'age': ['33', '55', '63', '36', None, None, 'Missing'],
#
# NameError: name 'np' is not defined

# %% [markdown]
# > **Approach 1**: just remove the rows that have at least 1 missing value.

# %%
ppl_df = pd.DataFrame(people)
ppl_df

# %%
ppl_df.dropna()
# by default it is actually ppl_df.dropna(axis='index', how='any')
# index -> drops rows
# any -> if any columns has a missing values. Note: sometimes it might be ok,
# if the person does not have an `age`.

# %%
# remove rows if all columns have missing values
ppl_df.dropna(how='all')

# %%
# remove columns if all rows have missing values
ppl_df.dropna(axis=1, how='all')  # Same as ppl_df.dropna(axis='columns', how='all')

# %%
# remove columns if any row has a missing value
ppl_df.dropna(axis=1, how='any')

# %%
# remove entries with no emails
ppl_df.dropna(axis=0, subset=['email'])

# %%
# remove entries if they don't have an email and last name
ppl_df.dropna(axis=0, how='all', subset=['email', 'last'])

# %% [markdown]
# > **Custom missing values**: substitue them with `np.nan` by using the `replace` method.

# %%
ppl_df = ppl_df.replace({
    'Missing': np.nan,
    'NA': np.nan,
})

# %%
ppl_df.dropna()

# %% [markdown]
# > **Approach 2**: full them in (impute them) using statistics about the column.

# %%
ppl_df = pd.DataFrame(people).replace({
    'Missing': np.nan,
    'NA': np.nan,
})
ppl_df

# %%
# for numerical values: fill in with the mean / mode / the mean value of the KNN
# for categorical values: create a new category, for ex. 'missing'
ppl_df.fillna('MISSING')

# %% [markdown]
# **Casting**

# %%
ppl_df.fillna(0)

# %%
ppl_df.info()

# %%
# because the `age` column is of type `object` we cannot get its mean
# ppl_df['age'].mean()

# %%
# the NaN value is actually a float 'under the hood'
type(np.nan)

# %%
# so we cannot cast to integers directly (i.e. without substitution or removal)
# ppl_df['age'] = ppl_df['age'].astype(np.int32)

# %%
# because it is a numerical variable, let's substitute is with the mean
ppl_df['age'] = ppl_df['age'].astype(np.float32)
ppl_df['age']

# %%
ppl_df['age'] = ppl_df['age'].fillna(ppl_df['age'].mean())
ppl_df

# %%
ppl_df.info()

# %%
ppl_df['age'].mean()

# %%
# What is the average number of years of coding experience?
df['YearsCode'].head(10)

# %%
# Note that the column has a dtype `object`!
# That means that we can neither take the mean:
# df['YearsCode'].mean()

# %%
# nor can we cast to float
# df['YearsCode'].astype(np.float)

# %%
# however, the good thing about this error is that it shows us
# what the problem actually is - we have a string as an entry

# in order to deal with this problem, we'll replace
# all the strings with a number
df['YearsCode'].unique()

# %%
df['YearsCode'] = df['YearsCode'].replace({
    'Less than 1 year': 0,
    'More than 50 years': 51,
})
df['YearsCode'].unique()

# %%
# now we can convert to float
df['YearsCode'] = df['YearsCode'].astype(np.float32)
df['YearsCode']

# %%
df['YearsCode'].mean()

# %%
df['YearsCode'].mode()[0]

# %%
df['YearsCode'].median()

# %% [markdown]
# ## Reading/Writing Data to Different Sources - Excel, JSON, SQL, Etc

# %% [markdown]
# We'll pretend that we only need the results for Bulgaria. Let's save them as a `csv` to show how it's done.

# %%
# We say that the table already has a column that can act as an index.
# Let's use it.

df = pd.read_csv(DATA_PATH, index_col='ResponseId')
df

# %%
# Get the results from bulgarian developers.
cond = (df['Country'] == 'Bulgaria')
df[cond]

# %%
# Export this dataframe to a new csv file.
df.to_csv('results_for_bulgaria.csv')

# %% [markdown]
# # For Home

# %% [markdown]
# Choose a dataset from a previous year and analyse it using Pandas!

# %%
# !wget https://info.stackoverflowsolutions.com/rs/719-EMH-566/images/stack-overflow-developer-survey-2020.zip -O tmp.zip
# !unzip tmp.zip -d ./data
# !rm tmp.zip
# Out:
# --2022-03-16 14:31:35--  https://info.stackoverflowsolutions.com/rs/719-EMH-566/images/stack-overflow-developer-survey-2020.zip
# Resolving info.stackoverflowsolutions.com (info.stackoverflowsolutions.com)... 104.17.70.206, 104.17.72.206, 104.17.73.206, ...
# Connecting to info.stackoverflowsolutions.com (info.stackoverflowsolutions.com)|104.17.70.206|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9908290 (9.4M) [application/zip]
# Saving to: ‘tmp.zip’
#
# tmp.zip             100%[===================>]   9.45M  1.02MB/s    in 10s
#
# 2022-03-16 14:31:46 (945 KB/s) - ‘tmp.zip’ saved [9908290/9908290]
#
# Archive:  tmp.zip
# replace ./data/README_2020.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: ./data/README_2020.txt
# replace ./data/so_survey_2020.pdf? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: ./data/so_survey_2020.pdf
# replace ./data/survey_results_public.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: ./data/survey_results_public.csv
# replace ./data/survey_results_schema.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: a
# error:  invalid response [a]
# replace ./data/survey_results_schema.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: a
# error:  invalid response [a]
# replace ./data/survey_results_schema.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: a
# error:  invalid response [a]
# replace ./data/survey_results_schema.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: a
# error:  invalid response [a]
# replace ./data/survey_results_schema.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: ./data/survey_results_schema.csv

# %%
import pandas as pd
import numpy as np

# %%
DATA_PATH = '/content/data/survey_results_public.csv'
SCHEMA_PATH = '/content/data/survey_results_schema.csv'

# %%
# Get dataset
df = pd.read_csv(DATA_PATH)
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
#         Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0       NaN         13  Monthly        NaN            NaN             Germany
# 1       NaN         19      NaN        NaN            NaN      United Kingdom
# 2       NaN         15      NaN        NaN            NaN  Russian Federation
# 3      25.0         18      NaN        NaN            NaN             Albania
# 4      31.0         16      NaN        NaN            NaN       United States
# ...     ...        ...      ...        ...            ...                 ...
# 64456   NaN         16      NaN        NaN            NaN       United States
# 64457   NaN        NaN      NaN        NaN            NaN             Morocco
# 64458   NaN        NaN      NaN        NaN            NaN            Viet Nam
# 64459   NaN        NaN      NaN        NaN            NaN              Poland
# 64460   NaN        NaN      NaN        NaN            NaN               Spain
#
#          CurrencyDesc  ...                  SurveyEase           SurveyLength  \
# 0       European Euro  ...  Neither easy nor difficult  Appropriate in length
# 1      Pound sterling  ...                         NaN                    NaN
# 2                 NaN  ...  Neither easy nor difficult  Appropriate in length
# 3        Albanian lek  ...                         NaN                    NaN
# 4                 NaN  ...                        Easy              Too short
# ...               ...  ...                         ...                    ...
# 64456             NaN  ...                         NaN                    NaN
# 64457             NaN  ...                         NaN                    NaN
# 64458             NaN  ...                         NaN                    NaN
# 64459             NaN  ...                         NaN                    NaN
# 64460             NaN  ...                         NaN                    NaN
#
#       Trans                                     UndergradMajor  \
# 0        No  Computer science, computer engineering, or sof...
# 1       NaN  Computer science, computer engineering, or sof...
# 2       NaN                                                NaN
# 3        No  Computer science, computer engineering, or sof...
# 4        No  Computer science, computer engineering, or sof...
# ...     ...                                                ...
# 64456   NaN  Computer science, computer engineering, or sof...
# 64457   NaN                                                NaN
# 64458   NaN                                                NaN
# 64459   NaN                                                NaN
# 64460   NaN  Computer science, computer engineering, or sof...
#
#             WebframeDesireNextYear                      WebframeWorkedWith  \
# 0                     ASP.NET Core                    ASP.NET;ASP.NET Core
# 1                              NaN                                     NaN
# 2                              NaN                                     NaN
# 3                              NaN                                     NaN
# 4             Django;Ruby on Rails                           Ruby on Rails
# ...                            ...                                     ...
# 64456                          NaN                                     NaN
# 64457                          NaN                                     NaN
# 64458                          NaN                                     NaN
# 64459  Angular;Angular.js;React.js                                     NaN
# 64460          ASP.NET Core;jQuery  Angular;Angular.js;ASP.NET Core;jQuery
#
#                                   WelcomeChange WorkWeekHrs YearsCode  \
# 0       Just as welcome now as I felt last year        50.0        36
# 1      Somewhat more welcome now than last year         NaN         7
# 2      Somewhat more welcome now than last year         NaN         4
# 3      Somewhat less welcome now than last year        40.0         7
# 4       Just as welcome now as I felt last year         NaN        15
# ...                                         ...         ...       ...
# 64456                                       NaN         NaN        10
# 64457                                       NaN         NaN       NaN
# 64458                                       NaN         NaN       NaN
# 64459                                       NaN         NaN       NaN
# 64460                                       NaN         NaN       NaN
#
#            YearsCodePro
# 0                    27
# 1                     4
# 2                   NaN
# 3                     4
# 4                     8
# ...                 ...
# 64456  Less than 1 year
# 64457               NaN
# 64458               NaN
# 64459               NaN
# 64460               NaN
#
# [64461 rows x 61 columns]

# %%
# Get questions
schema_df = pd.read_csv(SCHEMA_PATH)
schema_df
# Out:
#                 Column                                       QuestionText
# 0           Respondent  Randomized respondent ID number (not in order ...
# 1           MainBranch  Which of the following options best describes ...
# 2             Hobbyist                            Do you code as a hobby?
# 3                  Age  What is your age (in years)? If you prefer not...
# 4           Age1stCode  At what age did you write your first line of c...
# ..                 ...                                                ...
# 56  WebframeWorkedWith  Which web frameworks have you done extensive d...
# 57       WelcomeChange  Compared to last year, how welcome do you feel...
# 58         WorkWeekHrs  On average, how many hours per week do you wor...
# 59           YearsCode  Including any education, how many years have y...
# 60        YearsCodePro  NOT including education, how many years have y...
#
# [61 rows x 2 columns]

# %%
# Get all table columns of dataset
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
#        'Trans', 'UndergradMajor', 'WebframeDesireNextYear',
#        'WebframeWorkedWith', 'WelcomeChange', 'WorkWeekHrs', 'YearsCode',
#        'YearsCodePro'],
#       dtype='object')

# %% [markdown]
# ---

# %% [markdown]
# **Test Meta Information**

# %% [markdown]
# *Q1 Count of responses to the survey*

# %%
'Q1 How many people responded to the survey? {} responses'.format(df.shape[0])
# Out:
# 'Q1 How many people responded to the survey? 64461 responses'

# %% [markdown]
# *Q2 Count of questions used in the servey*

# %%
'Q2 How many questions were included in the survey? {} questions'.format(schema_df.shape[0])
# Out:
# 'Q2 How many questions were included in the survey? 61 questions'

# %% [markdown]
# ---

# %% [markdown]
# **Count responses by type**

# %% [markdown]
# *Q3 Which role best describes the respondents?*

# %%
df['MainBranch'].value_counts().map(lambda x: f'is the role of {x} respondents')
# Out:
# I am a developer by profession                                                   is the role of 47193 respondents
# I am a student who is learning to code                                            is the role of 7970 respondents
# I am not primarily a developer, but I write code sometimes as part of my work     is the role of 5502 respondents
# I code primarily as a hobby                                                       is the role of 2314 respondents
# I used to be a developer by profession, but no longer am                          is the role of 1183 respondents
# Name: MainBranch, dtype: object

# %% [markdown]
# *Q4 Which is the current employment status of the respondents?*

# %%
df['Employment'].value_counts().map(lambda x: f'is the employment status of {x} respondents')
# Out:
# Employed full-time                                      is the employment status of 45270 respondents
# Student                                                  is the employment status of 7787 respondents
# Independent contractor, freelancer, or self-employed     is the employment status of 5672 respondents
# Not employed, but looking for work                       is the employment status of 2343 respondents
# Employed part-time                                       is the employment status of 2217 respondents
# Not employed, and not looking for work                    is the employment status of 322 respondents
# Retired                                                   is the employment status of 243 respondents
# Name: Employment, dtype: object

# %% [markdown]
# *Q5 Which is the highest completed education level among the respondents?*

# %%
df['EdLevel'].value_counts(normalize=True).map(lambda x: f'has been completed by {round(x*100, 2)}% of the respondents')
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          has been completed by 46.22% of the respondents
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       has been completed by 22.83% of the respondents
# Some college/university study without earning a degree                                 has been completed by 12.6% of the respondents
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     has been completed by 8.31% of the respondents
# Associate degree (A.A., A.S., etc.)                                                    has been completed by 3.21% of the respondents
# Other doctoral degree (Ph.D., Ed.D., etc.)                                             has been completed by 2.94% of the respondents
# Primary/elementary school                                                              has been completed by 1.64% of the respondents
# Professional degree (JD, MD, etc.)                                                     has been completed by 1.39% of the respondents
# I never completed any formal education                                                 has been completed by 0.86% of the respondents
# Name: EdLevel, dtype: object

# %% [markdown]
# *Q6 Which is the most common undergraduate major among the respondents?*

# %%
df['UndergradMajor'].value_counts(normalize=True).map(lambda x: f'is the major of {round(x*100, 2)}% of the respondents')
# Out:
# Computer science, computer engineering, or software engineering                   is the major of 61.93% of the respondents
# Another engineering discipline (such as civil, electrical, mechanical, etc.)       is the major of 9.32% of the respondents
# Information systems, information technology, or system administration              is the major of 7.98% of the respondents
# A natural science (such as biology, chemistry, physics, etc.)                      is the major of 4.32% of the respondents
# Mathematics or statistics                                                          is the major of 3.63% of the respondents
# Web development or web design                                                      is the major of 3.51% of the respondents
# A business discipline (such as accounting, finance, marketing, etc.)                is the major of 2.7% of the respondents
# A humanities discipline (such as literature, history, philosophy, etc.)            is the major of 1.97% of the respondents
# A social science (such as anthropology, psychology, political science, etc.)       is the major of 1.83% of the respondents
# Fine arts or performing arts (such as graphic design, music, studio art, etc.)     is the major of 1.42% of the respondents
# I never declared a major                                                           is the major of 0.89% of the respondents
# A health science (such as nursing, pharmacy, radiology, etc.)                      is the major of 0.49% of the respondents
# Name: UndergradMajor, dtype: object

# %% [markdown]
# *Q7 How old are the respondents currently?*

# %%
df['Age'].value_counts().map(lambda x: f'is the current age of {x} respondents')
# Out:
# 25.0    is the current age of 2693 respondents
# 28.0    is the current age of 2412 respondents
# 30.0    is the current age of 2406 respondents
# 26.0    is the current age of 2391 respondents
# 27.0    is the current age of 2338 respondents
#                          ...
# 34.5       is the current age of 1 respondents
# 14.7       is the current age of 1 respondents
# 97.0       is the current age of 1 respondents
# 3.0        is the current age of 1 respondents
# 14.5       is the current age of 1 respondents
# Name: Age, Length: 110, dtype: object

# %% [markdown]
# *Q8 How old were the respondents when they wrote their first line of code?*

# %%
df['Age1stCode'].value_counts().map(lambda x: f'YO was picked by {x} respondents')
# Out:
# 15    YO was picked by 5618 respondents
# 14    YO was picked by 5514 respondents
# 16    YO was picked by 5463 respondents
# 18    YO was picked by 5382 respondents
# 12    YO was picked by 5081 respondents
#                     ...
# 68       YO was picked by 1 respondents
# 76       YO was picked by 1 respondents
# 72       YO was picked by 1 respondents
# 83       YO was picked by 1 respondents
# 63       YO was picked by 1 respondents
# Name: Age1stCode, Length: 63, dtype: object

# %% [markdown]
# *Q9 How many years of overall coding experience do the respondents have?*

# %%
df['YearsCode'].value_counts().map(lambda x: f'YOE was picked by {x} respondents')
# Out:
# 10                    YOE was picked by 4510 respondents
# 5                     YOE was picked by 4249 respondents
# 6                     YOE was picked by 3834 respondents
# 7                     YOE was picked by 3477 respondents
# 8                     YOE was picked by 3407 respondents
# 4                     YOE was picked by 3254 respondents
# 3                     YOE was picked by 2951 respondents
# 15                    YOE was picked by 2586 respondents
# 20                    YOE was picked by 2562 respondents
# 12                    YOE was picked by 2453 respondents
# 9                     YOE was picked by 2344 respondents
# 2                     YOE was picked by 1916 respondents
# 11                    YOE was picked by 1691 respondents
# 14                    YOE was picked by 1479 respondents
# 13                    YOE was picked by 1468 respondents
# 25                    YOE was picked by 1338 respondents
# 16                    YOE was picked by 1203 respondents
# 30                    YOE was picked by 1114 respondents
# 18                    YOE was picked by 1089 respondents
# 17                    YOE was picked by 1057 respondents
# 1                      YOE was picked by 902 respondents
# 22                     YOE was picked by 792 respondents
# Less than 1 year       YOE was picked by 757 respondents
# 19                     YOE was picked by 657 respondents
# 35                     YOE was picked by 599 respondents
# 23                     YOE was picked by 572 respondents
# 21                     YOE was picked by 550 respondents
# 40                     YOE was picked by 535 respondents
# 24                     YOE was picked by 449 respondents
# 26                     YOE was picked by 378 respondents
# 27                     YOE was picked by 335 respondents
# 28                     YOE was picked by 314 respondents
# 32                     YOE was picked by 309 respondents
# 38                     YOE was picked by 289 respondents
# 37                     YOE was picked by 258 respondents
# 36                     YOE was picked by 246 respondents
# 33                     YOE was picked by 236 respondents
# 34                     YOE was picked by 230 respondents
# 29                     YOE was picked by 178 respondents
# 39                     YOE was picked by 155 respondents
# 31                     YOE was picked by 154 respondents
# More than 50 years     YOE was picked by 143 respondents
# 42                     YOE was picked by 127 respondents
# 45                     YOE was picked by 108 respondents
# 41                      YOE was picked by 99 respondents
# 43                      YOE was picked by 92 respondents
# 44                      YOE was picked by 69 respondents
# 46                      YOE was picked by 44 respondents
# 50                      YOE was picked by 42 respondents
# 48                      YOE was picked by 35 respondents
# 47                      YOE was picked by 27 respondents
# 49                      YOE was picked by 21 respondents
# Name: YearsCode, dtype: object

# %% [markdown]
# *Q10 How many years of professional coding experience do the respondents have?*

# %%
df['YearsCodePro'].value_counts().map(lambda x: f'YOE was picked by {x} respondents')
# Out:
# 3                     YOE was picked by 4815 respondents
# 2                     YOE was picked by 4814 respondents
# 5                     YOE was picked by 3978 respondents
# 4                     YOE was picked by 3716 respondents
# 1                     YOE was picked by 2818 respondents
# 6                     YOE was picked by 2741 respondents
# 10                    YOE was picked by 2735 respondents
# 8                     YOE was picked by 2234 respondents
# 7                     YOE was picked by 2229 respondents
# Less than 1 year      YOE was picked by 2174 respondents
# 15                    YOE was picked by 1531 respondents
# 12                    YOE was picked by 1460 respondents
# 20                    YOE was picked by 1416 respondents
# 9                     YOE was picked by 1232 respondents
# 11                     YOE was picked by 947 respondents
# 13                     YOE was picked by 904 respondents
# 14                     YOE was picked by 758 respondents
# 16                     YOE was picked by 624 respondents
# 25                     YOE was picked by 583 respondents
# 18                     YOE was picked by 533 respondents
# 17                     YOE was picked by 475 respondents
# 22                     YOE was picked by 444 respondents
# 19                     YOE was picked by 373 respondents
# 30                     YOE was picked by 370 respondents
# 21                     YOE was picked by 341 respondents
# 23                     YOE was picked by 321 respondents
# 24                     YOE was picked by 259 respondents
# 26                     YOE was picked by 180 respondents
# 35                     YOE was picked by 162 respondents
# 27                     YOE was picked by 149 respondents
# 28                     YOE was picked by 128 respondents
# 32                     YOE was picked by 103 respondents
# 40                     YOE was picked by 101 respondents
# 33                      YOE was picked by 93 respondents
# 31                      YOE was picked by 80 respondents
# 34                      YOE was picked by 79 respondents
# 29                      YOE was picked by 72 respondents
# 38                      YOE was picked by 64 respondents
# 36                      YOE was picked by 57 respondents
# 37                      YOE was picked by 53 respondents
# 39                      YOE was picked by 42 respondents
# More than 50 years      YOE was picked by 42 respondents
# 42                      YOE was picked by 26 respondents
# 45                      YOE was picked by 21 respondents
# 41                      YOE was picked by 19 respondents
# 44                      YOE was picked by 16 respondents
# 43                      YOE was picked by 15 respondents
# 46                       YOE was picked by 7 respondents
# 47                       YOE was picked by 5 respondents
# 50                       YOE was picked by 5 respondents
# 48                       YOE was picked by 4 respondents
# 49                       YOE was picked by 1 respondents
# Name: YearsCodePro, dtype: object

# %% [markdown]
# *Q11 Which are the 5 most common job titles among the respondents?*

# %%
df['DevType'].value_counts().head(5).map(lambda x: f'is the role of {x} respondents')
# Out:
# Developer, full-stack                                             is the role of 4424 respondents
# Developer, back-end                                               is the role of 3086 respondents
# Developer, back-end;Developer, front-end;Developer, full-stack    is the role of 2227 respondents
# Developer, back-end;Developer, full-stack                         is the role of 1476 respondents
# Developer, front-end                                              is the role of 1401 respondents
# Name: DevType, dtype: object

# %% [markdown]
# *Q12 Which coding language have the respondents worked most with in the past year?*

# %%
df['LanguageWorkedWith'].value_counts().map(lambda x: f'was used by {x} respondents')
# Out:
# HTML/CSS;JavaScript;PHP;SQL                                                         was used by 1073 respondents
# HTML/CSS;JavaScript                                                                  was used by 900 respondents
# C#;HTML/CSS;JavaScript;SQL                                                           was used by 856 respondents
# C#;HTML/CSS;JavaScript;SQL;TypeScript                                                was used by 754 respondents
# HTML/CSS;JavaScript;TypeScript                                                       was used by 697 respondents
#                                                                                                 ...
# Bash/Shell/PowerShell;Go;Java;JavaScript;SQL                                           was used by 1 respondents
# C;C#;HTML/CSS;PHP;Python;SQL                                                           was used by 1 respondents
# Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScript;Kotlin;R;SQL                         was used by 1 respondents
# Bash/Shell/PowerShell;C;C#;C++;Java;Ruby;SQL                                           was used by 1 respondents
# Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;JavaScript;Objective-C;Python;Swift       was used by 1 respondents
# Name: LanguageWorkedWith, Length: 14256, dtype: object

# %% [markdown]
# *Q13 How many respondents have worked with HTML in the past year?*

# %%
html_filter = df['LanguageWorkedWith'].str.contains('HTML', na=False)

'Q13 How many respondents have worked with HTML in the past year? {}'.format((df[html_filter]).shape[0])
# Out:
# 'Q13 How many respondents have worked with HTML in the past year? 36181'

# %% [markdown]
# *Q14 Which was the most commonly used database among the respondents in the past year?*

# %%
df['DatabaseWorkedWith'].value_counts().map(lambda x: f' was used by {x} respondents')
# Out:
# MySQL                                                                                          was used by 3827 respondents
# Microsoft SQL Server                                                                           was used by 3298 respondents
# PostgreSQL                                                                                     was used by 1937 respondents
# SQLite                                                                                         was used by 1313 respondents
# Microsoft SQL Server;MySQL                                                                     was used by 1158 respondents
#                                                                                                           ...
# Cassandra;Couchbase;DynamoDB;Elasticsearch;Firebase;Microsoft SQL Server;PostgreSQL;SQLite        was used by 1 respondents
# Cassandra;IBM DB2;MySQL;PostgreSQL                                                                was used by 1 respondents
# Couchbase;Elasticsearch;MySQL;Oracle;PostgreSQL                                                   was used by 1 respondents
# Couchbase;Elasticsearch;MariaDB;MongoDB;MySQL;PostgreSQL                                          was used by 1 respondents
# Firebase;IBM DB2;MariaDB;Microsoft SQL Server;MySQL;Oracle                                        was used by 1 respondents
# Name: DatabaseWorkedWith, Length: 2808, dtype: object

# %% [markdown]
# *Q15 How many respondents have worked with SQL in the past year?*

# %%
sql_filter = df['DatabaseWorkedWith'].str.contains('SQL', na=False)
'Q15 How many respondents have worked with SQL in the past year? {} respondents'.format((df[sql_filter]).shape[0])
# Out:
# 'Q15 How many respondents have worked with SQL in the past year? 44712 respondents'

# %% [markdown]
# *Q16  Which were the 5 most commonly used web frameworks among the respondents in the past year?*

# %%
df['WebframeWorkedWith'].value_counts().head().map(lambda x: f'was used by {x} respondents')
# Out:
# jQuery      was used by 2079 respondents
# React.js    was used by 1917 respondents
# Spring      was used by 1350 respondents
# Flask       was used by 1074 respondents
# Django       was used by 920 respondents
# Name: WebframeWorkedWith, dtype: object

# %% [markdown]
# *Q17 Which was the preferred operating system of the respondents?*

# %%
df['OpSys'].value_counts().map(lambda x: f'was preferred by {x} respondents')
# Out:
# Windows        was preferred by 27170 respondents
# Linux-based    was preferred by 14932 respondents
# MacOS          was preferred by 14075 respondents
# BSD               was preferred by 51 respondents
# Name: OpSys, dtype: object

# %% [markdown]
# *Q18 Which is the size of the organization the respondents work in?*

# %%
df['OrgSize'].value_counts(normalize=True).map(lambda x: f'is the organization size {round(x*100, 2)}% of the respondents work in')
# Out:
# 20 to 99 employees                                    is the organization size 21.65% of the respond...
# 100 to 499 employees                                  is the organization size 18.75% of the respond...
# 10,000 or more employees                              is the organization size 13.87% of the respond...
# 1,000 to 4,999 employees                              is the organization size 10.97% of the respond...
# 2 to 9 employees                                      is the organization size 9.94% of the responde...
# 10 to 19 employees                                    is the organization size 9.31% of the responde...
# 500 to 999 employees                                  is the organization size 6.5% of the responden...
# Just me - I am a freelancer, sole proprietor, etc.    is the organization size 4.94% of the responde...
# 5,000 to 9,999 employees                              is the organization size 4.08% of the responde...
# Name: OrgSize, dtype: object

# %% [markdown]
# *Q19 How many hours do the respondents work for weekly?*

# %%
df['WorkWeekHrs'].value_counts(normalize=True).map(lambda x: f'is the the weekly hour rate of {round(x*100, 2)}% of the respondents')
# Out:
# 40.00     is the the weekly hour rate of 46.88% of the r...
# 45.00     is the the weekly hour rate of 9.2% of the res...
# 50.00     is the the weekly hour rate of 6.68% of the re...
# 35.00     is the the weekly hour rate of 4.86% of the re...
# 38.00     is the the weekly hour rate of 3.29% of the re...
#                                 ...
# 79.00     is the the weekly hour rate of 0.0% of the res...
# 36.35     is the the weekly hour rate of 0.0% of the res...
# 112.00    is the the weekly hour rate of 0.0% of the res...
# 7.70      is the the weekly hour rate of 0.0% of the res...
# 87.00     is the the weekly hour rate of 0.0% of the res...
# Name: WorkWeekHrs, Length: 157, dtype: object

# %% [markdown]
# *Q20 What are the 5 most common salaries (converted to USD)?*

# %%
df['ConvertedComp'].value_counts().head().map(lambda x: f'USD is the salary of {round(x*100, 2)} respondents')
# Out:
# 120000.0     USD is the salary of 34100 respondents
# 100000.0     USD is the salary of 30600 respondents
# 150000.0     USD is the salary of 27700 respondents
# 1000000.0    USD is the salary of 25800 respondents
# 2000000.0    USD is the salary of 25800 respondents
# Name: ConvertedComp, dtype: object

# %% [markdown]
# ---

# %% [markdown]
# **Sort database**

# %% [markdown]
# *Database sorted by respondent age*

# %%
df = df.sort_values(by='Age')
df
# Out:
#        Respondent                              MainBranch Hobbyist  Age  \
# 20042       20122          I am a developer by profession      Yes  1.0
# 54687       55797          I am a developer by profession      Yes  1.0
# 58292       59438          I am a developer by profession      Yes  1.0
# 25061       25154          I am a developer by profession      Yes  1.0
# 12271       12310  I am a student who is learning to code      Yes  1.0
# ...           ...                                     ...      ...  ...
# 64456       64858                                     NaN      Yes  NaN
# 64457       64867                                     NaN      Yes  NaN
# 64458       64898                                     NaN      Yes  NaN
# 64459       64925                                     NaN      Yes  NaN
# 64460       65112                                     NaN      Yes  NaN
#
#                  Age1stCode CompFreq     CompTotal  ConvertedComp  \
# 20042                    20  Monthly  1.000000e+11      1000000.0
# 54687  Younger than 5 years  Monthly  4.000000e+00           48.0
# 58292  Younger than 5 years  Monthly  6.000000e+06         5268.0
# 25061                    12   Yearly  7.000000e+04        75669.0
# 12271                    23      NaN           NaN            NaN
# ...                     ...      ...           ...            ...
# 64456                    16      NaN           NaN            NaN
# 64457                   NaN      NaN           NaN            NaN
# 64458                   NaN      NaN           NaN            NaN
# 64459                   NaN      NaN           NaN            NaN
# 64460                   NaN      NaN           NaN            NaN
#
#              Country          CurrencyDesc  ...                  SurveyEase  \
# 20042      Indonesia     Indonesian rupiah  ...  Neither easy nor difficult
# 54687  United States  United States dollar  ...  Neither easy nor difficult
# 58292      Indonesia     Indonesian rupiah  ...  Neither easy nor difficult
# 25061    Netherlands         European Euro  ...  Neither easy nor difficult
# 12271        Nigeria                   NaN  ...  Neither easy nor difficult
# ...              ...                   ...  ...                         ...
# 64456  United States                   NaN  ...                         NaN
# 64457        Morocco                   NaN  ...                         NaN
# 64458       Viet Nam                   NaN  ...                         NaN
# 64459         Poland                   NaN  ...                         NaN
# 64460          Spain                   NaN  ...                         NaN
#
#                 SurveyLength Trans  \
# 20042               Too long   Yes
# 54687  Appropriate in length   Yes
# 58292               Too long    No
# 25061               Too long   NaN
# 12271  Appropriate in length    No
# ...                      ...   ...
# 64456                    NaN   NaN
# 64457                    NaN   NaN
# 64458                    NaN   NaN
# 64459                    NaN   NaN
# 64460                    NaN   NaN
#
#                                           UndergradMajor  \
# 20042  Computer science, computer engineering, or sof...
# 54687                                                NaN
# 58292                                                NaN
# 25061  Computer science, computer engineering, or sof...
# 12271                                                NaN
# ...                                                  ...
# 64456  Computer science, computer engineering, or sof...
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460  Computer science, computer engineering, or sof...
#
#               WebframeDesireNextYear  \
# 20042                         Vue.js
# 54687                        Angular
# 58292            ASP.NET Core;Vue.js
# 25061  Angular;ASP.NET Core;React.js
# 12271                         Django
# ...                              ...
# 64456                            NaN
# 64457                            NaN
# 64458                            NaN
# 64459    Angular;Angular.js;React.js
# 64460            ASP.NET Core;jQuery
#
#                                       WebframeWorkedWith  \
# 20042                                            Angular
# 54687                                            Angular
# 58292                                 Angular.js;Express
# 25061  Angular;ASP.NET Core;Express;jQuery;Laravel;Re...
# 12271                                             Django
# ...                                                  ...
# 64456                                                NaN
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460             Angular;Angular.js;ASP.NET Core;jQuery
#
#                                   WelcomeChange WorkWeekHrs         YearsCode  \
# 20042  Somewhat less welcome now than last year         9.0                 5
# 54687     A lot less welcome now than last year         NaN  Less than 1 year
# 58292  Somewhat more welcome now than last year        50.0                 3
# 25061     A lot more welcome now than last year        65.0                14
# 12271  Somewhat less welcome now than last year         NaN  Less than 1 year
# ...                                         ...         ...               ...
# 64456                                       NaN         NaN                10
# 64457                                       NaN         NaN               NaN
# 64458                                       NaN         NaN               NaN
# 64459                                       NaN         NaN               NaN
# 64460                                       NaN         NaN               NaN
#
#            YearsCodePro
# 20042                 1
# 54687  Less than 1 year
# 58292                 2
# 25061                 7
# 12271               NaN
# ...                 ...
# 64456  Less than 1 year
# 64457               NaN
# 64458               NaN
# 64459               NaN
# 64460               NaN
#
# [64461 rows x 61 columns]

# %% [markdown]
# *Database sorted by salary (converted to USD)*

# %%
df = df.sort_values(by='ConvertedComp', ascending=False)
df
# Out:
#        Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 15229       15280  I am a developer by profession      Yes  49.0          8
# 59488       60666  I am a developer by profession      Yes   NaN         14
# 60582       61798  I am a developer by profession      Yes  28.0         15
# 7956         7988  I am a developer by profession      Yes  28.0         14
# 14180       14224  I am a developer by profession      Yes  31.0         19
# ...           ...                             ...      ...   ...        ...
# 64456       64858                             NaN      Yes   NaN         16
# 64457       64867                             NaN      Yes   NaN        NaN
# 64458       64898                             NaN      Yes   NaN        NaN
# 64459       64925                             NaN      Yes   NaN        NaN
# 64460       65112                             NaN      Yes   NaN        NaN
#
#       CompFreq  CompTotal  ConvertedComp        Country          CurrencyDesc  \
# 15229   Weekly   130000.0      2000000.0  United States  United States dollar
# 59488  Monthly   190000.0      2000000.0  United States  United States dollar
# 60582   Weekly   120000.0      2000000.0  United States  United States dollar
# 7956    Weekly   110000.0      2000000.0  United States  United States dollar
# 14180   Weekly    91000.0      2000000.0  United States  United States dollar
# ...        ...        ...            ...            ...                   ...
# 64456      NaN        NaN            NaN  United States                   NaN
# 64457      NaN        NaN            NaN        Morocco                   NaN
# 64458      NaN        NaN            NaN       Viet Nam                   NaN
# 64459      NaN        NaN            NaN         Poland                   NaN
# 64460      NaN        NaN            NaN          Spain                   NaN
#
#        ... SurveyEase           SurveyLength Trans  \
# 15229  ...       Easy  Appropriate in length    No
# 59488  ...        NaN                    NaN   NaN
# 60582  ...       Easy  Appropriate in length    No
# 7956   ...       Easy               Too long    No
# 14180  ...       Easy  Appropriate in length    No
# ...    ...        ...                    ...   ...
# 64456  ...        NaN                    NaN   NaN
# 64457  ...        NaN                    NaN   NaN
# 64458  ...        NaN                    NaN   NaN
# 64459  ...        NaN                    NaN   NaN
# 64460  ...        NaN                    NaN   NaN
#
#                                           UndergradMajor  \
# 15229  Computer science, computer engineering, or sof...
# 59488  Fine arts or performing arts (such as graphic ...
# 60582  Computer science, computer engineering, or sof...
# 7956   Computer science, computer engineering, or sof...
# 14180  Fine arts or performing arts (such as graphic ...
# ...                                                  ...
# 64456  Computer science, computer engineering, or sof...
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460  Computer science, computer engineering, or sof...
#
#                               WebframeDesireNextYear  \
# 15229                               Angular;React.js
# 59488                                            NaN
# 60582                                            NaN
# 7956                                        React.js
# 14180  Express;Laravel;React.js;Ruby on Rails;Vue.js
# ...                                              ...
# 64456                                            NaN
# 64457                                            NaN
# 64458                                            NaN
# 64459                    Angular;Angular.js;React.js
# 64460                            ASP.NET Core;jQuery
#
#                            WebframeWorkedWith  \
# 15229                                     NaN
# 59488                                     NaN
# 60582                                     NaN
# 7956                                 React.js
# 14180                           jQuery;Vue.js
# ...                                       ...
# 64456                                     NaN
# 64457                                     NaN
# 64458                                     NaN
# 64459                                     NaN
# 64460  Angular;Angular.js;ASP.NET Core;jQuery
#
#                                  WelcomeChange WorkWeekHrs YearsCode  \
# 15229  Just as welcome now as I felt last year        40.0        41
# 59488  Just as welcome now as I felt last year        40.0        20
# 60582  Just as welcome now as I felt last year        35.0        13
# 7956   Just as welcome now as I felt last year        30.0        15
# 14180  Just as welcome now as I felt last year        40.0        11
# ...                                        ...         ...       ...
# 64456                                      NaN         NaN        10
# 64457                                      NaN         NaN       NaN
# 64458                                      NaN         NaN       NaN
# 64459                                      NaN         NaN       NaN
# 64460                                      NaN         NaN       NaN
#
#            YearsCodePro
# 15229                23
# 59488                15
# 60582                 8
# 7956                  5
# 14180                10
# ...                 ...
# 64456  Less than 1 year
# 64457               NaN
# 64458               NaN
# 64459               NaN
# 64460               NaN
#
# [64461 rows x 61 columns]

# %% [markdown]
# ---

# %% [markdown]
# **Statistics**

# %% [markdown]
# *Q21 What is the most common salary (converted in USD)?*

# %%
'Q21 What is the most common salary among the respondents? {}'.format(df['ConvertedComp'].mode()[0])
# Out:
# 'Q21 What is the most common salary among the respondents? 120000.0'

# %% [markdown]
# *Q22 What is the average salary (converted in USD)?*

# %%
'Q22 What is the average salary (converted in USD)? {}'.format(round(df['ConvertedComp'].mean(), 2))
# Out:
# 'Q22 What is the average salary (converted in USD)? 103756.05'

# %% [markdown]
# ---

# %% [markdown]
# **Splitting into groups**

# %%
group_by_country = df.groupby(['Country'])

# %% [markdown]
# *Q24 Which respondents are from Bulgaria?*

# %%
bg_respondents = group_by_country.get_group('Bulgaria')
bg_respondents
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 24431       24522                     I am a developer by profession      Yes
# 15118       15168  I am not primarily a developer, but I write co...      Yes
# 32992       33112                     I am a developer by profession      Yes
# 23509       23599                     I am a developer by profession       No
# 21814       21899                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 63039       64413                     I am a developer by profession      Yes
# 63375       64783             I am a student who is learning to code      Yes
# 64078       65548             I am a student who is learning to code      Yes
# 64108       65580                     I am a developer by profession      Yes
# 64450       64013                                                NaN      Yes
#
#         Age Age1stCode CompFreq  CompTotal  ConvertedComp   Country  \
# 24431  35.0         14   Yearly   120000.0       120000.0  Bulgaria
# 15118  32.0         11  Monthly    18000.0       119352.0  Bulgaria
# 32992  32.0         12  Monthly    17000.0       112716.0  Bulgaria
# 23509  42.0         11   Yearly   100000.0       108098.0  Bulgaria
# 21814  44.0         15  Monthly    15000.0        99456.0  Bulgaria
# ...     ...        ...      ...        ...            ...       ...
# 63039   NaN        NaN      NaN        NaN            NaN  Bulgaria
# 63375   NaN         22      NaN        NaN            NaN  Bulgaria
# 64078   NaN         11      NaN        NaN            NaN  Bulgaria
# 64108   NaN        NaN      NaN        NaN            NaN  Bulgaria
# 64450   NaN        NaN      NaN        NaN            NaN  Bulgaria
#
#                CurrencyDesc  ... SurveyEase           SurveyLength Trans  \
# 24431  United States dollar  ...       Easy  Appropriate in length    No
# 15118         Bulgarian lev  ...       Easy               Too long    No
# 32992         Bulgarian lev  ...       Easy  Appropriate in length    No
# 23509         European Euro  ...       Easy               Too long    No
# 21814         Bulgarian lev  ...       Easy               Too long    No
# ...                     ...  ...        ...                    ...   ...
# 63039                   NaN  ...        NaN                    NaN   NaN
# 63375                   NaN  ...        NaN                    NaN   NaN
# 64078                   NaN  ...        NaN                    NaN   NaN
# 64108                   NaN  ...        NaN                    NaN   NaN
# 64450                   NaN  ...        NaN                    NaN   NaN
#
#                                           UndergradMajor  \
# 24431                                                NaN
# 15118  Computer science, computer engineering, or sof...
# 32992  Computer science, computer engineering, or sof...
# 23509  Information systems, information technology, o...
# 21814  Computer science, computer engineering, or sof...
# ...                                                  ...
# 63039                                                NaN
# 63375                                                NaN
# 64078                                                NaN
# 64108                                                NaN
# 64450  Another engineering discipline (such as civil,...
#
#                             WebframeDesireNextYear  \
# 24431                                          NaN
# 15118                                     React.js
# 32992                                       Django
# 23509                        Flask;jQuery;React.js
# 21814  Angular;ASP.NET;ASP.NET Core;Express;jQuery
# ...                                            ...
# 63039                         ASP.NET;ASP.NET Core
# 63375                                          NaN
# 64078                                          NaN
# 64108                                          NaN
# 64450                                          NaN
#
#                         WebframeWorkedWith  \
# 24431                                  NaN
# 15118                             React.js
# 32992                               Django
# 23509         Django;Flask;jQuery;React.js
# 21814  Angular;ASP.NET;ASP.NET Core;jQuery
# ...                                    ...
# 63039          ASP.NET;ASP.NET Core;jQuery
# 63375                                  NaN
# 64078                                  NaN
# 64108                                  NaN
# 64450                                  NaN
#
#                                  WelcomeChange WorkWeekHrs         YearsCode  \
# 24431  Just as welcome now as I felt last year        60.0                15
# 15118  Just as welcome now as I felt last year        50.0                20
# 32992    A lot less welcome now than last year        50.0                21
# 23509  Just as welcome now as I felt last year         NaN                30
# 21814  Just as welcome now as I felt last year        40.0                39
# ...                                        ...         ...               ...
# 63039  Just as welcome now as I felt last year         NaN               NaN
# 63375                                      NaN         NaN  Less than 1 year
# 64078  Just as welcome now as I felt last year         NaN                 4
# 64108                                      NaN         NaN               NaN
# 64450  Just as welcome now as I felt last year         NaN               NaN
#
#       YearsCodePro
# 24431           12
# 15118           18
# 32992           10
# 23509           18
# 21814           23
# ...            ...
# 63039          NaN
# 63375          NaN
# 64078          NaN
# 64108          NaN
# 64450          NaN
#
# [323 rows x 61 columns]

# %% [markdown]
# *Q25 How many respondents are from Bulgaria?*

# %%
'Q25 How many respondents were from Bulgaria? {}'.format(bg_respondents.shape[0])
# Out:
# 'Q25 How many respondents were from Bulgaria? 323'

# %% [markdown]
# *Q26 What are the sizes of the organizations that the respondents from Bulgaria work for?*

# %%
bg_respondents['OrgSize'].value_counts(normalize=True).map(lambda x: f'is the organization size {round(x*100, 2)}% of the respondents work in')
# Out:
# 20 to 99 employees                                    is the organization size 26.45% of the respond...
# 100 to 499 employees                                  is the organization size 22.73% of the respond...
# 2 to 9 employees                                      is the organization size 11.16% of the respond...
# 10 to 19 employees                                    is the organization size 11.16% of the respond...
# 10,000 or more employees                              is the organization size 8.68% of the responde...
# 1,000 to 4,999 employees                              is the organization size 7.02% of the responde...
# Just me - I am a freelancer, sole proprietor, etc.    is the organization size 5.79% of the responde...
# 500 to 999 employees                                  is the organization size 5.37% of the responde...
# 5,000 to 9,999 employees                              is the organization size 1.65% of the responde...
# Name: OrgSize, dtype: object

# %% [markdown]
# *Q27 What part of the Bulgarian respondents work with Python?*

# %%
'Q27 What part of the Bulgarian respondents work with Python? {}%'.format(round(bg_respondents['LanguageWorkedWith'].str.contains('Python').value_counts(normalize=True)[True]*100, 2))
# Out:
# 'Q27 What part of the Bulgarian respondents work with Python? 29.67%'
